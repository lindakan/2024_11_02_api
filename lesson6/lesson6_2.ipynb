# %%
from openpyxl import load_workbook,Workbook,worksheet

wb:Workbook = load_workbook('aqi.xlsx')
type(wb)
# Out:
# openpyxl.workbook.workbook.Workbook

# %%
sheet:worksheet = wb.worksheets[0]
type(sheet)
sheets:list =[]
column_name:list[str] = [cell.value for cell in list(sheet)[0]]
print(column_name)

for row in list(sheet)[1:]:
    column_value= [cell.value for cell in row]
    print(column_value)
# Out:
# ['sitename', 'county', 'aqi', 'pollutant', 'status', 'so2', 'co', 'o3', 'o3_8hr', 'pm10', 'pm2.5', 'no2', 'nox', 'no', 'windspeed', 'winddirec', 'datacreationdate', 'unit', 'co_8hr', 'pm2.5_avg', 'pm10_avg', 'so2_avg', 'longitude', 'latitude', 'siteid']
# ['屏東(枋山)', '屏東縣', 40, None, '良好', 0, 0.24, 39.4, 43.6, 17, 6, 2.4, 2.6, 0.2, 5.7, 90, '2024-11-26 20:00', None, 0.1, 8.7, 27, 0, 120.651472, 22.260899, 313]
# ['花蓮（美崙）', '花蓮縣', 36, None, '良好', 0, 0.33, 47.7, 39.3, 26, 12, 3.8, 4.6, 0.8, 5, 33, '2024-11-26 20:00', None, 0.3, 10.8, 25, 0, 121.61575076, 23.97709367, 312]
# ['新北(樹林)', '新北市', 37, None, '良好', 0.3, 0.41, 29.1, 23.6, 40, 16, 19.7, 24.6, 4.9, 0, 141, '2024-11-26 20:00', None, 0.4, 11.4, 30, 0, 121.38352778, 24.94902778, 311]
# ['屏東（琉球）', '屏東縣', 57, '細懸浮微粒', '普通', 1.4, 0.4, 39, 55.2, 86, 17, 12.5, 13.4, 0.8, 3.2, 320, '2024-11-26 20:00', None, 0.3, 17.8, 54, 2, 120.37722, 22.35222, 204]
# ['臺南（麻豆）', '臺南市', 80, '懸浮微粒', '普通', 1.8, 0.39, 16.3, 37.8, 65, 16, 16.8, 17.3, 0.4, 3.4, 12, '2024-11-26 20:00', None, 0.3, 14.5, 80, 1, 120.24583056, 23.17904722, 203]
# ['高雄（湖內）', '高雄市', 73, '懸浮微粒', '普通', 1.8, 0.44, 20.2, 41.4, 101, 14, 16.8, 17, 0.2, 1.4, 318, '2024-11-26 20:00', None, 0.3, 9.9, 73, 1, 120.24535, 22.87985556, 202]
# ['彰化（員林）', '彰化縣', 30, None, '良好', 1.1, 0.34, 26.8, 33, 22, 9, 11, 12.6, 1.6, 1.5, 355, '2024-11-26 20:00', None, 0.3, 7.8, 27, 1, 120.56373, 23.96117, 201]
# ['大城', '彰化縣', 40, None, '良好', 1.5, 0.25, 37.5, 42.1, 36, 16, 6.8, 7.2, 0.4, 8.6, 47, '2024-11-26 20:00', None, 0.2, 12.2, 30, 1, 120.26964167, 23.85493056, 85]
# ['富貴角', '新北市', 49, None, '良好', 0.3, 0.2, 54.8, 49.2, 55, 18, 1.6, 1.7, 0.1, 9.1, 51, '2024-11-26 20:00', None, 0.2, 14, 49, 0, 121.53656894, 25.29681695, 84]
# ['麥寮', '雲林縣', 65, '懸浮微粒', '普通', 1.5, 0.29, 34, 40.3, 46, 19, 7.6, 8.8, 1.1, 5.9, 3, '2024-11-26 20:00', None, 0.3, 13.3, 65, 1, 120.251825, 23.753506, 83]
# ['關山', '臺東縣', 34, None, '良好', 0.9, 0.31, 31.7, 33, 16, 5, 4.2, 4.5, 0.3, 2.3, 32, '2024-11-26 20:00', None, 0.2, 5.2, 34, 1, 121.161933, 23.045083, 80]
# ['馬公', '澎湖縣', 37, None, '良好', 1.2, 0.26, 46.3, 40.2, 21, 8, 2.7, 3.5, 0.8, 7.3, 32, '2024-11-26 20:00', None, 0.3, 5.7, 14, 1, 119.566158, 23.569031, 78]
# ['金門', '金門縣', 46, None, '良好', 1.3, 0.37, 36.4, 50.2, 23, 14, 7.8, 8.5, 0.6, 2.7, 76, '2024-11-26 20:00', None, 0.3, 9.6, 21, 0, 118.312256, 24.432133, 77]
# ['馬祖', '連江縣', 43, None, '良好', 0.6, 0.26, 53.3, 46.4, 34, 14, 3.7, 4.7, 1, 1.2, 355, '2024-11-26 20:00', None, 0.2, 10.6, 26, 0, 119.952724, 26.153736, 75]
# ['埔里', '南投縣', 46, None, '良好', 1.6, 0.42, 30.8, 36.2, 21, 12, 9.7, 11, 1.3, 0.3, 321, '2024-11-26 20:00', None, 0.2, 14.3, 18, 1, 120.967903, 23.968842, 72]
# ['復興', '高雄市', 68, '懸浮微粒', '普通', 1.4, 0.52, 28.5, 42.4, 122, 21, 19.2, 20.7, 1.5, 1.5, 165, '2024-11-26 20:00', None, 0.4, 18.4, 68, 1, 120.312017, 22.608711, 71]
# ['永和', '新北市', 35, None, '良好', 1.1, 0.44, 37.8, 32, 40, 12, 13.6, 16.5, 2.9, 2.2, 82, '2024-11-26 20:00', None, 0.4, 10.7, 32, 1, 121.516306, 25.017, 70]
# ['竹山', '南投縣', 36, None, '良好', 0.8, 0.41, 15.3, 37.3, 32, 11, 17.4, 17.9, 0.5, 2, 28, '2024-11-26 20:00', None, 0.3, 11.1, 28, 0, 120.677306, 23.756389, 69]
# ['中壢', '桃園市', 42, None, '良好', 1, 0.78, 23.9, 17.7, 35, 16, 24.4, 39.9, 15.5, 1.3, 5, '2024-11-26 20:00', None, 0.7, 12.8, 29, 0, 121.221667, 24.953278, 68]
# ['三重', '新北市', 52, '二氧化氮', '普通', 0.7, 0.84, 18.5, 12.9, 48, 15, 32.6, 70.7, 38.1, '-', '-', '2024-11-26 20:00', None, 1, 13.8, 37, 0, 121.493806, 25.072611, 67]
# ['冬山', '宜蘭縣', 31, None, '良好', 0.7, 0.25, 39.2, 33.6, 34, 12, 6.7, 7.9, 1.2, 1.2, 239, '2024-11-26 20:00', None, 0.2, 9.4, 31, 0, 121.792928, 24.632203, 66]
# ['宜蘭', '宜蘭縣', 31, None, '良好', 0.8, 0.28, 33.2, 33.3, 23, 11, 4.8, 5.4, 0.6, 1.1, 293, '2024-11-26 20:00', None, 0.3, 9.7, 20, 1, 121.746394, 24.747917, 65]
# ['陽明', '臺北市', 39, None, '良好', 0.9, 0.24, 49.7, 43, 28, 7, 1.1, 2.2, 1, None, None, '2024-11-26 20:00', None, 0.2, 4.7, 17, 0, 121.529583, 25.182722, 64]
# ['花蓮', '花蓮縣', 34, None, '良好', 1.6, 0.25, 45.4, 37.3, 34, 10, 3.9, 4.3, 0.4, 4.4, 72, '2024-11-26 20:00', None, 0.3, 8.2, 31, 1, 121.599769, 23.971306, 63]
# ['臺東', '臺東縣', 34, None, '良好', 1, 0.39, 29, 37, 12, 5, 6.3, 7.8, 1.4, 1.6, 326, '2024-11-26 20:00', None, 0.3, 7.2, 21, 1, 121.15045, 22.755358, 62]
# ['恆春', '屏東縣', 28, None, '良好', 0.7, 0.29, None, None, 20, 7, 2.7, 3.4, 0.6, 10.2, 27, '2024-11-26 20:00', None, 0.2, 8.5, 17, 0, 120.788928, 21.958069, 61]
# ['潮州', '屏東縣', 53, '細懸浮微粒', '普通', 1.5, 0.35, 34.8, 50.6, 63, 22, 11, 12.5, 1.5, 2.1, 285, '2024-11-26 20:00', None, 0.2, 16.3, 34, 0, 120.561175, 22.523108, 60]
# ['屏東', '屏東縣', 48, None, '良好', 1.7, 0.42, 36.7, 46.5, 116, 21, 13.1, 13.6, 0.5, 1.8, 256, '2024-11-26 20:00', None, 0.2, 13.7, 48, 1, 120.488033, 22.673081, 59]
# ['小港', '高雄市', 63, '懸浮微粒', '普通', 1.3, 0.53, 29.4, 43.8, 113, 20, 22.4, 23.1, 0.7, 1.3, 331, '2024-11-26 20:00', None, 0.3, 14.9, 63, 1, 120.337736, 22.565833, 58]
# ['前鎮', '高雄市', 74, '懸浮微粒', '普通', 1.8, 0.53, 28.3, 43.3, 139, 23, 19.5, 22, 2.5, 3.2, 3, '2024-11-26 20:00', None, 0.4, 18, 74, 1, 120.30833356, 22.6044507, 57]
# ['前金', '高雄市', 79, '懸浮微粒', '普通', 1.4, 0.46, 27.4, 44.4, 130, 15, 18.3, 19.2, 0.8, 4.2, 354, '2024-11-26 20:00', None, 0.3, 14.3, 79, 0, 120.28676111, 22.63390278, 56]
# ['左營', '高雄市', 82, '懸浮微粒', '普通', 1.5, 0.46, 28.2, 46.3, 163, 23, 16.7, 17.5, 0.7, 3, 7, '2024-11-26 20:00', None, 0.3, 16.7, 82, 1, 120.292917, 22.674861, 54]
# ['楠梓', '高雄市', 90, '懸浮微粒', '普通', 1.8, 0.45, 26.7, 45.4, 182, 20, 16.6, 17.1, 0.4, 2.3, 340, '2024-11-26 20:00', None, 0.3, 14.7, 90, 1, 120.328289, 22.733667, 53]
# ['林園', '高雄市', 59, '懸浮微粒', '普通', 1.8, 0.51, 28.4, 47.3, 84, 17, 23.2, 23.2, 0, 1, 315, '2024-11-26 20:00', None, 0.3, 16.8, 59, 1, 120.41175, 22.4795, 52]
# ['大寮', '高雄市', 52, '細懸浮微粒', '普通', 2.1, 0.46, 24.7, 41.6, 57, 18, 23.2, 24.2, 0.9, 1.8, 318, '2024-11-26 20:00', None, 0.2, 16, 33, 2, 120.425311, 22.56413611, 51]
# ['鳳山', '高雄市', 71, '懸浮微粒', '普通', 1.3, 0.71, 25.2, 41.1, 164, 26, 21.4, 24.5, 3, 1.3, 252, '2024-11-26 20:00', None, 0.4, 19.3, 71, 1, 120.357422, 22.628126, 50]
# ['仁武', '高雄市', 64, '懸浮微粒', '普通', 1.5, 0.48, 25.4, 43.7, 136, 25, 17.9, 19, 1.1, 2.8, 342, '2024-11-26 20:00', None, 0.3, 17.6, 64, 1, 120.332631, 22.689056, 49]
# ['橋頭', '高雄市', 83, '懸浮微粒', '普通', 1.7, 0.48, 22.9, 44.1, 153, 24, 20.2, 21.7, 1.5, 3.2, 10, '2024-11-26 20:00', None, 0.3, 15.7, 83, 1, 120.305689, 22.757506, 48]
# ['美濃', '高雄市', 54, '懸浮微粒', '普通', 1.6, 0.39, 36.2, 44.8, 123, 21, 9.1, 9.8, 0.7, 1.2, 267, '2024-11-26 20:00', None, 0.2, 12.1, 54, 1, 120.530542, 22.883583, 47]
# ['臺南', '臺南市', 75, '懸浮微粒', '普通', 2, 0.45, 19.6, 42.1, 73, 21, 17.2, 17.8, 0.6, 4.2, 2, '2024-11-26 20:00', None, 0.3, 14.5, 75, 1, 120.21947897, 22.98928311, 46]
# ['安南', '臺南市', 75, '懸浮微粒', '普通', 1.5, 0.43, 20.9, 42.6, 63, 13, 13.7, 14.2, 0.4, 3, 320, '2024-11-26 20:00', None, 0.3, 14.7, 75, 0, 120.2175, 23.048197, 45]
# ['善化', '臺南市', 92, '懸浮微粒', '普通', 1.7, 0.4, 19.8, 42.1, 60, 16, 13.6, 14.4, 0.7, 3.9, 355, '2024-11-26 20:00', None, 0.2, 13.2, 92, 1, 120.29740529, 23.11337642, 44]
# ['新營', '臺南市', 105, '懸浮微粒', '對敏感族群不健康', 1.9, 0.45, 17.3, 37.7, 63, 16, 16.5, 16.8, 0.2, 3.4, 14, '2024-11-26 20:00', None, 0.3, 16.6, 113, 1, 120.31725, 23.305633, 43]
# ['嘉義', '嘉義市', 63, '懸浮微粒', '普通', 10.5, 0.47, 15.4, 37.4, 26, 16, 17.2, 18.8, 1.6, 2.7, 6, '2024-11-26 20:00', None, 0.3, 14.2, 63, 2, 120.44125148, 23.46477865, 42]
# ['臺西', '雲林縣', 39, None, '良好', 1.1, 0.28, 35.9, 41, 49, 10, 6.2, 6.8, 0.5, 7.4, 25, '2024-11-26 20:00', None, 0.3, 8.9, 39, 1, 120.19933333, 23.702175, 41]
# ['朴子', '嘉義縣', 72, '懸浮微粒', '普通', 2.3, 0.31, 25.1, 38.8, 56, 9, 11.4, 13.3, 1.9, 2.4, 352, '2024-11-26 20:00', None, 0.3, 9.6, 72, 1, 120.2478, 23.46538, 40]
# ['新港', '嘉義縣', 104, '懸浮微粒', '對敏感族群不健康', 1.9, 0.32, 25.4, 38.3, 40, 12, 12.9, 13.3, 0.4, 3.4, 5, '2024-11-26 20:00', None, 0.3, 15.3, 109, 1, 120.345531, 23.554839, 39]
# ['崙背', '雲林縣', 124, '懸浮微粒', '對敏感族群不健康', 1.6, 0.34, 26.9, 33.9, 135, 14, 11.3, 12.1, 0.7, 2.4, 2, '2024-11-26 20:00', None, 0.3, 17, 173, 1, 120.348742, 23.757547, 38]
# ['斗六', '雲林縣', 49, None, '良好', 1, 0.36, 22.6, 38.8, 21, 10, 12.2, 13.2, 1, 1.8, 344, '2024-11-26 20:00', None, 0.3, 10.8, 49, 1, 120.544994, 23.711853, 37]
# ['南投', '南投縣', 31, None, '良好', 1.1, 0.39, 19.7, 33.4, 21, 6, 15.5, 16.8, 1.2, 1.5, 340, '2024-11-26 20:00', None, 0.3, 9.1, 26, 1, 120.685306, 23.913, 36]
# ['二林', '彰化縣', 39, None, '良好', 1.1, 0.29, 34.8, 37.4, 39, 10, 9.1, 9.5, 0.3, 5.6, 26, '2024-11-26 20:00', None, 0.3, 7.8, 39, 1, 120.409653, 23.925175, 35]
# ['線西', '彰化縣', 34, None, '良好', 1.8, 0.28, 32.8, 33.6, 31, 15, 12.3, 12.8, 0.5, 8, 35, '2024-11-26 20:00', None, 0.3, 10.5, 29, 1, 120.469061, 24.131672, 34]
# ['彰化', '彰化縣', 26, None, '良好', 0.6, 0.33, 27, 28.4, 23, 8, 13.2, 14.3, 1.1, 2.4, 23, '2024-11-26 20:00', None, 0.3, 7.8, 22, 0, 120.541519, 24.066, 33]
# ['西屯', '臺中市', 29, None, '良好', 1, 0.27, 33.3, 31.9, 21, 8, 7.3, 8.6, 1.2, 4.7, 0, '2024-11-26 20:00', None, 0.3, 7.1, 26, 0, 120.616917, 24.162197, 32]
# ['忠明', '臺中市', 27, None, '良好', 1.5, 0.36, 26.6, 29.1, 16, 7, 10.9, 12.1, 1.2, 1.8, 329, '2024-11-26 20:00', None, 0.3, 6.7, 19, 1, 120.641092, 24.151958, 31]
# ['大里', '臺中市', 28, None, '良好', 1.3, 0.39, 22.7, 30.4, 20, 8, 10.8, 12.5, 1.6, 2.1, 8, '2024-11-26 20:00', None, 0.4, 8.2, 19, 1, 120.67844444, 24.09961111, 30]
# ['沙鹿', '臺中市', 26, None, '良好', 0.9, 0.27, 13, 24.1, 26, 11, 6.3, 7, 0.7, 5.4, 9, '2024-11-26 20:00', None, 0.3, 8.1, 22, 0, 120.568794, 24.225628, 29]
# ['豐原', '臺中市', 30, None, '良好', 0.8, 0.29, 27.4, 32, 11, 10, 5.8, 6.1, 0.3, 3.3, 33, '2024-11-26 20:00', None, 0.3, 8.7, 15, 1, 120.74252414, 24.25699731, 28]
# ['三義', '苗栗縣', 30, None, '良好', 0.9, 0.24, 40, 32.9, 25, 9, 3.2, 4.2, 0.9, 7, 16, '2024-11-26 20:00', None, 0.3, 6.5, 13, 0, 120.75956754, 24.38248443, 27]
# ['苗栗', '苗栗縣', 30, None, '良好', 1.6, 0.27, 39.6, 32.4, 27, 14, 7.7, 8.7, 1, 3.8, 8, '2024-11-26 20:00', None, 0.3, 8.5, 20, 1, 120.82011468, 24.56499183, 26]
# ['頭份', '苗栗縣', 31, None, '良好', 1.5, 0.32, 40.8, 31.1, 34, 11, 10.5, 11.6, 1.1, 2.3, 45, '2024-11-26 20:00', None, 0.3, 9.5, 21, 1, 120.89869286, 24.69690679, 25]
# ['新竹', '新竹市', 28, None, '良好', 1.6, 0.33, 39.2, 30.4, 34, 18, 10, 10.4, 0.4, 2.7, 39, '2024-11-26 20:00', None, 0.3, 7.4, 24, 1, 120.97236752, 24.8056356, 24]
# ['竹東', '新竹縣', 32, None, '良好', 0.5, 0.24, 43.8, 35.1, 31, 11, 5.5, 5.7, 0.2, 3.3, 45, '2024-11-26 20:00', None, 0.2, 6.5, 19, 0, 121.08895493, 24.74091408, 23]
# ['湖口', '新竹縣', 32, None, '良好', 2.4, 0.26, 45.1, 35, 30, 11, 4.5, 4.9, 0.3, 5.3, 49, '2024-11-26 20:00', None, 0.3, 8.2, 24, 1, 121.03886894, 24.90009696, 22]
# ['龍潭', '桃園市', 31, None, '良好', 1.4, 0.27, 41.9, 33.4, 37, 11, 7.4, 8.2, 0.8, 6.4, 62, '2024-11-26 20:00', None, 0.3, 9.2, 26, 1, 121.21645772, 24.86400048, 21]
# ['平鎮', '桃園市', 35, None, '良好', 1.2, 0.41, 39.4, 29.9, 29, 15, 13.3, 14.8, 1.5, 3.5, 79, '2024-11-26 20:00', None, 0.4, 10.7, 25, 0, 121.203986, 24.952786, 20]
# ['觀音', '桃園市', 43, None, '良好', 1.8, 0.24, 44.5, 36.6, 39, 17, 7.3, 7.4, 0.1, 6.5, 86, '2024-11-26 20:00', None, 0.2, 13.1, 41, 0, 121.08283092, 25.03556747, 19]
# ['大園', '桃園市', 46, None, '良好', 1.3, 0.27, 41.4, 34.4, 42, 16, 12.2, 13.2, 0.9, 4.4, 64, '2024-11-26 20:00', None, 0.3, 14.3, 34, 1, 121.20251473, 25.06100357, 18]
# ['桃園', '桃園市', 27, None, '良好', 0.8, 0.35, 41.1, 29, 32, 10, 10, 11.3, 1.2, 3.7, 51, '2024-11-26 20:00', None, 0.4, 8.2, 27, 0, 121.30500531, 24.9947107, 17]
# ['大同', '臺北市', 48, None, '良好', 0.8, 0.58, 26.9, 21.6, 41, 17, 26.5, 41.6, 15.1, '-', '-', '2024-11-26 20:00', None, 0.6, 14.8, 32, 0, 121.51342074, 25.06331455, 16]
# ['松山', '臺北市', 46, None, '良好', 1.3, 0.28, 37.6, 30.8, 44, 16, 13.2, 15.2, 1.9, 2.1, 18, '2024-11-26 20:00', None, 0.3, 14.1, 36, 1, 121.578611, 25.05, 15]
# ['古亭', '臺北市', 36, None, '良好', 1.4, 0.35, 37.1, 31.4, 40, 13, 13.2, 13.8, 0.6, 1.8, 67, '2024-11-26 20:00', None, 0.3, 11.2, 31, 0, 121.529556, 25.020608, 14]
# ['萬華', '臺北市', 39, None, '良好', 1.6, 0.34, 32.1, 22.5, 37, 16, 16.8, 19.1, 2.2, 2.9, 94, '2024-11-26 20:00', None, 0.3, 11.9, 32, 1, 121.507972, 25.046503, 13]
# ['中山', '臺北市', 45, None, '良好', 0.9, 0.42, 34.1, 27, 42, 16, 17.3, 20.1, 2.8, 2, 62, '2024-11-26 20:00', None, 0.4, 14, 32, 0, 121.526528, 25.062361, 12]
# ['士林', '臺北市', 36, None, '良好', 0.8, 0.24, 47.6, 39.4, 30, 19, 5.7, 6.3, 0.6, 2.3, 49, '2024-11-26 20:00', None, 0.2, 10.1, 27, 0, 121.51666356, 25.10334003, 11]
# ['淡水', '新北市', 36, None, '良好', 1.4, 0.25, 48, 39.8, 40, 12, 3.3, 4.3, 0.9, None, None, '2024-11-26 20:00', None, 0.2, 10.6, 28, 1, 121.449239, 25.1645, 10]
# ['林口', '新北市', 31, None, '良好', 0.8, 0.26, 40, 29.2, 32, 12, 7.8, 9.2, 1.3, 3.1, 58, '2024-11-26 20:00', None, 0.2, 9.7, 29, 0, 121.36548982, 25.07798949, 9]
# ['菜寮', '新北市', 40, None, '良好', 0.7, 0.32, 43.9, 35.6, 36, 16, 10.1, 10.8, 0.7, 3.5, 75, '2024-11-26 20:00', None, 0.3, 12.2, 26, 0, 121.481028, 25.06895, 8]
# ['新莊', '新北市', 41, None, '良好', 1.1, 0.28, 44.9, 34.4, 47, 17, 6.9, 7.5, 0.6, 5.7, 68, '2024-11-26 20:00', None, 0.3, 12.7, 34, 0, 121.4325, 25.037972, 7]
# ['板橋', '新北市', 34, None, '良好', 1, 0.36, 43.3, 34.7, 41, 14, 13.7, 14.7, 1, 3, 55, '2024-11-26 20:00', None, 0.3, 10.4, 29, 1, 121.458667, 25.012972, 6]
# ['土城', '新北市', 37, None, '良好', 1, 0.35, 40.4, 32.4, 34, 10, 11.6, 12.3, 0.6, 1.9, 145, '2024-11-26 20:00', None, 0.3, 11.5, 29, 1, 121.451861, 24.982528, 5]
# ['新店', '新北市', 49, None, '良好', 0.6, 0.33, 37.7, 29.2, 40, 17, 10.1, 10.9, 0.7, 1.9, 118, '2024-11-26 20:00', None, 0.3, 15.1, 27, 0, 121.537778, 24.977222, 4]
# ['萬里', '新北市', 82, '懸浮微粒', '普通', 0.1, 0.23, 53.9, 48.2, 95, 17, 2.9, 3.5, 0.5, 5.9, 45, '2024-11-26 20:00', None, 0.2, 16.3, 82, 0, 121.689881, 25.179667, 3]
# ['汐止', '新北市', 39, None, '良好', 1.7, 0.25, 40.9, 33.3, 38, 15, 9.8, 11, 1.2, 1.1, 42, '2024-11-26 20:00', None, 0.2, 12, 28, 0, 121.64081, 25.06624, 2]
# ['基隆', '基隆市', 39, None, '良好', 1.2, 0.24, 48.7, 42.9, 41, 12, 4, 4.2, 0.1, 2.4, 89, '2024-11-26 20:00', None, 0.2, 8.9, 31, 1, 121.760056, 25.129167, 1]
# ['屏東(枋山)', '屏東縣', 41, None, '良好', 0, 0.24, 39.7, 44.4, 21, 6, 2.7, 2.9, 0.2, 6.9, 88, '2024-11-26 19:00', None, 0.1, 9.2, 28, 0, 120.651472, 22.260899, 313]
# ['花蓮（美崙）', '花蓮縣', 34, None, '良好', 0, 0.34, 42.8, 37.5, 25, 12, 5.4, 6.8, 1.4, 4.7, 38, '2024-11-26 19:00', None, 0.3, 10.1, 25, 0, 121.61575076, 23.97709367, 312]
# ['新北(樹林)', '新北市', 38, None, '良好', 0.7, 0.43, 26.8, 21.1, 39, 14, 23.7, 32.2, 8.5, 0, 140, '2024-11-26 19:00', None, 0.4, 10.5, 27, 0, 121.38352778, 24.94902778, 311]
# ['屏東（琉球）', '屏東縣', 57, '細懸浮微粒', '普通', 1.4, 0.36, 48.3, 56.3, 55, 19, 9.7, 10.6, 0.9, 3.2, 315, '2024-11-26 19:00', None, 0.3, 18, 47, 2, 120.37722, 22.35222, 204]
# ['臺南（麻豆）', '臺南市', 79, '懸浮微粒', '普通', 1.4, 0.41, 22.2, 40.1, 105, 18, 14, 14.5, 0.4, 3.1, 9, '2024-11-26 19:00', None, 0.2, 14, 79, 1, 120.24583056, 23.17904722, 203]
# ['高雄（湖內）', '高雄市', 61, '懸浮微粒', '普通', 1.6, 0.4, 32.1, 43.3, 113, 12, 14, 13.9, 0, 1.4, 303, '2024-11-26 19:00', None, 0.3, 8.5, 61, 1, 120.24535, 22.87985556, 202]
# ['彰化（員林）', '彰化縣', 31, None, '良好', 1.3, 0.4, 22.7, 33.5, 26, 9, 13.7, 15.8, 2.1, 1.9, 352, '2024-11-26 19:00', None, 0.3, 8, 30, 1, 120.56373, 23.96117, 201]
# ['大城', '彰化縣', 39, None, '良好', 1.4, 0.25, 37.1, 42.1, 24, 14, 6, 7.1, 1, 9, 45, '2024-11-26 19:00', None, 0.2, 11, 30, 1, 120.26964167, 23.85493056, 85]
# ['富貴角', '新北市', 48, None, '良好', 0.3, 0.2, 54.8, 46.4, 54, 18, 1.8, 1.9, 0.1, 10.7, 51, '2024-11-26 19:00', None, 0.2, 13, 48, 0, 121.53656894, 25.29681695, 84]
# ['麥寮', '雲林縣', 70, '懸浮微粒', '普通', 1.2, 0.3, 34.5, 40.5, 62, 14, 7.3, 8.3, 1, 7.4, 3, '2024-11-26 19:00', None, 0.3, 11.7, 70, 1, 120.251825, 23.753506, 83]
# ['關山', '臺東縣', 39, None, '良好', 0.9, 0.33, 30.9, 33.2, 16, 6, 5.1, 5.4, 0.3, 2.6, 37, '2024-11-26 19:00', None, 0.2, 5.3, 39, 1, 121.161933, 23.045083, 80]
# ['馬公', '澎湖縣', 35, None, '良好', 1.1, 0.29, 41, 38.2, 16, 9, 3.4, 4.2, 0.8, 7.3, 39, '2024-11-26 19:00', None, 0.3, 5.2, 13, 1, 119.566158, 23.569031, 78]
# ['金門', '金門縣', 46, None, '良好', 0.8, 0.38, 37, 50.4, 22, 11, 6.8, 7.7, 0.8, 2.1, 86, '2024-11-26 19:00', None, 0.3, 8.4, 21, 0, 118.312256, 24.432133, 77]
# ['馬祖', '連江縣', 39, None, '良好', 0.6, 0.27, 53, 42.9, 34, 10, 4.3, 5.3, 0.9, 1, 330, '2024-11-26 19:00', None, 0.3, 9.6, 24, 0, 119.952724, 26.153736, 75]
# ['埔里', '南投縣', 47, None, '良好', 1.7, 0.4, 33.7, 36.2, 23, 15, 11.2, 12.4, 1.2, 0.5, 310, '2024-11-26 19:00', None, 0.2, 14.5, 17, 1, 120.967903, 23.968842, 72]
# ['復興', '高雄市', 56, '細懸浮微粒', '普通', 1.5, 0.58, 33.8, 43.1, 80, 19, 21.2, 23.1, 1.8, 2, 282, '2024-11-26 19:00', None, 0.4, 17.5, 54, 0, 120.312017, 22.608711, 71]
# ['永和', '新北市', 34, None, '良好', 1, 0.48, 36.7, 29.7, 39, 14, 15.4, 19, 3.6, 2.7, 73, '2024-11-26 19:00', None, 0.4, 10.4, 29, 1, 121.516306, 25.017, 70]
# ['竹山', '南投縣', 37, None, '良好', 0.8, 0.43, 19, 39.8, 33, 18, 17.1, 17.8, 0.6, 2, 23, '2024-11-26 19:00', None, 0.3, 11.4, 28, 0, 120.677306, 23.756389, 69]
# ['中壢', '桃園市', 47, None, '良好', 0.7, 0.8, 22.9, 16.2, 41, 14, 28, 49, 20.9, 1.2, 307, '2024-11-26 19:00', None, 0.7, 12, 27, 0, 121.221667, 24.953278, 68]
# ['三重', '新北市', 55, '二氧化氮', '普通', 0.8, 1.16, 15.5, 11, 42, 16, 36.7, 77.4, 40.7, '-', '-', '2024-11-26 19:00', None, 1, 13, 35, 0, 121.493806, 25.072611, 67]
# ['冬山', '宜蘭縣', 31, None, '良好', 0.6, 0.27, 39.2, 31.6, 37, 11, 8.6, 10.6, 1.9, 1.3, 343, '2024-11-26 19:00', None, 0.3, 8.7, 31, 0, 121.792928, 24.632203, 66]
# ['宜蘭', '宜蘭縣', 31, None, '良好', 0.9, 0.29, 37.2, 31.8, 22, 8, 4.4, 5.2, 0.8, 1.8, 298, '2024-11-26 19:00', None, 0.3, 9.5, 19, 1, 121.746394, 24.747917, 65]
# ['陽明', '臺北市', 37, None, '良好', 0.9, 0.25, 49.4, 40.3, 22, 9, 1.1, 2.2, 1.1, 1.4, 40, '2024-11-26 19:00', None, 0.2, 4, 13, 0, 121.529583, 25.182722, 64]
# ['花蓮', '花蓮縣', 32, None, '良好', 1.5, 0.28, 40.6, 35.5, 31, 7, 4.8, 5.4, 0.6, 3.6, 78, '2024-11-26 19:00', None, 0.3, 8, 30, 1, 121.599769, 23.971306, 63]
# ['臺東', '臺東縣', 35, None, '良好', 1, 0.42, 28.5, 38.3, 20, 6, 7.6, 9.5, 1.8, 1.4, 315, '2024-11-26 19:00', None, 0.3, 7.6, 23, 1, 121.15045, 22.755358, 62]
# ['恆春', '屏東縣', 37, None, '良好', 0.7, 0.3, None, 40.7, 17, 8, 2.7, 3.4, 0.7, 10.7, 33, '2024-11-26 19:00', None, 0.2, 8.7, 17, 0, 120.788928, 21.958069, 61]
# ['潮州', '屏東縣', 50, None, '良好', 1.1, 0.23, 37.3, 51.6, 21, 10, 4.4, 5.8, 1.3, 2.3, 185, '2024-11-26 19:00', None, 0.1, 15.4, 28, 0, 120.561175, 22.523108, 60]
# ['屏東', '屏東縣', 44, None, '良好', 1.5, 0.44, 38.8, 47.2, 54, 14, 14.8, 15.4, 0.6, 2.4, 280, '2024-11-26 19:00', None, 0.2, 12.1, 34, 1, 120.488033, 22.673081, 59]
# ['小港', '高雄市', 50, None, '良好', 1.5, 0.55, 32.3, 44.9, 79, 18, 27.1, 27.7, 0.6, 2.4, 303, '2024-11-26 19:00', None, 0.3, 14.1, 50, 1, 120.337736, 22.565833, 58]
# ['前鎮', '高雄市', 57, '懸浮微粒', '普通', 1.9, 0.62, 31.8, 44.5, 93, 18, 23.8, 26.7, 2.9, 3.4, 13, '2024-11-26 19:00', None, 0.3, 16.7, 57, 1, 120.30833356, 22.6044507, 57]
# ['前金', '高雄市', 65, '懸浮微粒', '普通', 1.3, 0.43, 38.1, 45.6, 101, 14, 17, 18, 1, 4.6, 354, '2024-11-26 19:00', None, 0.3, 13.8, 65, 0, 120.28676111, 22.63390278, 56]
# ['左營', '高雄市', 61, '懸浮微粒', '普通', 1.4, 0.45, 38.6, 47.6, 109, 18, 15.7, 16.4, 0.6, 2.5, 355, '2024-11-26 19:00', None, 0.3, 14.6, 61, 1, 120.292917, 22.674861, 54]
# ['楠梓', '高雄市', 65, '懸浮微粒', '普通', 1.3, 0.41, 38.3, 47.1, 137, 18, 15.2, 15.9, 0.7, 1.9, 335, '2024-11-26 19:00', None, 0.2, 13.7, 65, 1, 120.328289, 22.733667, 53]
# ['林園', '高雄市', 54, '細懸浮微粒', '普通', 2.6, 0.49, 27.6, 49.4, 67, 19, 29.2, 29.5, 0.2, 2.4, 306, '2024-11-26 19:00', None, 0.3, 16.9, 52, 1, 120.41175, 22.4795, 52]
# ['大寮', '高雄市', 51, '細懸浮微粒', '普通', 1.7, 0.44, 34.4, 43.5, 40, 20, 19.6, 20.2, 0.5, 2.2, 330, '2024-11-26 19:00', None, 0.2, 15.5, 29, 2, 120.425311, 22.56413611, 51]
# ['鳳山', '高雄市', 56, '細懸浮微粒', '普通', 1.4, 0.74, 31, 42.7, 88, 21, 22.6, 25.6, 3, 1.4, 256, '2024-11-26 19:00', None, 0.4, 17.7, 50, 1, 120.357422, 22.628126, 50]
# ['仁武', '高雄市', 51, '細懸浮微粒', '普通', 1, 0.45, 36.7, 45.1, 93, 22, 16.6, 17.8, 1.2, 3.5, 345, '2024-11-26 19:00', None, 0.3, 15.5, 45, 1, 120.332631, 22.689056, 49]
# ['橋頭', '高雄市', 64, '懸浮微粒', '普通', 1.6, 0.44, 36.3, 46.1, 147, 20, 16.9, 18.1, 1.2, 3.2, 3, '2024-11-26 19:00', None, 0.2, 13.4, 64, 1, 120.305689, 22.757506, 48]
# ['美濃', '高雄市', 42, None, '良好', 1.6, 0.36, 42.8, 45.1, 83, 16, 9.4, 10.4, 0.9, 1.5, 272, '2024-11-26 19:00', None, 0.2, 10.4, 38, 1, 120.530542, 22.883583, 47]
# ['臺南', '臺南市', 71, '懸浮微粒', '普通', 1.5, 0.43, 29.6, 44.5, 127, 20, 14.1, 14.7, 0.6, 4, 4, '2024-11-26 19:00', None, 0.3, 12.6, 71, 1, 120.21947897, 22.98928311, 46]
# ['安南', '臺南市', 74, '懸浮微粒', '普通', 1, 0.43, 29.7, 44.8, 118, 19, 11.5, 12, 0.4, 3.7, 320, '2024-11-26 19:00', None, 0.3, 14.8, 74, 0, 120.2175, 23.048197, 45]
# ['善化', '臺南市', 89, '懸浮微粒', '普通', 1.9, 0.4, 24.8, 44.4, 176, 13, 13.1, 14.1, 0.9, 4.1, 1, '2024-11-26 19:00', None, 0.2, 12.5, 89, 1, 120.29740529, 23.11337642, 44]
# ['新營', '臺南市', 105, '懸浮微粒', '對敏感族群不健康', 1.7, 0.44, 20.2, 39.9, 102, 15, 15.8, 16, 0.2, 3.8, 13, '2024-11-26 19:00', None, 0.3, 16.4, 114, 1, 120.31725, 23.305633, 43]
# ['嘉義', '嘉義市', 72, '懸浮微粒', '普通', 7.9, 0.54, 15.6, 40.1, 46, 16, 18.7, 20.2, 1.4, 2.6, 6, '2024-11-26 19:00', None, 0.3, 14.3, 72, 2, 120.44125148, 23.46477865, 42]
# ['臺西', '雲林縣', 37, None, '良好', 0.9, 0.29, 35.2, 40.8, 38, 6, 6.3, 6.7, 0.4, 8.8, 23, '2024-11-26 19:00', None, 0.3, 8.2, 35, 1, 120.19933333, 23.702175, 41]
# ['朴子', '嘉義縣', 75, '懸浮微粒', '普通', 2, 0.33, 25.9, 39.8, 58, 10, 11.2, 13.2, 1.9, 2.5, 354, '2024-11-26 19:00', None, 0.2, 9.8, 75, 1, 120.2478, 23.46538, 40]
# ['新港', '嘉義縣', 106, '懸浮微粒', '對敏感族群不健康', 2.2, 0.41, 21.2, 39.8, 75, 12, 14.4, 14.8, 0.3, 4.7, 9, '2024-11-26 19:00', None, 0.3, 15.5, 118, 1, 120.345531, 23.554839, 39]
# ['崙背', '雲林縣', 128, '懸浮微粒', '對敏感族群不健康', 2.7, 0.45, 20.1, 34.1, 157, 13, 16.6, 17.5, 0.9, 2.2, 353, '2024-11-26 19:00', None, 0.3, 17.6, 184, 1, 120.348742, 23.757547, 38]
# ['斗六', '雲林縣', 59, '懸浮微粒', '普通', 1.3, 0.42, 20, 40.5, 34, 12, 15.2, 16.1, 0.9, 1.8, 337, '2024-11-26 19:00', None, 0.3, 11.5, 59, 1, 120.544994, 23.711853, 37]
# ['南投', '南投縣', 32, None, '良好', 1.3, 0.45, 15.7, 34.9, 24, 12, 19.8, 21.6, 1.8, 1.2, 5, '2024-11-26 19:00', None, 0.3, 9.6, 28, 1, 120.685306, 23.913, 36]
# ['二林', '彰化縣', 42, None, '良好', 1.4, 0.35, 29, 37.1, 32, 10, 12.4, 13, 0.6, 4.9, 22, '2024-11-26 19:00', None, 0.3, 7.7, 42, 1, 120.409653, 23.925175, 35]
# ['線西', '彰化縣', 31, None, '良好', 1.1, 0.29, 30.9, 32.7, 22, 11, 11.7, 12.5, 0.7, 7.7, 31, '2024-11-26 19:00', None, 0.3, 9.5, 30, 1, 120.469061, 24.131672, 34]
# ['彰化', '彰化縣', 27, None, '良好', 0.5, 0.38, 25, 28.1, 21, 7, 13.7, 15.1, 1.4, 3.1, 20, '2024-11-26 19:00', None, 0.3, 8.2, 24, 0, 120.541519, 24.066, 33]
# ['西屯', '臺中市', 29, None, '良好', 0.8, 0.3, 30, 30.9, 19, 8, 8.9, 10.1, 1.2, 4.8, 0, '2024-11-26 19:00', None, 0.3, 7.7, 29, 0, 120.616917, 24.162197, 32]
# ['忠明', '臺中市', 26, None, '良好', 1.5, 0.43, 22.7, 29, 15, 11, 13.6, 15.2, 1.6, 2.3, 327, '2024-11-26 19:00', None, 0.3, 6.2, 21, 1, 120.641092, 24.151958, 31]
# ['大里', '臺中市', 29, None, '良好', 1.4, 0.47, 18.9, 31.5, 20, 13, 15, 16.7, 1.7, 3.5, 11, '2024-11-26 19:00', None, 0.4, 7.8, 19, 1, 120.67844444, 24.09961111, 30]
# ['沙鹿', '臺中市', 26, None, '良好', 0.9, 0.29, 10.9, 25.9, 27, 8, 7.6, 8.2, 0.6, 5.7, 30, '2024-11-26 19:00', None, 0.3, 7.9, 21, 0, 120.568794, 24.225628, 29]
# ['豐原', '臺中市', 30, None, '良好', 1.2, 0.37, 22.2, 32.3, 20, 16, 10.9, 11.5, 0.6, 2.2, 19, '2024-11-26 19:00', None, 0.3, 8, 16, 1, 120.74252414, 24.25699731, 28]
# ['三義', '苗栗縣', 28, None, '良好', 0.8, 0.26, 35.6, 30.6, 15, 11, 4.6, 5.7, 1, 7.4, 19, '2024-11-26 19:00', None, 0.3, 6.2, 12, 0, 120.75956754, 24.38248443, 27]
# ['苗栗', '苗栗縣', 28, None, '良好', 1.6, 0.28, 37.7, 30.2, 28, 11, 7.7, 8.8, 1.1, 5.2, 18, '2024-11-26 19:00', None, 0.3, 7.6, 19, 1, 120.82011468, 24.56499183, 26]
# ['頭份', '苗栗縣', 29, None, '良好', 1.7, 0.34, 35.1, 28.7, 28, 12, 12, 13.3, 1.3, 3.4, 44, '2024-11-26 19:00', None, 0.3, 9, 18, 1, 120.89869286, 24.69690679, 25]
# ['新竹', '新竹市', 25, None, '良好', 1.7, 0.35, 36.2, 27.9, 38, 10, 12.6, 13, 0.4, 3.4, 52, '2024-11-26 19:00', None, 0.3, 5.4, 22, 1, 120.97236752, 24.8056356, 24]
# ['竹東', '新竹縣', 30, None, '良好', 0.5, 0.24, 42.3, 32.4, 28, 7, 5.8, 6.3, 0.5, 5.1, 40, '2024-11-26 19:00', None, 0.2, 6, 17, 0, 121.08895493, 24.74091408, 23]
# ['湖口', '新竹縣', 29, None, '良好', 2.4, 0.26, 44.4, 32, 36, 8, 5.6, 6, 0.3, 6.8, 47, '2024-11-26 19:00', None, 0.3, 7.3, 23, 1, 121.03886894, 24.90009696, 22]
# ['龍潭', '桃園市', 28, None, '良好', 1.5, 0.28, 40.6, 30.6, 35, 12, 8, 8.9, 0.9, 6.3, 53, '2024-11-26 19:00', None, 0.3, 8.5, 24, 1, 121.21645772, 24.86400048, 21]
# ['平鎮', '桃園市', 30, None, '良好', 0.9, 0.45, 39.7, 27.1, 35, 13, 12.9, 14.6, 1.7, 2.6, 71, '2024-11-26 19:00', None, 0.4, 9.2, 23, 0, 121.203986, 24.952786, 20]
# ['觀音', '桃園市', 42, None, '良好', 1.2, 0.22, 45.8, 33.5, 56, 16, 6.5, 6.6, 0.1, 6.2, 89, '2024-11-26 19:00', None, 0.2, 12.4, 42, 0, 121.08283092, 25.03556747, 19]
# ['大園', '桃園市', 43, None, '良好', 2.1, 0.26, 41.9, 31.6, 46, 17, 11.9, 13.1, 1.1, 5.9, 61, '2024-11-26 19:00', None, 0.3, 13.3, 32, 1, 121.20251473, 25.06100357, 18]
# ['桃園', '桃園市', 27, None, '良好', 0.9, 0.39, 38.1, 26.4, 38, 12, 12.2, 13.9, 1.7, 3, 56, '2024-11-26 19:00', None, 0.4, 8.4, 26, 0, 121.30500531, 24.9947107, 17]
# ['大同', '臺北市', 47, None, '良好', 0.9, 0.73, 23.5, 19.1, 40, 18, 27.2, 47.8, 20.6, '-', '-', '2024-11-26 19:00', None, 0.6, 14.6, 29, 0, 121.51342074, 25.06331455, 16]
# ['松山', '臺北市', 43, None, '良好', 1.2, 0.33, 34.4, 28.5, 43, 18, 16.6, 19, 2.4, 2.2, 17, '2024-11-26 19:00', None, 0.3, 13.2, 34, 1, 121.578611, 25.05, 15]
# ['古亭', '臺北市', 37, None, '良好', 1.3, 0.38, 36.9, 29.1, 38, 12, 13.8, 14.5, 0.7, 1.1, 57, '2024-11-26 19:00', None, 0.3, 11.5, 28, 0, 121.529556, 25.020608, 14]
# ['萬華', '臺北市', 37, None, '良好', 1.6, 0.41, 27.6, 19.4, 38, 17, 22.1, 24.9, 2.8, 2.3, 95, '2024-11-26 19:00', None, 0.3, 10.7, 30, 1, 121.507972, 25.046503, 13]
# ['中山', '臺北市', 42, None, '良好', 0.9, 0.52, 29.4, 24.4, 41, 16, 22.2, 26.3, 4, 1.9, 61, '2024-11-26 19:00', None, 0.4, 12.9, 30, 0, 121.526528, 25.062361, 12]
# ['士林', '臺北市', 33, None, '良好', 0.9, 0.27, 45.3, 36.2, 39, 12, 7.4, 8.2, 0.7, 1.3, 60, '2024-11-26 19:00', None, 0.2, 8.3, 26, 0, 121.51666356, 25.10334003, 11]
# ['淡水', '新北市', 33, None, '良好', 1.3, 0.26, 46.4, 37, 37, 14, 3.8, 4.8, 0.9, 2.7, 30, '2024-11-26 19:00', None, 0.3, 10, 25, 1, 121.449239, 25.1645, 10]
# ['林口', '新北市', 28, None, '良好', 1.1, 0.27, 38.8, 27.7, 36, 14, 9.2, 10.5, 1.3, 2.6, 53, '2024-11-26 19:00', None, 0.3, 8.7, 28, 0, 121.36548982, 25.07798949, 9]
# ['菜寮', '新北市', 36, None, '良好', 0.8, 0.37, 41.6, 32, 35, 16, 11.5, 12.1, 0.6, 3.5, 76, '2024-11-26 19:00', None, 0.3, 11.1, 22, 0, 121.481028, 25.06895, 8]
# ['新莊', '新北市', 38, None, '良好', 1.1, 0.32, 43.3, 30.5, 40, 13, 7.9, 8.4, 0.5, 4.6, 78, '2024-11-26 19:00', None, 0.3, 11.6, 31, 0, 121.4325, 25.037972, 7]
# ['板橋', '新北市', 30, None, '良好', 0.9, 0.45, 39, 30.7, 34, 12, 16.8, 18.1, 1.2, 2.6, 76, '2024-11-26 19:00', None, 0.4, 9.2, 26, 1, 121.458667, 25.012972, 6]
# ['土城', '新北市', 37, None, '良好', 1.2, 0.38, 38.9, 29.8, 34, 17, 13.2, 14, 0.8, 2, 157, '2024-11-26 19:00', None, 0.3, 11.5, 28, 1, 121.451861, 24.982528, 5]
# ['新店', '新北市', 47, None, '良好', 0.6, 0.36, 36.9, 26.6, 31, 20, 10.4, 11.4, 1, 2.3, 99, '2024-11-26 19:00', None, 0.3, 14.6, 23, 0, 121.537778, 24.977222, 4]
# ['萬里', '新北市', 78, '懸浮微粒', '普通', 0.2, 0.25, 54.5, 45.6, 94, 19, 2.7, 3.1, 0.3, 5.8, 44, '2024-11-26 19:00', None, 0.2, 15.3, 78, 0, 121.689881, 25.179667, 3]
# ['汐止', '新北市', 37, None, '良好', 2, 0.25, 40.7, 30.9, 33, 12, 10.3, 11.4, 1.1, 2.1, 24, '2024-11-26 19:00', None, 0.2, 11.4, 25, 0, 121.64081, 25.06624, 2]
# ['基隆', '基隆市', 37, None, '良好', 1, 0.26, 49.1, 40.1, 35, 11, 4.5, 4.9, 0.4, 2.4, 90, '2024-11-26 19:00', None, 0.2, 7.7, 29, 1, 121.760056, 25.129167, 1]
# ['屏東(枋山)', '屏東縣', 41, None, '良好', 0, 0.24, 39.7, 44.4, 21, 6, 2.7, 2.9, 0.2, 6.9, 88, '2024-11-26 19:00', None, 0.1, 9.2, 28, 0, 120.651472, 22.260899, 313]
# ['花蓮（美崙）', '花蓮縣', 34, None, '良好', 0, 0.34, 42.8, 37.5, 25, 12, 5.4, 6.8, 1.4, 4.7, 38, '2024-11-26 19:00', None, 0.3, 10.1, 25, 0, 121.61575076, 23.97709367, 312]
# ['新北(樹林)', '新北市', 38, None, '良好', 0.7, 0.43, 26.8, 21.1, 39, 14, 23.7, 32.2, 8.5, 0, 140, '2024-11-26 19:00', None, 0.4, 10.5, 27, 0, 121.38352778, 24.94902778, 311]
# ['屏東（琉球）', '屏東縣', 57, '細懸浮微粒', '普通', 1.4, 0.36, 48.3, 56.3, 55, 19, 9.7, 10.6, 0.9, 3.2, 315, '2024-11-26 19:00', None, 0.3, 18, 47, 2, 120.37722, 22.35222, 204]
# ['臺南（麻豆）', '臺南市', 79, '懸浮微粒', '普通', 1.4, 0.41, 22.2, 40.1, 105, 18, 14, 14.5, 0.4, 3.1, 9, '2024-11-26 19:00', None, 0.2, 14, 79, 1, 120.24583056, 23.17904722, 203]
# ['高雄（湖內）', '高雄市', 61, '懸浮微粒', '普通', 1.6, 0.4, 32.1, 43.3, 113, 12, 14, 13.9, 0, 1.4, 303, '2024-11-26 19:00', None, 0.3, 8.5, 61, 1, 120.24535, 22.87985556, 202]
# ['彰化（員林）', '彰化縣', 31, None, '良好', 1.3, 0.4, 22.7, 33.5, 26, 9, 13.7, 15.8, 2.1, 1.9, 352, '2024-11-26 19:00', None, 0.3, 8, 30, 1, 120.56373, 23.96117, 201]
# ['大城', '彰化縣', 39, None, '良好', 1.4, 0.25, 37.1, 42.1, 24, 14, 6, 7.1, 1, 9, 45, '2024-11-26 19:00', None, 0.2, 11, 30, 1, 120.26964167, 23.85493056, 85]
# ['富貴角', '新北市', 48, None, '良好', 0.3, 0.2, 54.8, 46.4, 54, 18, 1.8, 1.9, 0.1, 10.7, 51, '2024-11-26 19:00', None, 0.2, 13, 48, 0, 121.53656894, 25.29681695, 84]
# ['麥寮', '雲林縣', 70, '懸浮微粒', '普通', 1.2, 0.3, 34.5, 40.5, 62, 14, 7.3, 8.3, 1, 7.4, 3, '2024-11-26 19:00', None, 0.3, 11.7, 70, 1, 120.251825, 23.753506, 83]
# ['關山', '臺東縣', 39, None, '良好', 0.9, 0.33, 30.9, 33.2, 16, 6, 5.1, 5.4, 0.3, 2.6, 37, '2024-11-26 19:00', None, 0.2, 5.3, 39, 1, 121.161933, 23.045083, 80]
# ['馬公', '澎湖縣', 35, None, '良好', 1.1, 0.29, 41, 38.2, 16, 9, 3.4, 4.2, 0.8, 7.3, 39, '2024-11-26 19:00', None, 0.3, 5.2, 13, 1, 119.566158, 23.569031, 78]
# ['金門', '金門縣', 46, None, '良好', 0.8, 0.38, 37, 50.4, 22, 11, 6.8, 7.7, 0.8, 2.1, 86, '2024-11-26 19:00', None, 0.3, 8.4, 21, 0, 118.312256, 24.432133, 77]
# ['馬祖', '連江縣', 39, None, '良好', 0.6, 0.27, 53, 42.9, 34, 10, 4.3, 5.3, 0.9, 1, 330, '2024-11-26 19:00', None, 0.3, 9.6, 24, 0, 119.952724, 26.153736, 75]
# ['埔里', '南投縣', 47, None, '良好', 1.7, 0.4, 33.7, 36.2, 23, 15, 11.2, 12.4, 1.2, 0.5, 310, '2024-11-26 19:00', None, 0.2, 14.5, 17, 1, 120.967903, 23.968842, 72]
# ['復興', '高雄市', 56, '細懸浮微粒', '普通', 1.5, 0.58, 33.8, 43.1, 80, 19, 21.2, 23.1, 1.8, 2, 282, '2024-11-26 19:00', None, 0.4, 17.5, 54, 0, 120.312017, 22.608711, 71]
# ['永和', '新北市', 34, None, '良好', 1, 0.48, 36.7, 29.7, 39, 14, 15.4, 19, 3.6, 2.7, 73, '2024-11-26 19:00', None, 0.4, 10.4, 29, 1, 121.516306, 25.017, 70]
# ['竹山', '南投縣', 37, None, '良好', 0.8, 0.43, 19, 39.8, 33, 18, 17.1, 17.8, 0.6, 2, 23, '2024-11-26 19:00', None, 0.3, 11.4, 28, 0, 120.677306, 23.756389, 69]
# ['中壢', '桃園市', 47, None, '良好', 0.7, 0.8, 22.9, 16.2, 41, 14, 28, 49, 20.9, 1.2, 307, '2024-11-26 19:00', None, 0.7, 12, 27, 0, 121.221667, 24.953278, 68]
# ['三重', '新北市', 55, '二氧化氮', '普通', 0.8, 1.16, 15.5, 11, 42, 16, 36.7, 77.4, 40.7, '-', '-', '2024-11-26 19:00', None, 1, 13, 35, 0, 121.493806, 25.072611, 67]
# ['冬山', '宜蘭縣', 31, None, '良好', 0.6, 0.27, 39.2, 31.6, 37, 11, 8.6, 10.6, 1.9, 1.3, 343, '2024-11-26 19:00', None, 0.3, 8.7, 31, 0, 121.792928, 24.632203, 66]
# ['宜蘭', '宜蘭縣', 31, None, '良好', 0.9, 0.29, 37.2, 31.8, 22, 8, 4.4, 5.2, 0.8, 1.8, 298, '2024-11-26 19:00', None, 0.3, 9.5, 19, 1, 121.746394, 24.747917, 65]
# ['陽明', '臺北市', 37, None, '良好', 0.9, 0.25, 49.4, 40.3, 22, 9, 1.1, 2.2, 1.1, None, None, '2024-11-26 19:00', None, 0.2, 4, 13, 0, 121.529583, 25.182722, 64]
# ['花蓮', '花蓮縣', 32, None, '良好', 1.5, 0.28, 40.6, 35.5, 31, 7, 4.8, 5.4, 0.6, 3.6, 78, '2024-11-26 19:00', None, 0.3, 8, 30, 1, 121.599769, 23.971306, 63]
# ['臺東', '臺東縣', 35, None, '良好', 1, 0.42, 28.5, 38.3, 20, 6, 7.6, 9.5, 1.8, 1.4, 315, '2024-11-26 19:00', None, 0.3, 7.6, 23, 1, 121.15045, 22.755358, 62]
# ['恆春', '屏東縣', 37, None, '良好', 0.7, 0.3, None, 40.7, 17, 8, 2.7, 3.4, 0.7, 10.7, 33, '2024-11-26 19:00', None, 0.2, 8.7, 17, 0, 120.788928, 21.958069, 61]
# ['潮州', '屏東縣', 50, None, '良好', 1.1, 0.23, 37.3, 51.6, 21, 10, 4.4, 5.8, 1.3, 2.3, 185, '2024-11-26 19:00', None, 0.1, 15.4, 28, 0, 120.561175, 22.523108, 60]
# ['屏東', '屏東縣', 44, None, '良好', 1.5, 0.44, 38.8, 47.2, 54, 14, 14.8, 15.4, 0.6, 2.4, 280, '2024-11-26 19:00', None, 0.2, 12.1, 34, 1, 120.488033, 22.673081, 59]
# ['小港', '高雄市', 50, None, '良好', 1.5, 0.55, 32.3, 44.9, 79, 18, 27.1, 27.7, 0.6, 2.4, 303, '2024-11-26 19:00', None, 0.3, 14.1, 50, 1, 120.337736, 22.565833, 58]
# ['前鎮', '高雄市', 57, '懸浮微粒', '普通', 1.9, 0.62, 31.8, 44.5, 93, 18, 23.8, 26.7, 2.9, 3.4, 13, '2024-11-26 19:00', None, 0.3, 16.7, 57, 1, 120.30833356, 22.6044507, 57]
# ['前金', '高雄市', 65, '懸浮微粒', '普通', 1.3, 0.43, 38.1, 45.6, 101, 14, 17, 18, 1, 4.6, 354, '2024-11-26 19:00', None, 0.3, 13.8, 65, 0, 120.28676111, 22.63390278, 56]
# ['左營', '高雄市', 61, '懸浮微粒', '普通', 1.4, 0.45, 38.6, 47.6, 109, 18, 15.7, 16.4, 0.6, 2.5, 355, '2024-11-26 19:00', None, 0.3, 14.6, 61, 1, 120.292917, 22.674861, 54]
# ['楠梓', '高雄市', 65, '懸浮微粒', '普通', 1.3, 0.41, 38.3, 47.1, 137, 18, 15.2, 15.9, 0.7, 1.9, 335, '2024-11-26 19:00', None, 0.2, 13.7, 65, 1, 120.328289, 22.733667, 53]
# ['林園', '高雄市', 54, '細懸浮微粒', '普通', 2.6, 0.49, 27.6, 49.4, 67, 19, 29.2, 29.5, 0.2, 2.4, 306, '2024-11-26 19:00', None, 0.3, 16.9, 52, 1, 120.41175, 22.4795, 52]
# ['大寮', '高雄市', 51, '細懸浮微粒', '普通', 1.7, 0.44, 34.4, 43.5, 40, 20, 19.6, 20.2, 0.5, 2.2, 330, '2024-11-26 19:00', None, 0.2, 15.5, 29, 2, 120.425311, 22.56413611, 51]
# ['鳳山', '高雄市', 56, '細懸浮微粒', '普通', 1.4, 0.74, 31, 42.7, 88, 21, 22.6, 25.6, 3, 1.4, 256, '2024-11-26 19:00', None, 0.4, 17.7, 50, 1, 120.357422, 22.628126, 50]
# ['仁武', '高雄市', 51, '細懸浮微粒', '普通', 1, 0.45, 36.7, 45.1, 93, 22, 16.6, 17.8, 1.2, 3.5, 345, '2024-11-26 19:00', None, 0.3, 15.5, 45, 1, 120.332631, 22.689056, 49]
# ['橋頭', '高雄市', 64, '懸浮微粒', '普通', 1.6, 0.44, 36.3, 46.1, 147, 20, 16.9, 18.1, 1.2, 3.2, 3, '2024-11-26 19:00', None, 0.2, 13.4, 64, 1, 120.305689, 22.757506, 48]
# ['美濃', '高雄市', 42, None, '良好', 1.6, 0.36, 42.8, 45.1, 83, 16, 9.4, 10.4, 0.9, 1.5, 272, '2024-11-26 19:00', None, 0.2, 10.4, 38, 1, 120.530542, 22.883583, 47]
# ['臺南', '臺南市', 71, '懸浮微粒', '普通', 1.5, 0.43, 29.6, 44.5, 127, 20, 14.1, 14.7, 0.6, 4, 4, '2024-11-26 19:00', None, 0.3, 12.6, 71, 1, 120.21947897, 22.98928311, 46]
# ['安南', '臺南市', 74, '懸浮微粒', '普通', 1, 0.43, 29.7, 44.8, 118, 19, 11.5, 12, 0.4, 3.7, 320, '2024-11-26 19:00', None, 0.3, 14.8, 74, 0, 120.2175, 23.048197, 45]
# ['善化', '臺南市', 89, '懸浮微粒', '普通', 1.9, 0.4, 24.8, 44.4, 176, 13, 13.1, 14.1, 0.9, 4.1, 1, '2024-11-26 19:00', None, 0.2, 12.5, 89, 1, 120.29740529, 23.11337642, 44]
# ['新營', '臺南市', 105, '懸浮微粒', '對敏感族群不健康', 1.7, 0.44, 20.2, 39.9, 102, 15, 15.8, 16, 0.2, 3.8, 13, '2024-11-26 19:00', None, 0.3, 16.4, 114, 1, 120.31725, 23.305633, 43]
# ['嘉義', '嘉義市', 72, '懸浮微粒', '普通', 7.9, 0.54, 15.6, 40.1, 46, 16, 18.7, 20.2, 1.4, 2.6, 6, '2024-11-26 19:00', None, 0.3, 14.3, 72, 2, 120.44125148, 23.46477865, 42]
# ['臺西', '雲林縣', 37, None, '良好', 0.9, 0.29, 35.2, 40.8, 38, 6, 6.3, 6.7, 0.4, 8.8, 23, '2024-11-26 19:00', None, 0.3, 8.2, 35, 1, 120.19933333, 23.702175, 41]
# ['朴子', '嘉義縣', 75, '懸浮微粒', '普通', 2, 0.33, 25.9, 39.8, 58, 10, 11.2, 13.2, 1.9, 2.5, 354, '2024-11-26 19:00', None, 0.2, 9.8, 75, 1, 120.2478, 23.46538, 40]
# ['新港', '嘉義縣', 106, '懸浮微粒', '對敏感族群不健康', 2.2, 0.41, 21.2, 39.8, 75, 12, 14.4, 14.8, 0.3, 4.7, 9, '2024-11-26 19:00', None, 0.3, 15.5, 118, 1, 120.345531, 23.554839, 39]
# ['崙背', '雲林縣', 128, '懸浮微粒', '對敏感族群不健康', 2.7, 0.45, 20.1, 34.1, 157, 13, 16.6, 17.5, 0.9, 2.2, 353, '2024-11-26 19:00', None, 0.3, 17.6, 184, 1, 120.348742, 23.757547, 38]
# ['斗六', '雲林縣', 59, '懸浮微粒', '普通', 1.3, 0.42, 20, 40.5, 34, 12, 15.2, 16.1, 0.9, 1.8, 337, '2024-11-26 19:00', None, 0.3, 11.5, 59, 1, 120.544994, 23.711853, 37]
# ['南投', '南投縣', 32, None, '良好', 1.3, 0.45, 15.7, 34.9, 24, 12, 19.8, 21.6, 1.8, 1.2, 5, '2024-11-26 19:00', None, 0.3, 9.6, 28, 1, 120.685306, 23.913, 36]
# ['二林', '彰化縣', 42, None, '良好', 1.4, 0.35, 29, 37.1, 32, 10, 12.4, 13, 0.6, 4.9, 22, '2024-11-26 19:00', None, 0.3, 7.7, 42, 1, 120.409653, 23.925175, 35]
# ['線西', '彰化縣', 31, None, '良好', 1.1, 0.29, 30.9, 32.7, 22, 11, 11.7, 12.5, 0.7, 7.7, 31, '2024-11-26 19:00', None, 0.3, 9.5, 30, 1, 120.469061, 24.131672, 34]
# ['彰化', '彰化縣', 27, None, '良好', 0.5, 0.38, 25, 28.1, 21, 7, 13.7, 15.1, 1.4, 3.1, 20, '2024-11-26 19:00', None, 0.3, 8.2, 24, 0, 120.541519, 24.066, 33]
# ['西屯', '臺中市', 29, None, '良好', 0.8, 0.3, 30, 30.9, 19, 8, 8.9, 10.1, 1.2, 4.8, 0, '2024-11-26 19:00', None, 0.3, 7.7, 29, 0, 120.616917, 24.162197, 32]
# ['忠明', '臺中市', 26, None, '良好', 1.5, 0.43, 22.7, 29, 15, 11, 13.6, 15.2, 1.6, 2.3, 327, '2024-11-26 19:00', None, 0.3, 6.2, 21, 1, 120.641092, 24.151958, 31]
# ['大里', '臺中市', 29, None, '良好', 1.4, 0.47, 18.9, 31.5, 20, 13, 15, 16.7, 1.7, 3.5, 11, '2024-11-26 19:00', None, 0.4, 7.8, 19, 1, 120.67844444, 24.09961111, 30]
# ['沙鹿', '臺中市', 26, None, '良好', 0.9, 0.29, 10.9, 25.9, 27, 8, 7.6, 8.2, 0.6, 5.7, 30, '2024-11-26 19:00', None, 0.3, 7.9, 21, 0, 120.568794, 24.225628, 29]
# ['豐原', '臺中市', 30, None, '良好', 1.2, 0.37, 22.2, 32.3, 20, 16, 10.9, 11.5, 0.6, 2.2, 19, '2024-11-26 19:00', None, 0.3, 8, 16, 1, 120.74252414, 24.25699731, 28]
# ['三義', '苗栗縣', 28, None, '良好', 0.8, 0.26, 35.6, 30.6, 15, 11, 4.6, 5.7, 1, 7.4, 19, '2024-11-26 19:00', None, 0.3, 6.2, 12, 0, 120.75956754, 24.38248443, 27]
# ['苗栗', '苗栗縣', 28, None, '良好', 1.6, 0.28, 37.7, 30.2, 28, 11, 7.7, 8.8, 1.1, 5.2, 18, '2024-11-26 19:00', None, 0.3, 7.6, 19, 1, 120.82011468, 24.56499183, 26]
# ['頭份', '苗栗縣', 29, None, '良好', 1.7, 0.34, 35.1, 28.7, 28, 12, 12, 13.3, 1.3, 3.4, 44, '2024-11-26 19:00', None, 0.3, 9, 18, 1, 120.89869286, 24.69690679, 25]
# ['新竹', '新竹市', 25, None, '良好', 1.7, 0.35, 36.2, 27.9, 38, 10, 12.6, 13, 0.4, 3.4, 52, '2024-11-26 19:00', None, 0.3, 5.4, 22, 1, 120.97236752, 24.8056356, 24]
# ['竹東', '新竹縣', 30, None, '良好', 0.5, 0.24, 42.3, 32.4, 28, 7, 5.8, 6.3, 0.5, 5.1, 40, '2024-11-26 19:00', None, 0.2, 6, 17, 0, 121.08895493, 24.74091408, 23]
# ['湖口', '新竹縣', 29, None, '良好', 2.4, 0.26, 44.4, 32, 36, 8, 5.6, 6, 0.3, 6.8, 47, '2024-11-26 19:00', None, 0.3, 7.3, 23, 1, 121.03886894, 24.90009696, 22]
# ['龍潭', '桃園市', 28, None, '良好', 1.5, 0.28, 40.6, 30.6, 35, 12, 8, 8.9, 0.9, 6.3, 53, '2024-11-26 19:00', None, 0.3, 8.5, 24, 1, 121.21645772, 24.86400048, 21]
# ['平鎮', '桃園市', 30, None, '良好', 0.9, 0.45, 39.7, 27.1, 35, 13, 12.9, 14.6, 1.7, 2.6, 71, '2024-11-26 19:00', None, 0.4, 9.2, 23, 0, 121.203986, 24.952786, 20]
# ['觀音', '桃園市', 42, None, '良好', 1.2, 0.22, 45.8, 33.5, 56, 16, 6.5, 6.6, 0.1, 6.2, 89, '2024-11-26 19:00', None, 0.2, 12.4, 42, 0, 121.08283092, 25.03556747, 19]
# ['大園', '桃園市', 43, None, '良好', 2.1, 0.26, 41.9, 31.6, 46, 17, 11.9, 13.1, 1.1, 5.9, 61, '2024-11-26 19:00', None, 0.3, 13.3, 32, 1, 121.20251473, 25.06100357, 18]
# ['桃園', '桃園市', 27, None, '良好', 0.9, 0.39, 38.1, 26.4, 38, 12, 12.2, 13.9, 1.7, 3, 56, '2024-11-26 19:00', None, 0.4, 8.4, 26, 0, 121.30500531, 24.9947107, 17]
# ['大同', '臺北市', 47, None, '良好', 0.9, 0.73, 23.5, 19.1, 40, 18, 27.2, 47.8, 20.6, '-', '-', '2024-11-26 19:00', None, 0.6, 14.6, 29, 0, 121.51342074, 25.06331455, 16]
# ['松山', '臺北市', 43, None, '良好', 1.2, 0.33, 34.4, 28.5, 43, 18, 16.6, 19, 2.4, 2.2, 17, '2024-11-26 19:00', None, 0.3, 13.2, 34, 1, 121.578611, 25.05, 15]
# ['古亭', '臺北市', 37, None, '良好', 1.3, 0.38, 36.9, 29.1, 38, 12, 13.8, 14.5, 0.7, 1.1, 57, '2024-11-26 19:00', None, 0.3, 11.5, 28, 0, 121.529556, 25.020608, 14]
# ['萬華', '臺北市', 37, None, '良好', 1.6, 0.41, 27.6, 19.4, 38, 17, 22.1, 24.9, 2.8, 2.3, 95, '2024-11-26 19:00', None, 0.3, 10.7, 30, 1, 121.507972, 25.046503, 13]
# ['中山', '臺北市', 42, None, '良好', 0.9, 0.52, 29.4, 24.4, 41, 16, 22.2, 26.3, 4, 1.9, 61, '2024-11-26 19:00', None, 0.4, 12.9, 30, 0, 121.526528, 25.062361, 12]
# ['士林', '臺北市', 33, None, '良好', 0.9, 0.27, 45.3, 36.2, 39, 12, 7.4, 8.2, 0.7, 1.3, 60, '2024-11-26 19:00', None, 0.2, 8.3, 26, 0, 121.51666356, 25.10334003, 11]
# ['淡水', '新北市', 33, None, '良好', 1.3, 0.26, 46.4, 37, 37, 14, 3.8, 4.8, 0.9, None, None, '2024-11-26 19:00', None, 0.3, 10, 25, 1, 121.449239, 25.1645, 10]
# ['林口', '新北市', 28, None, '良好', 1.1, 0.27, 38.8, 27.7, 36, 14, 9.2, 10.5, 1.3, 2.6, 53, '2024-11-26 19:00', None, 0.3, 8.7, 28, 0, 121.36548982, 25.07798949, 9]
# ['菜寮', '新北市', 36, None, '良好', 0.8, 0.37, 41.6, 32, 35, 16, 11.5, 12.1, 0.6, 3.5, 76, '2024-11-26 19:00', None, 0.3, 11.1, 22, 0, 121.481028, 25.06895, 8]
# ['新莊', '新北市', 38, None, '良好', 1.1, 0.32, 43.3, 30.5, 40, 13, 7.9, 8.4, 0.5, 4.6, 78, '2024-11-26 19:00', None, 0.3, 11.6, 31, 0, 121.4325, 25.037972, 7]
# ['板橋', '新北市', 30, None, '良好', 0.9, 0.45, 39, 30.7, 34, 12, 16.8, 18.1, 1.2, 2.6, 76, '2024-11-26 19:00', None, 0.4, 9.2, 26, 1, 121.458667, 25.012972, 6]
# ['土城', '新北市', 37, None, '良好', 1.2, 0.38, 38.9, 29.8, 34, 17, 13.2, 14, 0.8, 2, 157, '2024-11-26 19:00', None, 0.3, 11.5, 28, 1, 121.451861, 24.982528, 5]
# ['新店', '新北市', 47, None, '良好', 0.6, 0.36, 36.9, 26.6, 31, 20, 10.4, 11.4, 1, 2.3, 99, '2024-11-26 19:00', None, 0.3, 14.6, 23, 0, 121.537778, 24.977222, 4]
# ['萬里', '新北市', 78, '懸浮微粒', '普通', 0.2, 0.25, 54.5, 45.6, 94, 19, 2.7, 3.1, 0.3, 5.8, 44, '2024-11-26 19:00', None, 0.2, 15.3, 78, 0, 121.689881, 25.179667, 3]
# ['汐止', '新北市', 37, None, '良好', 2, 0.25, 40.7, 30.9, 33, 12, 10.3, 11.4, 1.1, 2.1, 24, '2024-11-26 19:00', None, 0.2, 11.4, 25, 0, 121.64081, 25.06624, 2]
# ['基隆', '基隆市', 37, None, '良好', 1, 0.26, 49.1, 40.1, 35, 11, 4.5, 4.9, 0.4, 2.4, 90, '2024-11-26 19:00', None, 0.2, 7.7, 29, 1, 121.760056, 25.129167, 1]
# ['屏東(枋山)', '屏東縣', 40, None, '良好', 0, 0.23, 40.5, 43.7, 30, 9, 2.9, 3.3, 0.4, 6.6, 93, '2024-11-26 18:00', None, 0.1, 9.3, 28, 0, 120.651472, 22.260899, 313]
# ['花蓮（美崙）', '花蓮縣', 32, None, '良好', 0, 0.36, 40.9, 35.7, 29, 13, 5.6, 7.9, 2.3, 4.6, 39, '2024-11-26 18:00', None, 0.3, 9.2, 23, 0, 121.61575076, 23.97709367, 312]
# ['新北(樹林)', '新北市', 32, None, '良好', 0.7, 0.43, 26.4, 19.1, 38, 15, 19.5, 25.5, 6, 0.2, 155, '2024-11-26 18:00', None, 0.4, 9.7, 24, 0, 121.38352778, 24.94902778, 311]
# ['屏東（琉球）', '屏東縣', 59, '細懸浮微粒', '普通', 1.3, 0.35, 55.2, 55.1, 56, 15, 8.3, 9.5, 1.1, 3.7, 317, '2024-11-26 18:00', None, 0.2, 18.7, 46, 2, 120.37722, 22.35222, 204]
# ['臺南（麻豆）', '臺南市', 66, '懸浮微粒', '普通', 1.2, 0.36, 35.5, 41, 124, 19, 9.3, 9.7, 0.3, 2.9, 6, '2024-11-26 18:00', None, 0.2, 12.7, 66, 1, 120.24583056, 23.17904722, 203]
# ['高雄（湖內）', '高雄市', 53, '懸浮微粒', '普通', 1.5, 0.38, 41.5, 42.8, 79, 10, 12.6, 12.5, 0, 1.4, 7, '2024-11-26 18:00', None, 0.2, 8.8, 53, 1, 120.24535, 22.87985556, 202]
# ['彰化（員林）', '彰化縣', 31, None, '良好', 1.3, 0.48, 21.1, 33.8, 33, 9, 15, 18.3, 3.3, 1.2, 344, '2024-11-26 18:00', None, 0.3, 7.4, 29, 1, 120.56373, 23.96117, 201]
# ['大城', '彰化縣', 38, None, '良好', 1.4, 0.28, 35.5, 41.4, 27, 16, 6.1, 7.2, 1, 9.7, 41, '2024-11-26 18:00', None, 0.2, 9.4, 29, 1, 120.26964167, 23.85493056, 85]
# ['富貴角', '新北市', 46, None, '良好', 0.3, 0.2, 54.3, 43.3, 59, 14, 1.3, 1.4, 0.1, 8.9, 55, '2024-11-26 18:00', None, 0.2, 11.7, 46, 0, 121.53656894, 25.29681695, 84]
# ['麥寮', '雲林縣', 71, '懸浮微粒', '普通', 1.1, 0.34, 32.8, 39.9, 64, 12, 7.4, 8.9, 1.4, 8.1, 3, '2024-11-26 18:00', None, 0.3, 10.6, 71, 1, 120.251825, 23.753506, 83]
# ['關山', '臺東縣', 57, '懸浮微粒', '普通', 0.8, 0.34, 31.9, 32.4, 16, 5, 5.5, 5.9, 0.4, 2.8, 31, '2024-11-26 18:00', None, 0.2, 5.5, 57, 1, 121.161933, 23.045083, 80]
# ['馬公', '澎湖縣', 33, None, '良好', 1.2, 0.33, 39.7, 36.6, 18, 6, 3.5, 4.5, 0.9, 6.8, 29, '2024-11-26 18:00', None, 0.3, 4.4, 12, 1, 119.566158, 23.569031, 78]
# ['金門', '金門縣', 45, None, '良好', 0.8, 0.43, 41.7, 49.4, 22, 8, 6.4, 7.1, 0.6, 1.9, 93, '2024-11-26 18:00', None, 0.4, 8, 19, 0, 118.312256, 24.432133, 77]
# ['馬祖', '連江縣', 36, None, '良好', 0.5, 0.28, 51.7, 39.7, 33, 11, 4.7, 5.6, 0.9, 1.6, 310, '2024-11-26 18:00', None, 0.3, 9.3, 19, 0, 119.952724, 26.153736, 75]
# ['埔里', '南投縣', 46, None, '良好', 1.7, 0.44, 35.5, 35.6, 25, 20, 10.4, 11.8, 1.3, 0.3, 0, '2024-11-26 18:00', None, 0.2, 14.2, 16, 1, 120.967903, 23.968842, 72]
# ['復興', '高雄市', 56, '細懸浮微粒', '普通', 1.5, 0.67, 36, 42.6, 64, 18, 23.1, 25.4, 2.2, 1.9, 286, '2024-11-26 18:00', None, 0.4, 17.4, 47, 0, 120.312017, 22.608711, 71]
# ['永和', '新北市', 31, None, '良好', 1.1, 0.49, 36.2, 27.1, 44, 15, 14.8, 18.1, 3.2, 1.7, 77, '2024-11-26 18:00', None, 0.4, 9.5, 27, 1, 121.516306, 25.017, 70]
# ['竹山', '南投縣', 38, None, '良好', 0.9, 0.38, 25.8, 41.2, 28, 9, 15.5, 16, 0.5, 2.3, 31, '2024-11-26 18:00', None, 0.2, 10, 26, 0, 120.677306, 23.756389, 69]
# ['中壢', '桃園市', 43, None, '良好', 0.8, 0.94, 21.3, 14.3, 34, 16, 26.7, 45.6, 18.9, 1.5, 342, '2024-11-26 18:00', None, 0.6, 11.6, 24, 0, 121.221667, 24.953278, 68]
# ['三重', '新北市', 53, '二氧化氮', '普通', 0.7, 1.15, 16.1, 9.5, 47, 18, 34.6, 72.1, 37.5, '-', '-', '2024-11-26 18:00', None, 1, 11.7, 31, 0, 121.493806, 25.072611, 67]
# ['冬山', '宜蘭縣', 31, None, '良好', 0.6, 0.3, 36.5, 29.7, 40, 15, 9.5, 12.8, 3.3, 0.7, 324, '2024-11-26 18:00', None, 0.3, 7.6, 31, 0, 121.792928, 24.632203, 66]
# ['宜蘭', '宜蘭縣', 29, None, '良好', 1.1, 0.28, 38.2, 30, 25, 15, 5.5, 6.4, 0.8, 2.1, 334, '2024-11-26 18:00', None, 0.3, 9, 18, 1, 121.746394, 24.747917, 65]
# ['陽明', '臺北市', 34, None, '良好', 0.9, 0.25, 50, 37.4, 21, 5, 1.1, 1.8, 0.7, 2, 70, '2024-11-26 18:00', None, 0.3, 2.6, 11, 0, 121.529583, 25.182722, 64]
# ['花蓮', '花蓮縣', 31, None, '良好', 1.4, 0.3, 38.3, 34.8, 31, 9, 5.6, 6.1, 0.5, 3.9, 81, '2024-11-26 18:00', None, 0.3, 8.1, 29, 1, 121.599769, 23.971306, 63]
# ['臺東', '臺東縣', 35, None, '良好', 1, 0.39, 35.4, 38.1, 19, 7, 6, 7.4, 1.4, 1.6, 302, '2024-11-26 18:00', None, 0.2, 8, 25, 1, 121.15045, 22.755358, 62]
# ['恆春', '屏東縣', 36, None, '良好', 0.7, 0.29, None, 39.9, 16, 15, 2.7, 3.3, 0.5, 9.7, 30, '2024-11-26 18:00', None, 0.1, 8.6, 17, 0, 120.788928, 21.958069, 61]
# ['潮州', '屏東縣', 51, '細懸浮微粒', '普通', 1.3, 0.21, 52.1, 51.1, 32, 16, 7.5, 8.9, 1.4, 2.8, 190, '2024-11-26 18:00', None, 0.1, 15.6, 28, 0, 120.561175, 22.523108, 60]
# ['屏東', '屏東縣', 43, None, '良好', 1.2, 0.34, 44.9, 46.9, 30, 11, 11, 11.6, 0.6, 1.3, 304, '2024-11-26 18:00', None, 0.2, 11.4, 30, 1, 120.488033, 22.673081, 59]
# ['小港', '高雄市', 45, None, '良好', 1.9, 0.52, 35, 44.7, 67, 16, 27.2, 27.5, 0.3, 2.9, 296, '2024-11-26 18:00', None, 0.2, 13.8, 45, 1, 120.337736, 22.565833, 58]
# ['前鎮', '高雄市', 53, '細懸浮微粒', '普通', 2, 0.62, 36.8, 44.5, 65, 19, 25.3, 27.8, 2.5, 3.4, 21, '2024-11-26 18:00', None, 0.3, 16.5, 49, 1, 120.30833356, 22.6044507, 57]
# ['前金', '高雄市', 57, '懸浮微粒', '普通', 1.4, 0.46, 43, 44.7, 71, 15, 17.6, 18.7, 1.1, 4.2, 351, '2024-11-26 18:00', None, 0.2, 13.8, 57, 0, 120.28676111, 22.63390278, 56]
# ['左營', '高雄市', 50, None, '良好', 1.6, 0.47, 42.2, 47, 70, 15, 17.8, 18.5, 0.6, 2.8, 353, '2024-11-26 18:00', None, 0.2, 14.3, 50, 0, 120.292917, 22.674861, 54]
# ['楠梓', '高雄市', 50, None, '良好', 1.8, 0.41, 43.4, 46.4, 79, 15, 18, 18.7, 0.6, 2.5, 341, '2024-11-26 18:00', None, 0.2, 12.9, 50, 1, 120.328289, 22.733667, 53]
# ['林園', '高雄市', 55, '細懸浮微粒', '普通', 2.1, 0.39, 40.3, 50.5, 73, 19, 22.2, 24.1, 1.9, 1.5, 208, '2024-11-26 18:00', None, 0.2, 17.1, 47, 1, 120.41175, 22.4795, 52]
# ['大寮', '高雄市', 49, None, '良好', 1.2, 0.33, 39.5, 43, 24, 10, 17.5, 18.1, 0.6, 2.9, 346, '2024-11-26 18:00', None, 0.2, 15.1, 27, 2, 120.425311, 22.56413611, 51]
# ['鳳山', '高雄市', 57, '細懸浮微粒', '普通', None, None, 36.6, 42.4, 61, 20, None, None, None, 1.2, 251, '2024-11-26 18:00', None, 0.4, 17.8, 42, 1, 120.357422, 22.628126, 50]
# ['仁武', '高雄市', 48, None, '良好', 1.4, 0.46, 41.2, 44.2, 61, 20, 20.6, 21.8, 1.2, 3.8, 339, '2024-11-26 18:00', None, 0.2, 14.9, 34, 1, 120.332631, 22.689056, 49]
# ['橋頭', '高雄市', 45, None, '良好', 1.5, 0.41, 43.2, 45.6, 75, 15, 18.3, 19.6, 1.3, 3.7, 10, '2024-11-26 18:00', None, 0.2, 11.9, 45, 1, 120.305689, 22.757506, 48]
# ['美濃', '高雄市', 41, None, '良好', 1.3, 0.33, 46.2, 44.1, 41, 12, 8.4, 9.4, 0.9, 1.2, 262, '2024-11-26 18:00', None, 0.2, 8.9, 28, 0, 120.530542, 22.883583, 47]
# ['臺南', '臺南市', 55, '懸浮微粒', '普通', 1.5, 0.42, 41.9, 44.9, 92, 18, 12.2, 12.7, 0.5, 4.2, 7, '2024-11-26 18:00', None, 0.2, 10.6, 55, 1, 120.21947897, 22.98928311, 46]
# ['安南', '臺南市', 60, '懸浮微粒', '普通', 1, 0.43, 40.9, 45.1, 93, 15, 9.6, 10.1, 0.5, 3.4, 322, '2024-11-26 18:00', None, 0.3, 13.7, 60, 0, 120.2175, 23.048197, 45]
# ['善化', '臺南市', 64, '懸浮微粒', '普通', 1.6, 0.35, 39.5, 45.4, 153, 15, 9, 9.9, 0.9, 4.3, 354, '2024-11-26 18:00', None, 0.2, 11.5, 64, 1, 120.29740529, 23.11337642, 44]
# ['新營', '臺南市', 101, '懸浮微粒', '對敏感族群不健康', 1.9, 0.44, 28.6, 41.1, 258, 29, 15.2, 16.1, 0.8, 3.5, 17, '2024-11-26 18:00', None, 0.3, 16, 101, 1, 120.31725, 23.305633, 43]
# ['嘉義', '嘉義市', 69, '懸浮微粒', '普通', 3.4, 0.48, 25.7, 42, 61, 11, 16.3, 17.3, 1, 3.3, 8, '2024-11-26 18:00', None, 0.3, 12.9, 69, 2, 120.44125148, 23.46477865, 42]
# ['臺西', '雲林縣', 37, None, '良好', 1, 0.33, 34, 40.1, 33, 10, 6.4, 7, 0.5, 9.4, 23, '2024-11-26 18:00', None, 0.3, 8, 33, 1, 120.19933333, 23.702175, 41]
# ['朴子', '嘉義縣', 74, '懸浮微粒', '普通', 1.7, 0.37, 29.5, 40.3, 101, 11, 10.1, 12, 1.8, 2.4, 350, '2024-11-26 18:00', None, 0.2, 9.3, 74, 1, 120.2478, 23.46538, 40]
# ['新港', '嘉義縣', 105, '懸浮微粒', '對敏感族群不健康', 2.4, 0.38, 26.1, 41.3, 87, 19, 14, 13.9, 0, 3.9, 2, '2024-11-26 18:00', None, 0.2, 15, 113, 1, 120.345531, 23.554839, 39]
# ...
# ['斗六', '雲林縣', 33, None, '良好', 1.3, 0.28, 59.3, 36.6, 19, 8, 6, 7.2, 1.1, 4, 326, '2024-11-26 15:00', None, 0.2, 7.5, 32, 1, 120.544994, 23.711853, 37]
# ['南投', '南投縣', 30, None, '良好', 1.1, 0.31, 55.8, 32, 17, 7, 9.1, 10.7, 1.6, 3, 36, '2024-11-26 15:00', None, 0.3, 8.1, 19, 1, 120.685306, 23.913, 36]
# ['二林', '彰化縣', 32, None, '良好', 1.8, 0.36, 48.4, 35.2, 52, 8, 8.2, 9.8, 1.6, 6.4, 3, '2024-11-26 15:00', None, 0.2, 6.7, 30, 1, 120.409653, 23.925175, 35]
# ['線西', '彰化縣', 28, None, '良好', 3.1, 0.42, 41.7, 30.7, 47, 14, 9.9, 12.3, 2.4, 8.8, 26, '2024-11-26 15:00', None, 0.3, 6.5, 21, 1, 120.469061, 24.131672, 34]
# ['彰化', '彰化縣', 24, None, '良好', 0.5, 0.35, 37.8, 27, 40, 6, 10.9, 13.4, 2.5, 3.9, 14, '2024-11-26 15:00', None, 0.3, 6.5, 18, 0, 120.541519, 24.066, 33]
# ['西屯', '臺中市', 26, None, '良好', 1, 0.33, 40.4, 29, 27, 7, 9.5, 11.9, 2.4, 5.1, 9, '2024-11-26 15:00', None, 0.2, 5.8, 20, 1, 120.616917, 24.162197, 32]
# ['忠明', '臺中市', 26, None, '良好', 1.5, 0.36, 39.8, 28.1, 17, 5, 9.9, 13, 3, 3.8, 349, '2024-11-26 15:00', None, 0.3, 5.3, 14, 1, 120.641092, 24.151958, 31]
# ['大里', '臺中市', 28, None, '良好', 1.1, 0.36, 43.6, 30.8, 15, 4, 9.8, 12.6, 2.7, 3.5, 330, '2024-11-26 15:00', None, 0.2, 6.5, 14, 1, 120.67844444, 24.09961111, 30]
# ['沙鹿', '臺中市', 28, None, '良好', 1, 0.34, 40.3, 30.2, 39, 8, 7.3, 9.4, 2.1, 6.2, 358, '2024-11-26 15:00', None, 0.2, 6.1, 18, 1, 120.568794, 24.225628, 29]
# ['豐原', '臺中市', 30, None, '良好', 2.2, 0.34, 37.7, 32.1, 18, 3, 8.4, 10.5, 2.1, 3.6, 348, '2024-11-26 15:00', None, 0.2, 6.5, 10, 1, 120.74252414, 24.25699731, 28]
# ['三義', '苗栗縣', None, None, None, None, None, None, None, None, None, None, None, None, None, None, '2024-11-26 15:00', None, None, None, None, None, 120.75956754, 24.38248443, 27]
# ['苗栗', '苗栗縣', 21, None, '良好', 1.4, 0.36, 28.1, 23.4, 20, 4, 9.1, 11.1, 2, 4.3, 15, '2024-11-26 15:00', None, 0.3, 4.5, 14, 1, 120.82011468, 24.56499183, 26]
# ['頭份', '苗栗縣', 21, None, '良好', 2, 0.38, 26.5, 22.2, 18, 10, 9.9, 13.7, 3.8, 3.6, 30, '2024-11-26 15:00', None, 0.3, 6.4, 11, 1, 120.89869286, 24.69690679, 25]
# ['新竹', '新竹市', 19, None, '良好', 1.9, 0.38, 25, 21.5, 18, 4, 11.1, 13.4, 2.3, 3.9, 42, '2024-11-26 15:00', None, 0.3, 3.5, 9, 1, 120.97236752, 24.8056356, 24]
# ['竹東', '新竹縣', 21, None, '良好', 0.2, 0.34, 31.7, 23.4, 8, 6, 6.4, 7.7, 1.3, 6.5, 29, '2024-11-26 15:00', None, 0.3, 4.5, 9, 0, 121.08895493, 24.74091408, 23]
# ['湖口', '新竹縣', 21, None, '良好', 2.4, 0.35, 28.2, 23, 16, 7, 8, 9.2, 1.1, 6.6, 43, '2024-11-26 15:00', None, 0.3, 5.7, 11, 1, 121.03886894, 24.90009696, 22]
# ['龍潭', '桃園市', 19, None, '良好', 1.1, 0.36, 27.7, 21.7, 23, 6, 8.4, 10.4, 2, 6.4, 54, '2024-11-26 15:00', None, 0.3, 6, 13, 1, 121.21645772, 24.86400048, 21]
# ['平鎮', '桃園市', 23, None, '良好', 1, 0.37, 24.3, 17.9, 17, 6, 14, 16.5, 2.5, 3.3, 52, '2024-11-26 15:00', None, 0.4, 5.8, 10, 0, 121.203986, 24.952786, 20]
# ['觀音', '桃園市', 29, None, '良好', 1.4, 0.28, 27.5, 22.9, 37, 10, 11.6, 12.8, 1.2, 6.7, 75, '2024-11-26 15:00', None, 0.2, 9, 22, 0, 121.08283092, 25.03556747, 19]
# ['大園', '桃園市', 26, None, '良好', 1.9, 0.32, 29.9, 21.8, None, 10, 11.5, 14.1, 2.6, 5.9, 45, '2024-11-26 15:00', None, 0.3, 8.1, 12, 1, 121.20251473, 25.06100357, 18]
# ['桃園', '桃園市', 19, None, '良好', 1, 0.4, 25.2, 20.5, 22, None, 11.5, 14.4, 2.8, 3.6, 35, '2024-11-26 15:00', None, 0.3, 3.5, 12, 1, 121.30500531, 24.9947107, 17]
# ['大同', '臺北市', 33, None, '良好', 0.7, 0.55, 21.5, 12.1, 28, 8, 20, 35.6, 15.6, '-', '-', '2024-11-26 15:00', None, 0.8, 9.2, 16, 0, 121.51342074, 25.06331455, 16]
# ['松山', '臺北市', 27, None, '良好', 1.1, 0.3, 30.2, 20.7, 33, 13, 9.7, 11.9, 2.2, 2.5, 15, '2024-11-26 15:00', None, 0.3, 8.4, 21, 1, 121.578611, 25.05, 15]
# ['古亭', '臺北市', 25, None, '良好', 0.9, 0.35, 29.1, 20.9, 24, 8, 9.9, 11.7, 1.7, 2.3, 57, '2024-11-26 15:00', None, 0.3, 7.6, 15, 1, 121.529556, 25.020608, 14]
# ['萬華', '臺北市', 23, None, '良好', 1.6, 0.38, 18.6, 13.2, 29, 11, 14.6, 18.9, 4.3, 2.6, 66, '2024-11-26 15:00', None, 0.4, 6.2, 16, 1, 121.507972, 25.046503, 13]
# ['中山', '臺北市', 27, None, '良好', 0.7, 0.4, 26.6, 15.7, 20, 10, 13.3, 17.7, 4.4, 2.3, 66, '2024-11-26 15:00', None, 0.5, 8.2, 16, 0, 121.526528, 25.062361, 12]
# ['士林', '臺北市', 23, None, '良好', 1.4, 0.28, 37, 25.6, 18, 7, 5.4, 6.5, 1.1, 1.5, 76, '2024-11-26 15:00', None, 0.3, 5.1, 13, 0, 121.51666356, 25.10334003, 11]
# ['淡水', '新北市', 24, None, '良好', 1.1, 0.29, 35.5, 26, 21, 7, 3.9, 5.2, 1.3, None, None, '2024-11-26 15:00', None, 0.3, 6.5, 13, 1, 121.449239, 25.1645, 10]
# ['林口', '新北市', 19, None, '良好', 0.9, 0.29, 25.7, 21.2, 27, 6, 10.6, 13.9, 3.3, 4.1, 47, '2024-11-26 15:00', None, 0.3, 4, 13, 0, 121.36548982, 25.07798949, 9]
# ['菜寮', '新北市', 19, None, '良好', 0.8, 0.37, 30.5, 20, 13, 6, 9.7, 11.2, 1.5, 2.9, 67, '2024-11-26 15:00', None, 0.4, 6, 11, 1, 121.481028, 25.06895, 8]
# ['新莊', '新北市', 23, None, '良好', 0.9, 0.33, 31.1, 20, 19, 12, 7.9, 9.4, 1.5, 5.2, 68, '2024-11-26 15:00', None, 0.3, 7.1, 17, 1, 121.4325, 25.037972, 7]
# ['板橋', '新北市', 19, None, '良好', 0.9, 0.38, 32.2, 21, 20, 6, 10.5, 12.3, 1.8, 2.9, 65, '2024-11-26 15:00', None, 0.4, 4.2, 12, 1, 121.458667, 25.012972, 6]
# ['土城', '新北市', 26, None, '良好', 0.8, 0.38, 30.3, 23, 27, 12, 10.8, 12.3, 1.5, 2.3, 175, '2024-11-26 15:00', None, 0.3, 8.1, 18, 1, 121.451861, 24.982528, 5]
# ['新店', '新北市', 33, None, '良好', None, None, 21, 19.2, 28, None, None, None, None, 2.3, 68, '2024-11-26 15:00', None, 0.3, 10.3, 16, 0, 121.537778, 24.977222, 4]
# ['萬里', '新北市', 55, '懸浮微粒', '普通', 0.1, 0.26, 45, 33.1, 76, 15, 3.2, 3.9, 0.7, 5.9, 49, '2024-11-26 15:00', None, 0.3, 11, 55, 0, 121.689881, 25.179667, 3]
# ['汐止', '新北市', 23, None, '良好', 0.6, 0.27, 29.3, 21.4, 21, None, 9.7, 11.6, 1.9, 1.9, 39, '2024-11-26 15:00', None, 0.3, 7.2, 14, 0, 121.64081, 25.06624, 2]
# ['基隆', '基隆市', 26, None, '良好', 1.2, 0.27, 40, 28.3, 31, None, 4.1, 4.6, 0.4, 2.4, 93, '2024-11-26 15:00', None, 0.3, 3.4, 18, 1, 121.760056, 25.129167, 1]
# ['屏東(枋山)', '屏東縣', 35, None, '良好', 0.5, 0.12, 46.3, 36.5, 27, 5, 2.3, 2.8, 0.5, 4.3, 99, '2024-11-26 14:00', None, 0.1, 10.7, 30, 0, 120.651472, 22.260899, 313]
# ['花蓮（美崙）', '花蓮縣', 27, None, '良好', 0.2, 0.39, 35.2, 24.1, 21, 8, 4.9, 6.9, 2, 4.6, 52, '2024-11-26 14:00', None, 0.3, 8.2, 21, 0, 121.61575076, 23.97709367, 312]
# ['新北(樹林)', '新北市', 22, None, '良好', 0.1, 0.45, 20.6, 14, 18, 3, 13.8, 20.4, 6.5, 0.2, 175, '2024-11-26 14:00', None, 0.3, 5.1, 12, 0, 121.38352778, 24.94902778, 311]
# ['屏東（琉球）', '屏東縣', 68, '細懸浮微粒', '普通', 2.2, 0.3, 59.2, 35.8, 44, 17, 10, 11.9, 1.8, 3, 326, '2024-11-26 14:00', None, 0.4, 22.5, 43, 2, 120.37722, 22.35222, 204]
# ['臺南（麻豆）', '臺南市', 40, None, '良好', 1.3, 0.22, 43.3, 29.1, 50, 11, 6.1, 7.3, 1.2, 3, 359, '2024-11-26 14:00', None, 0.1, 8.9, 40, 0, 120.24583056, 23.17904722, 203]
# ['高雄（湖內）', '高雄市', 39, None, '良好', 1.2, 0.29, 47, 29.4, 64, 9, 6.5, 7.1, 0.6, 1.6, 6, '2024-11-26 14:00', None, 0.2, 8.8, 39, 1, 120.24535, 22.87985556, 202]
# ['彰化（員林）', '彰化縣', 25, None, '良好', 1.4, 0.37, 45.3, 27.2, 13, 2, 7.3, 10, 2.7, 1.6, 332, '2024-11-26 14:00', None, 0.2, 4.7, 19, 1, 120.56373, 23.96117, 201]
# ['大城', '彰化縣', 36, None, '良好', 1.6, 0.28, 46.2, 34.2, 41, 6, None, None, None, 8.4, 33, '2024-11-26 14:00', None, 0.2, 5.2, 36, 1, 120.26964167, 23.85493056, 85]
# ['富貴角', '新北市', 32, None, '良好', 0.1, 0.27, 40.8, 32.3, 45, 11, 2.2, 2.4, 0.1, 9.3, 46, '2024-11-26 14:00', None, 0.2, 6.7, 32, 0, 121.53656894, 25.29681695, 84]
# ['麥寮', '雲林縣', 36, None, '良好', 1.7, 0.33, 43.4, 32.1, 63, 10, 7, 9.5, 2.5, 7.1, 359, '2024-11-26 14:00', None, 0.2, 8.3, 36, 1, 120.251825, 23.753506, 83]
# ['關山', '臺東縣', 51, '懸浮微粒', '普通', 0.9, 0.22, 35.3, 21.1, 193, 9, 3.3, 3.9, 0.5, 4.9, 31, '2024-11-26 14:00', None, 0.1, 4.7, 51, 1, 121.161933, 23.045083, 80]
# ['馬公', '澎湖縣', 29, None, '良好', 1.2, 0.29, 40, 31.2, 14, 4, 3.7, 4.8, 1.1, 6.9, 35, '2024-11-26 14:00', None, 0.2, 2.6, 9, 1, 119.566158, 23.569031, 78]
# ['金門', '金門縣', 27, None, '良好', 1, 0.37, 58.4, 29.5, 13, 9, 5.8, 6.8, 1, 2, 32, '2024-11-26 14:00', None, 0.3, 8, 19, 0, 118.312256, 24.432133, 77]
# ['馬祖', '連江縣', 27, None, '良好', 0.4, 0.31, 37.5, 29.2, 10, 9, 3.7, 5.1, 1.3, 2.5, 310, '2024-11-26 14:00', None, 0.4, 7.5, 13, 0, 119.952724, 26.153736, 75]
# ['埔里', '南投縣', 53, '細懸浮微粒', '普通', 1.3, 0.18, 37.9, 23.4, 13, 14, 1.3, 2.9, 1.5, 1.4, 304, '2024-11-26 14:00', None, 0.2, 16.4, 18, 1, 120.967903, 23.968842, 72]
# ['復興', '高雄市', 59, '細懸浮微粒', '普通', 1, 0.29, 48.8, 29.8, 34, 12, 10.2, 12.8, 2.6, 2.2, 286, '2024-11-26 14:00', None, 0.3, 18.6, 41, 0, 120.312017, 22.608711, 71]
# ['永和', '新北市', 20, None, '良好', 0.9, 0.48, 25.3, 16.5, 21, 9, 10.4, 15.2, 4.7, 3.3, 81, '2024-11-26 14:00', None, 0.7, 6.2, 13, 1, 121.516306, 25.017, 70]
# ['竹山', '南投縣', 39, None, '良好', 0.7, 0.33, 49.8, 26.3, None, None, 4.5, 5.1, 0.5, 1.2, 292, '2024-11-26 14:00', None, 0.2, 12.1, 21, 1, 120.677306, 23.756389, 69]
# ['中壢', '桃園市', 43, None, '良好', 0.9, 0.81, 11.7, 9.7, 20, 9, 26.6, 62.3, 35.6, 1.2, 283, '2024-11-26 14:00', None, 0.6, 9.5, 15, 1, 121.221667, 24.953278, 68]
# ['三重', '新北市', 42, None, '良好', 0.8, 0.99, 9.7, 6.2, 24, 14, 25.6, 75.4, 49.7, '-', '-', '2024-11-26 14:00', None, 1, 9, 17, 0, 121.493806, 25.072611, 67]
# ['冬山', '宜蘭縣', 17, None, '良好', 0.4, 0.35, 28, 18.3, 24, 5, 7, 10.2, 3.2, 3.4, 30, '2024-11-26 14:00', None, 0.3, 3.7, 16, 0, 121.792928, 24.632203, 66]
# ['宜蘭', '宜蘭縣', 20, None, '良好', 1.1, 0.38, None, 22.3, 9, 5, 6.7, 8.6, 1.9, 2.9, 78, '2024-11-26 14:00', None, 0.3, 5.1, 8, 0, 121.746394, 24.747917, 65]
# ['陽明', '臺北市', 27, None, '良好', 0.7, 0.34, 33.7, 29.1, 8, 0, 2, 3, 0.9, 2, 60, '2024-11-26 14:00', None, 0.3, 1.2, 4, 0, 121.529583, 25.182722, 64]
# ['花蓮', '花蓮縣', 27, None, '良好', 1.2, 0.33, 33.1, 20.8, 26, 7, 4.6, 5.3, 0.7, 5.2, 83, '2024-11-26 14:00', None, 0.2, 7, 27, 1, 121.599769, 23.971306, 63]
# ['臺東', '臺東縣', 28, None, '良好', 1.2, 0.27, 42, 27.4, 45, 9, 3.8, 5.8, 1.9, 5.3, 18, '2024-11-26 14:00', None, 0.1, 6.9, 28, 1, 121.15045, 22.755358, 62]
# ['恆春', '屏東縣', 31, None, '良好', None, None, None, 33, 19, 9, None, None, None, 8.5, 26, '2024-11-26 14:00', None, 0.1, 6, 14, 0, 120.788928, 21.958069, 61]
# ['潮州', '屏東縣', 54, '細懸浮微粒', '普通', 1.1, 0.17, 54.2, 29.6, 20, 10, 3.2, 4.5, 1.3, 1.5, 281, '2024-11-26 14:00', None, 0.2, 16.6, 29, 0, 120.561175, 22.523108, 60]
# ['屏東', '屏東縣', 53, '細懸浮微粒', '普通', 1.3, 0.18, 49.6, 32.7, 22, 11, 5.5, 6.3, 0.8, 1.8, 347, '2024-11-26 14:00', None, 0.2, 16.5, 30, 1, 120.488033, 22.673081, 59]
# ['小港', '高雄市', 49, None, '良好', 1.3, 0.23, 50.7, 30.9, 41, 10, 12.7, 15, 2.2, 3.5, 304, '2024-11-26 14:00', None, 0.2, 15.2, 36, 1, 120.337736, 22.565833, 58]
# ['前鎮', '高雄市', 58, '細懸浮微粒', '普通', 1.6, 0.27, 50.5, 31.8, 43, 15, 9.5, 11.7, 2.1, 3.2, 359, '2024-11-26 14:00', None, 0.2, 18.3, 43, 1, 120.30833356, 22.6044507, 57]
# ['前金', '高雄市', 54, '細懸浮微粒', '普通', 1.1, 0.26, 48.2, 31.9, 47, 16, 11, 13.6, 2.6, 4.1, 356, '2024-11-26 14:00', None, 0.2, 16.6, 52, 0, 120.28676111, 22.63390278, 56]
# ['左營', '高雄市', 55, '細懸浮微粒', '普通', 1.3, 0.25, 52.6, 33.6, 41, 19, 6.3, 7.5, 1.2, 4, 359, '2024-11-26 14:00', None, 0.2, 17, 43, 0, 120.292917, 22.674861, 54]
# ['楠梓', '高雄市', 48, None, '良好', 1.4, 0.22, 51.9, 32.4, 41, 14, 8.8, 9.9, 1.1, 2.6, 25, '2024-11-26 14:00', None, 0.2, 14.8, 46, 1, 120.328289, 22.733667, 53]
# ['林園', '高雄市', 62, '細懸浮微粒', '普通', 2, 0.29, 50.6, 34.3, 29, 11, 8.8, 9.7, 0.8, 2.1, 1, '2024-11-26 14:00', None, 0.2, 20.1, 40, 1, 120.41175, 22.4795, 52]
# ['大寮', '高雄市', 57, '細懸浮微粒', '普通', 1, 0.2, 48.9, 30.9, 20, 13, 8.7, 9.9, 1.2, 1.7, 359, '2024-11-26 14:00', None, 0.2, 17.8, 24, 2, 120.425311, 22.56413611, 51]
# ['鳳山', '高雄市', 59, '細懸浮微粒', '普通', 0.7, 0.37, 45.4, 28.8, 43, 14, 12.1, 15, 2.8, 1.5, 269, '2024-11-26 14:00', None, 0.4, 18.9, 41, 1, 120.357422, 22.628126, 50]
# ['仁武', '高雄市', 59, '細懸浮微粒', '普通', 1.2, 0.25, 49.3, 29.4, 29, 15, 8.9, 11.1, 2.2, 3.2, 345, '2024-11-26 14:00', None, 0.2, 18.6, 36, 1, 120.332631, 22.689056, 49]
# ['橋頭', '高雄市', 52, '細懸浮微粒', '普通', 1.4, 0.22, 50.1, 32.2, 31, 11, 8.7, 10.3, 1.6, 2.9, 10, '2024-11-26 14:00', None, 0.2, 16, 40, 1, 120.305689, 22.757506, 48]
# ['美濃', '高雄市', 33, None, '良好', 1.1, 0.2, 46, 29.9, 19, 7, 3.9, 5, 1.1, 1.5, 293, '2024-11-26 14:00', None, 0.2, 10.1, 23, 1, 120.530542, 22.883583, 47]
# ['臺南', '臺南市', 35, None, '良好', 1.3, 0.24, 48.6, 32, 39, 11, 7.1, 7.8, 0.6, 2.8, 15, '2024-11-26 14:00', None, 0.2, 8.8, 35, 0, 120.21947897, 22.98928311, 46]
# ['安南', '臺南市', 43, None, '良好', 1.1, 0.26, 48.4, 32.4, 44, 10, 5.9, 7.3, 1.3, 3.6, 328, '2024-11-26 14:00', None, 0.2, 12.5, 43, 0, 120.2175, 23.048197, 45]
# ['善化', '臺南市', 40, None, '良好', 1.4, 0.19, 49.6, 32.7, 39, 7, 3.9, 5.1, 1.2, 5.2, 8, '2024-11-26 14:00', None, 0.1, 9.2, 40, 1, 120.29740529, 23.11337642, 44]
# ['新營', '臺南市', 45, None, '良好', 1.2, 0.25, 46.8, 30.3, 49, 13, 6.7, 8.2, 1.4, 3.4, 25, '2024-11-26 14:00', None, 0.2, 10.5, 45, 1, 120.31725, 23.305633, 43]
# ['嘉義', '嘉義市', 36, None, '良好', 1.1, 0.24, 51.1, 30.9, 33, 8, 4.4, 5.5, 1.1, 2.5, 13, '2024-11-26 14:00', None, 0.2, 11.1, 35, 2, 120.44125148, 23.46477865, 42]
# ['臺西', '雲林縣', 34, None, '良好', 1.6, 0.32, 42.7, 31.8, 37, 6, 7.3, 9, 1.6, 6.8, 19, '2024-11-26 14:00', None, 0.2, 5.2, 34, 1, 120.19933333, 23.702175, 41]
# ['朴子', '嘉義縣', 50, None, '良好', 1.4, 0.23, 46.7, 31.2, 38, 10, 4.6, 7, 2.4, 2.8, 345, '2024-11-26 14:00', None, 0.2, 7.3, 50, 1, 120.2478, 23.46538, 40]
# ['新港', '嘉義縣', 34, None, '良好', 1.8, 0.22, 49, 32.6, 26, 14, 6.1, 7.1, 0.9, 3.5, 7, '2024-11-26 14:00', None, 0.1, 8.9, 34, 1, 120.345531, 23.554839, 39]
# ['崙背', '雲林縣', 63, '懸浮微粒', '普通', 1.1, 0.31, 46.4, 28, 33, 8, 5.1, 6.4, 1.2, 2.5, 323, '2024-11-26 14:00', None, 0.2, 9.8, 63, 1, 120.348742, 23.757547, 38]
# ['斗六', '雲林縣', 41, None, '良好', 1.2, 0.24, 52.3, 31.3, 16, 5, 4.6, 5.6, 0.9, 1.5, 10, '2024-11-26 14:00', None, 0.2, 8.1, 41, 1, 120.544994, 23.711853, 37]
# ['南投', '南投縣', 27, None, '良好', 1.2, 0.28, 48.3, 26.4, 9, 4, 7.5, 9.4, 1.8, 1.6, 221, '2024-11-26 14:00', None, 0.3, 8.3, 19, 1, 120.685306, 23.913, 36]
# ['二林', '彰化縣', 29, None, '良好', 1, 0.34, 49.4, 31.5, 24, 6, 6.1, 7.5, 1.4, 4.9, 352, '2024-11-26 14:00', None, 0.2, 6.2, 26, 1, 120.409653, 23.925175, 35]
# ['線西', '彰化縣', 26, None, '良好', 1.9, 0.36, 39.8, 28.8, 22, 3, 8.6, 11, 2.4, 7.4, 14, '2024-11-26 14:00', None, 0.2, 5, 17, 1, 120.469061, 24.131672, 34]
# ['彰化', '彰化縣', 22, None, '良好', 0.4, 0.34, 30.1, 24.6, None, None, None, None, None, 2.7, 5, '2024-11-26 14:00', None, 0.3, 6.8, 13, 0, 120.541519, 24.066, 33]
# ['西屯', '臺中市', 24, None, '良好', 1, 0.3, 38.6, 27, 15, 4, 8.1, 10.7, 2.6, 4.4, 352, '2024-11-26 14:00', None, 0.2, 6.1, 22, 1, 120.616917, 24.162197, 32]
# ['忠明', '臺中市', 23, None, '良好', 1.2, 0.36, 37.2, 25.9, 10, 4, 10.1, 13.7, 3.5, 2.2, 283, '2024-11-26 14:00', None, 0.2, 5.9, 14, 1, 120.641092, 24.151958, 31]
# ['大里', '臺中市', 25, None, '良好', 1.3, 0.36, 40.6, 27.2, 9, 4, 9.4, 12.6, 3.2, 3.1, 297, '2024-11-26 14:00', None, 0.2, 7.7, 15, 1, 120.67844444, 24.09961111, 30]
# ['沙鹿', '臺中市', 25, None, '良好', 0.9, 0.32, 40.6, 27.7, 9, 6, 6.5, 8.6, 2.1, 5.2, 338, '2024-11-26 14:00', None, 0.2, 5.7, 15, 1, 120.568794, 24.225628, 29]
# ['豐原', '臺中市', 28, None, '良好', 1, 0.3, 40.2, 30.6, 8, 4, 5.1, 6.3, 1.2, 3.8, 330, '2024-11-26 14:00', None, 0.2, 7.4, 9, 1, 120.74252414, 24.25699731, 28]
# ['三義', '苗栗縣', 23, None, '良好', 0.8, 0.31, 33.8, 25.2, 9, 2, 4.3, 6.6, 2.3, 6.2, 12, '2024-11-26 14:00', None, 0.2, 3.9, 8, 0, 120.75956754, 24.38248443, 27]
# ['苗栗', '苗栗縣', 19, None, '良好', 1.2, 0.32, 32.2, 21.4, 9, 3, 6, 8.3, 2.3, 5, 6, '2024-11-26 14:00', None, 0.2, 4.9, 12, 1, 120.82011468, 24.56499183, 26]
# ['頭份', '苗栗縣', 19, None, '良好', 1.8, 0.36, 28.8, 21.5, 6, 6, 6.9, 10.6, 3.6, 4.6, 10, '2024-11-26 14:00', None, 0.3, 5.8, 10, 1, 120.89869286, 24.69690679, 25]
# ['新竹', '新竹市', 19, None, '良好', 1.4, 0.39, 24.7, 21.8, 4, 4, 9.7, 12.8, 3.1, 4.4, 28, '2024-11-26 14:00', None, 0.3, 3.3, 8, 1, 120.97236752, 24.8056356, 24]
# ['竹東', '新竹縣', 19, None, '良好', 0.3, 0.32, 31.4, 21.2, 7, 0, 5, 6.7, 1.7, 3.1, 19, '2024-11-26 14:00', None, 0.2, 4.4, 9, 0, 121.08895493, 24.74091408, 23]
# ['湖口', '新竹縣', 21, None, '良好', 2.5, 0.38, 22.8, 23, 8, 5, 8.9, 10.9, 2, 6, 37, '2024-11-26 14:00', None, 0.3, 5.2, 9, 1, 121.03886894, 24.90009696, 22]
# ['龍潭', '桃園市', 20, None, '良好', 1, 0.34, 30.6, 20.9, 14, 4, 5.9, 8.2, 2.3, 6.4, 57, '2024-11-26 14:00', None, 0.3, 6.3, 11, 1, 121.21645772, 24.86400048, 21]

# %%
from pprint import pprint
sheet:worksheet = wb.worksheets[0]
type(sheet)
sheets:list = []
column_names:list[str] =[cell.value for cell in list(sheet)[0]]
print(column_names)

for row in list(sheet)[1:]:
    site:dict = {}
    for idx,cell in enumerate(row):        
        #print(column_names[idx], item.value)
        #print(idx,cell)
        site[column_names[idx]] = cell.value
    #print("===========")
    sheets.append(site)
#print(len(sheets))
pprint(sheets)
# Out:
# ['sitename', 'county', 'aqi', 'pollutant', 'status', 'so2', 'co', 'o3', 'o3_8hr', 'pm10', 'pm2.5', 'no2', 'nox', 'no', 'windspeed', 'winddirec', 'datacreationdate', 'unit', 'co_8hr', 'pm2.5_avg', 'pm10_avg', 'so2_avg', 'longitude', 'latitude', 'siteid']
# [{'aqi': 40,
#   'co': 0.24,
#   'co_8hr': 0.1,
#   'county': '屏東縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.260899,
#   'longitude': 120.651472,
#   'no': 0.2,
#   'no2': 2.4,
#   'nox': 2.6,
#   'o3': 39.4,
#   'o3_8hr': 43.6,
#   'pm10': 17,
#   'pm10_avg': 27,
#   'pm2.5': 6,
#   'pm2.5_avg': 8.7,
#   'pollutant': None,
#   'siteid': 313,
#   'sitename': '屏東(枋山)',
#   'so2': 0,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 90,
#   'windspeed': 5.7},
#  {'aqi': 36,
#   'co': 0.33,
#   'co_8hr': 0.3,
#   'county': '花蓮縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.97709367,
#   'longitude': 121.61575076,
#   'no': 0.8,
#   'no2': 3.8,
#   'nox': 4.6,
#   'o3': 47.7,
#   'o3_8hr': 39.3,
#   'pm10': 26,
#   'pm10_avg': 25,
#   'pm2.5': 12,
#   'pm2.5_avg': 10.8,
#   'pollutant': None,
#   'siteid': 312,
#   'sitename': '花蓮（美崙）',
#   'so2': 0,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 33,
#   'windspeed': 5},
#  {'aqi': 37,
#   'co': 0.41,
#   'co_8hr': 0.4,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.94902778,
#   'longitude': 121.38352778,
#   'no': 4.9,
#   'no2': 19.7,
#   'nox': 24.6,
#   'o3': 29.1,
#   'o3_8hr': 23.6,
#   'pm10': 40,
#   'pm10_avg': 30,
#   'pm2.5': 16,
#   'pm2.5_avg': 11.4,
#   'pollutant': None,
#   'siteid': 311,
#   'sitename': '新北(樹林)',
#   'so2': 0.3,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 141,
#   'windspeed': 0},
#  {'aqi': 57,
#   'co': 0.4,
#   'co_8hr': 0.3,
#   'county': '屏東縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.35222,
#   'longitude': 120.37722,
#   'no': 0.8,
#   'no2': 12.5,
#   'nox': 13.4,
#   'o3': 39,
#   'o3_8hr': 55.2,
#   'pm10': 86,
#   'pm10_avg': 54,
#   'pm2.5': 17,
#   'pm2.5_avg': 17.8,
#   'pollutant': '細懸浮微粒',
#   'siteid': 204,
#   'sitename': '屏東（琉球）',
#   'so2': 1.4,
#   'so2_avg': 2,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 320,
#   'windspeed': 3.2},
#  {'aqi': 80,
#   'co': 0.39,
#   'co_8hr': 0.3,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.17904722,
#   'longitude': 120.24583056,
#   'no': 0.4,
#   'no2': 16.8,
#   'nox': 17.3,
#   'o3': 16.3,
#   'o3_8hr': 37.8,
#   'pm10': 65,
#   'pm10_avg': 80,
#   'pm2.5': 16,
#   'pm2.5_avg': 14.5,
#   'pollutant': '懸浮微粒',
#   'siteid': 203,
#   'sitename': '臺南（麻豆）',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 12,
#   'windspeed': 3.4},
#  {'aqi': 73,
#   'co': 0.44,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.87985556,
#   'longitude': 120.24535,
#   'no': 0.2,
#   'no2': 16.8,
#   'nox': 17,
#   'o3': 20.2,
#   'o3_8hr': 41.4,
#   'pm10': 101,
#   'pm10_avg': 73,
#   'pm2.5': 14,
#   'pm2.5_avg': 9.9,
#   'pollutant': '懸浮微粒',
#   'siteid': 202,
#   'sitename': '高雄（湖內）',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 318,
#   'windspeed': 1.4},
#  {'aqi': 30,
#   'co': 0.34,
#   'co_8hr': 0.3,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.96117,
#   'longitude': 120.56373,
#   'no': 1.6,
#   'no2': 11,
#   'nox': 12.6,
#   'o3': 26.8,
#   'o3_8hr': 33,
#   'pm10': 22,
#   'pm10_avg': 27,
#   'pm2.5': 9,
#   'pm2.5_avg': 7.8,
#   'pollutant': None,
#   'siteid': 201,
#   'sitename': '彰化（員林）',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 355,
#   'windspeed': 1.5},
#  {'aqi': 40,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.85493056,
#   'longitude': 120.26964167,
#   'no': 0.4,
#   'no2': 6.8,
#   'nox': 7.2,
#   'o3': 37.5,
#   'o3_8hr': 42.1,
#   'pm10': 36,
#   'pm10_avg': 30,
#   'pm2.5': 16,
#   'pm2.5_avg': 12.2,
#   'pollutant': None,
#   'siteid': 85,
#   'sitename': '大城',
#   'so2': 1.5,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 47,
#   'windspeed': 8.6},
#  {'aqi': 49,
#   'co': 0.2,
#   'co_8hr': 0.2,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.29681695,
#   'longitude': 121.53656894,
#   'no': 0.1,
#   'no2': 1.6,
#   'nox': 1.7,
#   'o3': 54.8,
#   'o3_8hr': 49.2,
#   'pm10': 55,
#   'pm10_avg': 49,
#   'pm2.5': 18,
#   'pm2.5_avg': 14,
#   'pollutant': None,
#   'siteid': 84,
#   'sitename': '富貴角',
#   'so2': 0.3,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 51,
#   'windspeed': 9.1},
#  {'aqi': 65,
#   'co': 0.29,
#   'co_8hr': 0.3,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.753506,
#   'longitude': 120.251825,
#   'no': 1.1,
#   'no2': 7.6,
#   'nox': 8.8,
#   'o3': 34,
#   'o3_8hr': 40.3,
#   'pm10': 46,
#   'pm10_avg': 65,
#   'pm2.5': 19,
#   'pm2.5_avg': 13.3,
#   'pollutant': '懸浮微粒',
#   'siteid': 83,
#   'sitename': '麥寮',
#   'so2': 1.5,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 3,
#   'windspeed': 5.9},
#  {'aqi': 34,
#   'co': 0.31,
#   'co_8hr': 0.2,
#   'county': '臺東縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.045083,
#   'longitude': 121.161933,
#   'no': 0.3,
#   'no2': 4.2,
#   'nox': 4.5,
#   'o3': 31.7,
#   'o3_8hr': 33,
#   'pm10': 16,
#   'pm10_avg': 34,
#   'pm2.5': 5,
#   'pm2.5_avg': 5.2,
#   'pollutant': None,
#   'siteid': 80,
#   'sitename': '關山',
#   'so2': 0.9,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 32,
#   'windspeed': 2.3},
#  {'aqi': 37,
#   'co': 0.26,
#   'co_8hr': 0.3,
#   'county': '澎湖縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.569031,
#   'longitude': 119.566158,
#   'no': 0.8,
#   'no2': 2.7,
#   'nox': 3.5,
#   'o3': 46.3,
#   'o3_8hr': 40.2,
#   'pm10': 21,
#   'pm10_avg': 14,
#   'pm2.5': 8,
#   'pm2.5_avg': 5.7,
#   'pollutant': None,
#   'siteid': 78,
#   'sitename': '馬公',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 32,
#   'windspeed': 7.3},
#  {'aqi': 46,
#   'co': 0.37,
#   'co_8hr': 0.3,
#   'county': '金門縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.432133,
#   'longitude': 118.312256,
#   'no': 0.6,
#   'no2': 7.8,
#   'nox': 8.5,
#   'o3': 36.4,
#   'o3_8hr': 50.2,
#   'pm10': 23,
#   'pm10_avg': 21,
#   'pm2.5': 14,
#   'pm2.5_avg': 9.6,
#   'pollutant': None,
#   'siteid': 77,
#   'sitename': '金門',
#   'so2': 1.3,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 76,
#   'windspeed': 2.7},
#  {'aqi': 43,
#   'co': 0.26,
#   'co_8hr': 0.2,
#   'county': '連江縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 26.153736,
#   'longitude': 119.952724,
#   'no': 1,
#   'no2': 3.7,
#   'nox': 4.7,
#   'o3': 53.3,
#   'o3_8hr': 46.4,
#   'pm10': 34,
#   'pm10_avg': 26,
#   'pm2.5': 14,
#   'pm2.5_avg': 10.6,
#   'pollutant': None,
#   'siteid': 75,
#   'sitename': '馬祖',
#   'so2': 0.6,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 355,
#   'windspeed': 1.2},
#  {'aqi': 46,
#   'co': 0.42,
#   'co_8hr': 0.2,
#   'county': '南投縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.968842,
#   'longitude': 120.967903,
#   'no': 1.3,
#   'no2': 9.7,
#   'nox': 11,
#   'o3': 30.8,
#   'o3_8hr': 36.2,
#   'pm10': 21,
#   'pm10_avg': 18,
#   'pm2.5': 12,
#   'pm2.5_avg': 14.3,
#   'pollutant': None,
#   'siteid': 72,
#   'sitename': '埔里',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 321,
#   'windspeed': 0.3},
#  {'aqi': 68,
#   'co': 0.52,
#   'co_8hr': 0.4,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.608711,
#   'longitude': 120.312017,
#   'no': 1.5,
#   'no2': 19.2,
#   'nox': 20.7,
#   'o3': 28.5,
#   'o3_8hr': 42.4,
#   'pm10': 122,
#   'pm10_avg': 68,
#   'pm2.5': 21,
#   'pm2.5_avg': 18.4,
#   'pollutant': '懸浮微粒',
#   'siteid': 71,
#   'sitename': '復興',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 165,
#   'windspeed': 1.5},
#  {'aqi': 35,
#   'co': 0.44,
#   'co_8hr': 0.4,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.017,
#   'longitude': 121.516306,
#   'no': 2.9,
#   'no2': 13.6,
#   'nox': 16.5,
#   'o3': 37.8,
#   'o3_8hr': 32,
#   'pm10': 40,
#   'pm10_avg': 32,
#   'pm2.5': 12,
#   'pm2.5_avg': 10.7,
#   'pollutant': None,
#   'siteid': 70,
#   'sitename': '永和',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 82,
#   'windspeed': 2.2},
#  {'aqi': 36,
#   'co': 0.41,
#   'co_8hr': 0.3,
#   'county': '南投縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.756389,
#   'longitude': 120.677306,
#   'no': 0.5,
#   'no2': 17.4,
#   'nox': 17.9,
#   'o3': 15.3,
#   'o3_8hr': 37.3,
#   'pm10': 32,
#   'pm10_avg': 28,
#   'pm2.5': 11,
#   'pm2.5_avg': 11.1,
#   'pollutant': None,
#   'siteid': 69,
#   'sitename': '竹山',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 28,
#   'windspeed': 2},
#  {'aqi': 42,
#   'co': 0.78,
#   'co_8hr': 0.7,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.953278,
#   'longitude': 121.221667,
#   'no': 15.5,
#   'no2': 24.4,
#   'nox': 39.9,
#   'o3': 23.9,
#   'o3_8hr': 17.7,
#   'pm10': 35,
#   'pm10_avg': 29,
#   'pm2.5': 16,
#   'pm2.5_avg': 12.8,
#   'pollutant': None,
#   'siteid': 68,
#   'sitename': '中壢',
#   'so2': 1,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 5,
#   'windspeed': 1.3},
#  {'aqi': 52,
#   'co': 0.84,
#   'co_8hr': 1,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.072611,
#   'longitude': 121.493806,
#   'no': 38.1,
#   'no2': 32.6,
#   'nox': 70.7,
#   'o3': 18.5,
#   'o3_8hr': 12.9,
#   'pm10': 48,
#   'pm10_avg': 37,
#   'pm2.5': 15,
#   'pm2.5_avg': 13.8,
#   'pollutant': '二氧化氮',
#   'siteid': 67,
#   'sitename': '三重',
#   'so2': 0.7,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': '-',
#   'windspeed': '-'},
#  {'aqi': 31,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '宜蘭縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.632203,
#   'longitude': 121.792928,
#   'no': 1.2,
#   'no2': 6.7,
#   'nox': 7.9,
#   'o3': 39.2,
#   'o3_8hr': 33.6,
#   'pm10': 34,
#   'pm10_avg': 31,
#   'pm2.5': 12,
#   'pm2.5_avg': 9.4,
#   'pollutant': None,
#   'siteid': 66,
#   'sitename': '冬山',
#   'so2': 0.7,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 239,
#   'windspeed': 1.2},
#  {'aqi': 31,
#   'co': 0.28,
#   'co_8hr': 0.3,
#   'county': '宜蘭縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.747917,
#   'longitude': 121.746394,
#   'no': 0.6,
#   'no2': 4.8,
#   'nox': 5.4,
#   'o3': 33.2,
#   'o3_8hr': 33.3,
#   'pm10': 23,
#   'pm10_avg': 20,
#   'pm2.5': 11,
#   'pm2.5_avg': 9.7,
#   'pollutant': None,
#   'siteid': 65,
#   'sitename': '宜蘭',
#   'so2': 0.8,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 293,
#   'windspeed': 1.1},
#  {'aqi': 39,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '臺北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.182722,
#   'longitude': 121.529583,
#   'no': 1,
#   'no2': 1.1,
#   'nox': 2.2,
#   'o3': 49.7,
#   'o3_8hr': 43,
#   'pm10': 28,
#   'pm10_avg': 17,
#   'pm2.5': 7,
#   'pm2.5_avg': 4.7,
#   'pollutant': None,
#   'siteid': 64,
#   'sitename': '陽明',
#   'so2': 0.9,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': None,
#   'windspeed': None},
#  {'aqi': 34,
#   'co': 0.25,
#   'co_8hr': 0.3,
#   'county': '花蓮縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.971306,
#   'longitude': 121.599769,
#   'no': 0.4,
#   'no2': 3.9,
#   'nox': 4.3,
#   'o3': 45.4,
#   'o3_8hr': 37.3,
#   'pm10': 34,
#   'pm10_avg': 31,
#   'pm2.5': 10,
#   'pm2.5_avg': 8.2,
#   'pollutant': None,
#   'siteid': 63,
#   'sitename': '花蓮',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 72,
#   'windspeed': 4.4},
#  {'aqi': 34,
#   'co': 0.39,
#   'co_8hr': 0.3,
#   'county': '臺東縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.755358,
#   'longitude': 121.15045,
#   'no': 1.4,
#   'no2': 6.3,
#   'nox': 7.8,
#   'o3': 29,
#   'o3_8hr': 37,
#   'pm10': 12,
#   'pm10_avg': 21,
#   'pm2.5': 5,
#   'pm2.5_avg': 7.2,
#   'pollutant': None,
#   'siteid': 62,
#   'sitename': '臺東',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 326,
#   'windspeed': 1.6},
#  {'aqi': 28,
#   'co': 0.29,
#   'co_8hr': 0.2,
#   'county': '屏東縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 21.958069,
#   'longitude': 120.788928,
#   'no': 0.6,
#   'no2': 2.7,
#   'nox': 3.4,
#   'o3': None,
#   'o3_8hr': None,
#   'pm10': 20,
#   'pm10_avg': 17,
#   'pm2.5': 7,
#   'pm2.5_avg': 8.5,
#   'pollutant': None,
#   'siteid': 61,
#   'sitename': '恆春',
#   'so2': 0.7,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 27,
#   'windspeed': 10.2},
#  {'aqi': 53,
#   'co': 0.35,
#   'co_8hr': 0.2,
#   'county': '屏東縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.523108,
#   'longitude': 120.561175,
#   'no': 1.5,
#   'no2': 11,
#   'nox': 12.5,
#   'o3': 34.8,
#   'o3_8hr': 50.6,
#   'pm10': 63,
#   'pm10_avg': 34,
#   'pm2.5': 22,
#   'pm2.5_avg': 16.3,
#   'pollutant': '細懸浮微粒',
#   'siteid': 60,
#   'sitename': '潮州',
#   'so2': 1.5,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 285,
#   'windspeed': 2.1},
#  {'aqi': 48,
#   'co': 0.42,
#   'co_8hr': 0.2,
#   'county': '屏東縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.673081,
#   'longitude': 120.488033,
#   'no': 0.5,
#   'no2': 13.1,
#   'nox': 13.6,
#   'o3': 36.7,
#   'o3_8hr': 46.5,
#   'pm10': 116,
#   'pm10_avg': 48,
#   'pm2.5': 21,
#   'pm2.5_avg': 13.7,
#   'pollutant': None,
#   'siteid': 59,
#   'sitename': '屏東',
#   'so2': 1.7,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 256,
#   'windspeed': 1.8},
#  {'aqi': 63,
#   'co': 0.53,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.565833,
#   'longitude': 120.337736,
#   'no': 0.7,
#   'no2': 22.4,
#   'nox': 23.1,
#   'o3': 29.4,
#   'o3_8hr': 43.8,
#   'pm10': 113,
#   'pm10_avg': 63,
#   'pm2.5': 20,
#   'pm2.5_avg': 14.9,
#   'pollutant': '懸浮微粒',
#   'siteid': 58,
#   'sitename': '小港',
#   'so2': 1.3,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 331,
#   'windspeed': 1.3},
#  {'aqi': 74,
#   'co': 0.53,
#   'co_8hr': 0.4,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.6044507,
#   'longitude': 120.30833356,
#   'no': 2.5,
#   'no2': 19.5,
#   'nox': 22,
#   'o3': 28.3,
#   'o3_8hr': 43.3,
#   'pm10': 139,
#   'pm10_avg': 74,
#   'pm2.5': 23,
#   'pm2.5_avg': 18,
#   'pollutant': '懸浮微粒',
#   'siteid': 57,
#   'sitename': '前鎮',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 3,
#   'windspeed': 3.2},
#  {'aqi': 79,
#   'co': 0.46,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.63390278,
#   'longitude': 120.28676111,
#   'no': 0.8,
#   'no2': 18.3,
#   'nox': 19.2,
#   'o3': 27.4,
#   'o3_8hr': 44.4,
#   'pm10': 130,
#   'pm10_avg': 79,
#   'pm2.5': 15,
#   'pm2.5_avg': 14.3,
#   'pollutant': '懸浮微粒',
#   'siteid': 56,
#   'sitename': '前金',
#   'so2': 1.4,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 354,
#   'windspeed': 4.2},
#  {'aqi': 82,
#   'co': 0.46,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.674861,
#   'longitude': 120.292917,
#   'no': 0.7,
#   'no2': 16.7,
#   'nox': 17.5,
#   'o3': 28.2,
#   'o3_8hr': 46.3,
#   'pm10': 163,
#   'pm10_avg': 82,
#   'pm2.5': 23,
#   'pm2.5_avg': 16.7,
#   'pollutant': '懸浮微粒',
#   'siteid': 54,
#   'sitename': '左營',
#   'so2': 1.5,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 7,
#   'windspeed': 3},
#  {'aqi': 90,
#   'co': 0.45,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.733667,
#   'longitude': 120.328289,
#   'no': 0.4,
#   'no2': 16.6,
#   'nox': 17.1,
#   'o3': 26.7,
#   'o3_8hr': 45.4,
#   'pm10': 182,
#   'pm10_avg': 90,
#   'pm2.5': 20,
#   'pm2.5_avg': 14.7,
#   'pollutant': '懸浮微粒',
#   'siteid': 53,
#   'sitename': '楠梓',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 340,
#   'windspeed': 2.3},
#  {'aqi': 59,
#   'co': 0.51,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.4795,
#   'longitude': 120.41175,
#   'no': 0,
#   'no2': 23.2,
#   'nox': 23.2,
#   'o3': 28.4,
#   'o3_8hr': 47.3,
#   'pm10': 84,
#   'pm10_avg': 59,
#   'pm2.5': 17,
#   'pm2.5_avg': 16.8,
#   'pollutant': '懸浮微粒',
#   'siteid': 52,
#   'sitename': '林園',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 315,
#   'windspeed': 1},
#  {'aqi': 52,
#   'co': 0.46,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.56413611,
#   'longitude': 120.425311,
#   'no': 0.9,
#   'no2': 23.2,
#   'nox': 24.2,
#   'o3': 24.7,
#   'o3_8hr': 41.6,
#   'pm10': 57,
#   'pm10_avg': 33,
#   'pm2.5': 18,
#   'pm2.5_avg': 16,
#   'pollutant': '細懸浮微粒',
#   'siteid': 51,
#   'sitename': '大寮',
#   'so2': 2.1,
#   'so2_avg': 2,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 318,
#   'windspeed': 1.8},
#  {'aqi': 71,
#   'co': 0.71,
#   'co_8hr': 0.4,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.628126,
#   'longitude': 120.357422,
#   'no': 3,
#   'no2': 21.4,
#   'nox': 24.5,
#   'o3': 25.2,
#   'o3_8hr': 41.1,
#   'pm10': 164,
#   'pm10_avg': 71,
#   'pm2.5': 26,
#   'pm2.5_avg': 19.3,
#   'pollutant': '懸浮微粒',
#   'siteid': 50,
#   'sitename': '鳳山',
#   'so2': 1.3,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 252,
#   'windspeed': 1.3},
#  {'aqi': 64,
#   'co': 0.48,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.689056,
#   'longitude': 120.332631,
#   'no': 1.1,
#   'no2': 17.9,
#   'nox': 19,
#   'o3': 25.4,
#   'o3_8hr': 43.7,
#   'pm10': 136,
#   'pm10_avg': 64,
#   'pm2.5': 25,
#   'pm2.5_avg': 17.6,
#   'pollutant': '懸浮微粒',
#   'siteid': 49,
#   'sitename': '仁武',
#   'so2': 1.5,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 342,
#   'windspeed': 2.8},
#  {'aqi': 83,
#   'co': 0.48,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.757506,
#   'longitude': 120.305689,
#   'no': 1.5,
#   'no2': 20.2,
#   'nox': 21.7,
#   'o3': 22.9,
#   'o3_8hr': 44.1,
#   'pm10': 153,
#   'pm10_avg': 83,
#   'pm2.5': 24,
#   'pm2.5_avg': 15.7,
#   'pollutant': '懸浮微粒',
#   'siteid': 48,
#   'sitename': '橋頭',
#   'so2': 1.7,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 10,
#   'windspeed': 3.2},
#  {'aqi': 54,
#   'co': 0.39,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.883583,
#   'longitude': 120.530542,
#   'no': 0.7,
#   'no2': 9.1,
#   'nox': 9.8,
#   'o3': 36.2,
#   'o3_8hr': 44.8,
#   'pm10': 123,
#   'pm10_avg': 54,
#   'pm2.5': 21,
#   'pm2.5_avg': 12.1,
#   'pollutant': '懸浮微粒',
#   'siteid': 47,
#   'sitename': '美濃',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 267,
#   'windspeed': 1.2},
#  {'aqi': 75,
#   'co': 0.45,
#   'co_8hr': 0.3,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.98928311,
#   'longitude': 120.21947897,
#   'no': 0.6,
#   'no2': 17.2,
#   'nox': 17.8,
#   'o3': 19.6,
#   'o3_8hr': 42.1,
#   'pm10': 73,
#   'pm10_avg': 75,
#   'pm2.5': 21,
#   'pm2.5_avg': 14.5,
#   'pollutant': '懸浮微粒',
#   'siteid': 46,
#   'sitename': '臺南',
#   'so2': 2,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 2,
#   'windspeed': 4.2},
#  {'aqi': 75,
#   'co': 0.43,
#   'co_8hr': 0.3,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.048197,
#   'longitude': 120.2175,
#   'no': 0.4,
#   'no2': 13.7,
#   'nox': 14.2,
#   'o3': 20.9,
#   'o3_8hr': 42.6,
#   'pm10': 63,
#   'pm10_avg': 75,
#   'pm2.5': 13,
#   'pm2.5_avg': 14.7,
#   'pollutant': '懸浮微粒',
#   'siteid': 45,
#   'sitename': '安南',
#   'so2': 1.5,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 320,
#   'windspeed': 3},
#  {'aqi': 92,
#   'co': 0.4,
#   'co_8hr': 0.2,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.11337642,
#   'longitude': 120.29740529,
#   'no': 0.7,
#   'no2': 13.6,
#   'nox': 14.4,
#   'o3': 19.8,
#   'o3_8hr': 42.1,
#   'pm10': 60,
#   'pm10_avg': 92,
#   'pm2.5': 16,
#   'pm2.5_avg': 13.2,
#   'pollutant': '懸浮微粒',
#   'siteid': 44,
#   'sitename': '善化',
#   'so2': 1.7,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 355,
#   'windspeed': 3.9},
#  {'aqi': 105,
#   'co': 0.45,
#   'co_8hr': 0.3,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.305633,
#   'longitude': 120.31725,
#   'no': 0.2,
#   'no2': 16.5,
#   'nox': 16.8,
#   'o3': 17.3,
#   'o3_8hr': 37.7,
#   'pm10': 63,
#   'pm10_avg': 113,
#   'pm2.5': 16,
#   'pm2.5_avg': 16.6,
#   'pollutant': '懸浮微粒',
#   'siteid': 43,
#   'sitename': '新營',
#   'so2': 1.9,
#   'so2_avg': 1,
#   'status': '對敏感族群不健康',
#   'unit': None,
#   'winddirec': 14,
#   'windspeed': 3.4},
#  {'aqi': 63,
#   'co': 0.47,
#   'co_8hr': 0.3,
#   'county': '嘉義市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.46477865,
#   'longitude': 120.44125148,
#   'no': 1.6,
#   'no2': 17.2,
#   'nox': 18.8,
#   'o3': 15.4,
#   'o3_8hr': 37.4,
#   'pm10': 26,
#   'pm10_avg': 63,
#   'pm2.5': 16,
#   'pm2.5_avg': 14.2,
#   'pollutant': '懸浮微粒',
#   'siteid': 42,
#   'sitename': '嘉義',
#   'so2': 10.5,
#   'so2_avg': 2,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 6,
#   'windspeed': 2.7},
#  {'aqi': 39,
#   'co': 0.28,
#   'co_8hr': 0.3,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.702175,
#   'longitude': 120.19933333,
#   'no': 0.5,
#   'no2': 6.2,
#   'nox': 6.8,
#   'o3': 35.9,
#   'o3_8hr': 41,
#   'pm10': 49,
#   'pm10_avg': 39,
#   'pm2.5': 10,
#   'pm2.5_avg': 8.9,
#   'pollutant': None,
#   'siteid': 41,
#   'sitename': '臺西',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 25,
#   'windspeed': 7.4},
#  {'aqi': 72,
#   'co': 0.31,
#   'co_8hr': 0.3,
#   'county': '嘉義縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.46538,
#   'longitude': 120.2478,
#   'no': 1.9,
#   'no2': 11.4,
#   'nox': 13.3,
#   'o3': 25.1,
#   'o3_8hr': 38.8,
#   'pm10': 56,
#   'pm10_avg': 72,
#   'pm2.5': 9,
#   'pm2.5_avg': 9.6,
#   'pollutant': '懸浮微粒',
#   'siteid': 40,
#   'sitename': '朴子',
#   'so2': 2.3,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 352,
#   'windspeed': 2.4},
#  {'aqi': 104,
#   'co': 0.32,
#   'co_8hr': 0.3,
#   'county': '嘉義縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.554839,
#   'longitude': 120.345531,
#   'no': 0.4,
#   'no2': 12.9,
#   'nox': 13.3,
#   'o3': 25.4,
#   'o3_8hr': 38.3,
#   'pm10': 40,
#   'pm10_avg': 109,
#   'pm2.5': 12,
#   'pm2.5_avg': 15.3,
#   'pollutant': '懸浮微粒',
#   'siteid': 39,
#   'sitename': '新港',
#   'so2': 1.9,
#   'so2_avg': 1,
#   'status': '對敏感族群不健康',
#   'unit': None,
#   'winddirec': 5,
#   'windspeed': 3.4},
#  {'aqi': 124,
#   'co': 0.34,
#   'co_8hr': 0.3,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.757547,
#   'longitude': 120.348742,
#   'no': 0.7,
#   'no2': 11.3,
#   'nox': 12.1,
#   'o3': 26.9,
#   'o3_8hr': 33.9,
#   'pm10': 135,
#   'pm10_avg': 173,
#   'pm2.5': 14,
#   'pm2.5_avg': 17,
#   'pollutant': '懸浮微粒',
#   'siteid': 38,
#   'sitename': '崙背',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '對敏感族群不健康',
#   'unit': None,
#   'winddirec': 2,
#   'windspeed': 2.4},
#  {'aqi': 49,
#   'co': 0.36,
#   'co_8hr': 0.3,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.711853,
#   'longitude': 120.544994,
#   'no': 1,
#   'no2': 12.2,
#   'nox': 13.2,
#   'o3': 22.6,
#   'o3_8hr': 38.8,
#   'pm10': 21,
#   'pm10_avg': 49,
#   'pm2.5': 10,
#   'pm2.5_avg': 10.8,
#   'pollutant': None,
#   'siteid': 37,
#   'sitename': '斗六',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 344,
#   'windspeed': 1.8},
#  {'aqi': 31,
#   'co': 0.39,
#   'co_8hr': 0.3,
#   'county': '南投縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.913,
#   'longitude': 120.685306,
#   'no': 1.2,
#   'no2': 15.5,
#   'nox': 16.8,
#   'o3': 19.7,
#   'o3_8hr': 33.4,
#   'pm10': 21,
#   'pm10_avg': 26,
#   'pm2.5': 6,
#   'pm2.5_avg': 9.1,
#   'pollutant': None,
#   'siteid': 36,
#   'sitename': '南投',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 340,
#   'windspeed': 1.5},
#  {'aqi': 39,
#   'co': 0.29,
#   'co_8hr': 0.3,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.925175,
#   'longitude': 120.409653,
#   'no': 0.3,
#   'no2': 9.1,
#   'nox': 9.5,
#   'o3': 34.8,
#   'o3_8hr': 37.4,
#   'pm10': 39,
#   'pm10_avg': 39,
#   'pm2.5': 10,
#   'pm2.5_avg': 7.8,
#   'pollutant': None,
#   'siteid': 35,
#   'sitename': '二林',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 26,
#   'windspeed': 5.6},
#  {'aqi': 34,
#   'co': 0.28,
#   'co_8hr': 0.3,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.131672,
#   'longitude': 120.469061,
#   'no': 0.5,
#   'no2': 12.3,
#   'nox': 12.8,
#   'o3': 32.8,
#   'o3_8hr': 33.6,
#   'pm10': 31,
#   'pm10_avg': 29,
#   'pm2.5': 15,
#   'pm2.5_avg': 10.5,
#   'pollutant': None,
#   'siteid': 34,
#   'sitename': '線西',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 35,
#   'windspeed': 8},
#  {'aqi': 26,
#   'co': 0.33,
#   'co_8hr': 0.3,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.066,
#   'longitude': 120.541519,
#   'no': 1.1,
#   'no2': 13.2,
#   'nox': 14.3,
#   'o3': 27,
#   'o3_8hr': 28.4,
#   'pm10': 23,
#   'pm10_avg': 22,
#   'pm2.5': 8,
#   'pm2.5_avg': 7.8,
#   'pollutant': None,
#   'siteid': 33,
#   'sitename': '彰化',
#   'so2': 0.6,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 23,
#   'windspeed': 2.4},
#  {'aqi': 29,
#   'co': 0.27,
#   'co_8hr': 0.3,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.162197,
#   'longitude': 120.616917,
#   'no': 1.2,
#   'no2': 7.3,
#   'nox': 8.6,
#   'o3': 33.3,
#   'o3_8hr': 31.9,
#   'pm10': 21,
#   'pm10_avg': 26,
#   'pm2.5': 8,
#   'pm2.5_avg': 7.1,
#   'pollutant': None,
#   'siteid': 32,
#   'sitename': '西屯',
#   'so2': 1,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 0,
#   'windspeed': 4.7},
#  {'aqi': 27,
#   'co': 0.36,
#   'co_8hr': 0.3,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.151958,
#   'longitude': 120.641092,
#   'no': 1.2,
#   'no2': 10.9,
#   'nox': 12.1,
#   'o3': 26.6,
#   'o3_8hr': 29.1,
#   'pm10': 16,
#   'pm10_avg': 19,
#   'pm2.5': 7,
#   'pm2.5_avg': 6.7,
#   'pollutant': None,
#   'siteid': 31,
#   'sitename': '忠明',
#   'so2': 1.5,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 329,
#   'windspeed': 1.8},
#  {'aqi': 28,
#   'co': 0.39,
#   'co_8hr': 0.4,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.09961111,
#   'longitude': 120.67844444,
#   'no': 1.6,
#   'no2': 10.8,
#   'nox': 12.5,
#   'o3': 22.7,
#   'o3_8hr': 30.4,
#   'pm10': 20,
#   'pm10_avg': 19,
#   'pm2.5': 8,
#   'pm2.5_avg': 8.2,
#   'pollutant': None,
#   'siteid': 30,
#   'sitename': '大里',
#   'so2': 1.3,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 8,
#   'windspeed': 2.1},
#  {'aqi': 26,
#   'co': 0.27,
#   'co_8hr': 0.3,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.225628,
#   'longitude': 120.568794,
#   'no': 0.7,
#   'no2': 6.3,
#   'nox': 7,
#   'o3': 13,
#   'o3_8hr': 24.1,
#   'pm10': 26,
#   'pm10_avg': 22,
#   'pm2.5': 11,
#   'pm2.5_avg': 8.1,
#   'pollutant': None,
#   'siteid': 29,
#   'sitename': '沙鹿',
#   'so2': 0.9,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 9,
#   'windspeed': 5.4},
#  {'aqi': 30,
#   'co': 0.29,
#   'co_8hr': 0.3,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.25699731,
#   'longitude': 120.74252414,
#   'no': 0.3,
#   'no2': 5.8,
#   'nox': 6.1,
#   'o3': 27.4,
#   'o3_8hr': 32,
#   'pm10': 11,
#   'pm10_avg': 15,
#   'pm2.5': 10,
#   'pm2.5_avg': 8.7,
#   'pollutant': None,
#   'siteid': 28,
#   'sitename': '豐原',
#   'so2': 0.8,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 33,
#   'windspeed': 3.3},
#  {'aqi': 30,
#   'co': 0.24,
#   'co_8hr': 0.3,
#   'county': '苗栗縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.38248443,
#   'longitude': 120.75956754,
#   'no': 0.9,
#   'no2': 3.2,
#   'nox': 4.2,
#   'o3': 40,
#   'o3_8hr': 32.9,
#   'pm10': 25,
#   'pm10_avg': 13,
#   'pm2.5': 9,
#   'pm2.5_avg': 6.5,
#   'pollutant': None,
#   'siteid': 27,
#   'sitename': '三義',
#   'so2': 0.9,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 16,
#   'windspeed': 7},
#  {'aqi': 30,
#   'co': 0.27,
#   'co_8hr': 0.3,
#   'county': '苗栗縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.56499183,
#   'longitude': 120.82011468,
#   'no': 1,
#   'no2': 7.7,
#   'nox': 8.7,
#   'o3': 39.6,
#   'o3_8hr': 32.4,
#   'pm10': 27,
#   'pm10_avg': 20,
#   'pm2.5': 14,
#   'pm2.5_avg': 8.5,
#   'pollutant': None,
#   'siteid': 26,
#   'sitename': '苗栗',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 8,
#   'windspeed': 3.8},
#  {'aqi': 31,
#   'co': 0.32,
#   'co_8hr': 0.3,
#   'county': '苗栗縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.69690679,
#   'longitude': 120.89869286,
#   'no': 1.1,
#   'no2': 10.5,
#   'nox': 11.6,
#   'o3': 40.8,
#   'o3_8hr': 31.1,
#   'pm10': 34,
#   'pm10_avg': 21,
#   'pm2.5': 11,
#   'pm2.5_avg': 9.5,
#   'pollutant': None,
#   'siteid': 25,
#   'sitename': '頭份',
#   'so2': 1.5,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 45,
#   'windspeed': 2.3},
#  {'aqi': 28,
#   'co': 0.33,
#   'co_8hr': 0.3,
#   'county': '新竹市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.8056356,
#   'longitude': 120.97236752,
#   'no': 0.4,
#   'no2': 10,
#   'nox': 10.4,
#   'o3': 39.2,
#   'o3_8hr': 30.4,
#   'pm10': 34,
#   'pm10_avg': 24,
#   'pm2.5': 18,
#   'pm2.5_avg': 7.4,
#   'pollutant': None,
#   'siteid': 24,
#   'sitename': '新竹',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 39,
#   'windspeed': 2.7},
#  {'aqi': 32,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '新竹縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.74091408,
#   'longitude': 121.08895493,
#   'no': 0.2,
#   'no2': 5.5,
#   'nox': 5.7,
#   'o3': 43.8,
#   'o3_8hr': 35.1,
#   'pm10': 31,
#   'pm10_avg': 19,
#   'pm2.5': 11,
#   'pm2.5_avg': 6.5,
#   'pollutant': None,
#   'siteid': 23,
#   'sitename': '竹東',
#   'so2': 0.5,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 45,
#   'windspeed': 3.3},
#  {'aqi': 32,
#   'co': 0.26,
#   'co_8hr': 0.3,
#   'county': '新竹縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.90009696,
#   'longitude': 121.03886894,
#   'no': 0.3,
#   'no2': 4.5,
#   'nox': 4.9,
#   'o3': 45.1,
#   'o3_8hr': 35,
#   'pm10': 30,
#   'pm10_avg': 24,
#   'pm2.5': 11,
#   'pm2.5_avg': 8.2,
#   'pollutant': None,
#   'siteid': 22,
#   'sitename': '湖口',
#   'so2': 2.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 49,
#   'windspeed': 5.3},
#  {'aqi': 31,
#   'co': 0.27,
#   'co_8hr': 0.3,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.86400048,
#   'longitude': 121.21645772,
#   'no': 0.8,
#   'no2': 7.4,
#   'nox': 8.2,
#   'o3': 41.9,
#   'o3_8hr': 33.4,
#   'pm10': 37,
#   'pm10_avg': 26,
#   'pm2.5': 11,
#   'pm2.5_avg': 9.2,
#   'pollutant': None,
#   'siteid': 21,
#   'sitename': '龍潭',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 62,
#   'windspeed': 6.4},
#  {'aqi': 35,
#   'co': 0.41,
#   'co_8hr': 0.4,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.952786,
#   'longitude': 121.203986,
#   'no': 1.5,
#   'no2': 13.3,
#   'nox': 14.8,
#   'o3': 39.4,
#   'o3_8hr': 29.9,
#   'pm10': 29,
#   'pm10_avg': 25,
#   'pm2.5': 15,
#   'pm2.5_avg': 10.7,
#   'pollutant': None,
#   'siteid': 20,
#   'sitename': '平鎮',
#   'so2': 1.2,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 79,
#   'windspeed': 3.5},
#  {'aqi': 43,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.03556747,
#   'longitude': 121.08283092,
#   'no': 0.1,
#   'no2': 7.3,
#   'nox': 7.4,
#   'o3': 44.5,
#   'o3_8hr': 36.6,
#   'pm10': 39,
#   'pm10_avg': 41,
#   'pm2.5': 17,
#   'pm2.5_avg': 13.1,
#   'pollutant': None,
#   'siteid': 19,
#   'sitename': '觀音',
#   'so2': 1.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 86,
#   'windspeed': 6.5},
#  {'aqi': 46,
#   'co': 0.27,
#   'co_8hr': 0.3,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.06100357,
#   'longitude': 121.20251473,
#   'no': 0.9,
#   'no2': 12.2,
#   'nox': 13.2,
#   'o3': 41.4,
#   'o3_8hr': 34.4,
#   'pm10': 42,
#   'pm10_avg': 34,
#   'pm2.5': 16,
#   'pm2.5_avg': 14.3,
#   'pollutant': None,
#   'siteid': 18,
#   'sitename': '大園',
#   'so2': 1.3,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 64,
#   'windspeed': 4.4},
#  {'aqi': 27,
#   'co': 0.35,
#   'co_8hr': 0.4,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.9947107,
#   'longitude': 121.30500531,
#   'no': 1.2,
#   'no2': 10,
#   'nox': 11.3,
#   'o3': 41.1,
#   'o3_8hr': 29,
#   'pm10': 32,
#   'pm10_avg': 27,
#   'pm2.5': 10,
#   'pm2.5_avg': 8.2,
#   'pollutant': None,
#   'siteid': 17,
#   'sitename': '桃園',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 51,
#   'windspeed': 3.7},
#  {'aqi': 48,
#   'co': 0.58,
#   'co_8hr': 0.6,
#   'county': '臺北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.06331455,
#   'longitude': 121.51342074,
#   'no': 15.1,
#   'no2': 26.5,
#   'nox': 41.6,
#   'o3': 26.9,
#   'o3_8hr': 21.6,
#   'pm10': 41,
#   'pm10_avg': 32,
#   'pm2.5': 17,
#   'pm2.5_avg': 14.8,
#   'pollutant': None,
#   'siteid': 16,
#   'sitename': '大同',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': '-',
#   'windspeed': '-'},
#  {'aqi': 46,
#   'co': 0.28,
#   'co_8hr': 0.3,
#   'county': '臺北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.05,
#   'longitude': 121.578611,
#   'no': 1.9,
#   'no2': 13.2,
#   'nox': 15.2,
#   'o3': 37.6,
#   'o3_8hr': 30.8,
#   'pm10': 44,
#   'pm10_avg': 36,
#   'pm2.5': 16,
#   'pm2.5_avg': 14.1,
#   'pollutant': None,
#   'siteid': 15,
#   'sitename': '松山',
#   'so2': 1.3,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 18,
#   'windspeed': 2.1},
#  {'aqi': 36,
#   'co': 0.35,
#   'co_8hr': 0.3,
#   'county': '臺北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.020608,
#   'longitude': 121.529556,
#   'no': 0.6,
#   'no2': 13.2,
#   'nox': 13.8,
#   'o3': 37.1,
#   'o3_8hr': 31.4,
#   'pm10': 40,
#   'pm10_avg': 31,
#   'pm2.5': 13,
#   'pm2.5_avg': 11.2,
#   'pollutant': None,
#   'siteid': 14,
#   'sitename': '古亭',
#   'so2': 1.4,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 67,
#   'windspeed': 1.8},
#  {'aqi': 39,
#   'co': 0.34,
#   'co_8hr': 0.3,
#   'county': '臺北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.046503,
#   'longitude': 121.507972,
#   'no': 2.2,
#   'no2': 16.8,
#   'nox': 19.1,
#   'o3': 32.1,
#   'o3_8hr': 22.5,
#   'pm10': 37,
#   'pm10_avg': 32,
#   'pm2.5': 16,
#   'pm2.5_avg': 11.9,
#   'pollutant': None,
#   'siteid': 13,
#   'sitename': '萬華',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 94,
#   'windspeed': 2.9},
#  {'aqi': 45,
#   'co': 0.42,
#   'co_8hr': 0.4,
#   'county': '臺北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.062361,
#   'longitude': 121.526528,
#   'no': 2.8,
#   'no2': 17.3,
#   'nox': 20.1,
#   'o3': 34.1,
#   'o3_8hr': 27,
#   'pm10': 42,
#   'pm10_avg': 32,
#   'pm2.5': 16,
#   'pm2.5_avg': 14,
#   'pollutant': None,
#   'siteid': 12,
#   'sitename': '中山',
#   'so2': 0.9,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 62,
#   'windspeed': 2},
#  {'aqi': 36,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '臺北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.10334003,
#   'longitude': 121.51666356,
#   'no': 0.6,
#   'no2': 5.7,
#   'nox': 6.3,
#   'o3': 47.6,
#   'o3_8hr': 39.4,
#   'pm10': 30,
#   'pm10_avg': 27,
#   'pm2.5': 19,
#   'pm2.5_avg': 10.1,
#   'pollutant': None,
#   'siteid': 11,
#   'sitename': '士林',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 49,
#   'windspeed': 2.3},
#  {'aqi': 36,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.1645,
#   'longitude': 121.449239,
#   'no': 0.9,
#   'no2': 3.3,
#   'nox': 4.3,
#   'o3': 48,
#   'o3_8hr': 39.8,
#   'pm10': 40,
#   'pm10_avg': 28,
#   'pm2.5': 12,
#   'pm2.5_avg': 10.6,
#   'pollutant': None,
#   'siteid': 10,
#   'sitename': '淡水',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': None,
#   'windspeed': None},
#  {'aqi': 31,
#   'co': 0.26,
#   'co_8hr': 0.2,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.07798949,
#   'longitude': 121.36548982,
#   'no': 1.3,
#   'no2': 7.8,
#   'nox': 9.2,
#   'o3': 40,
#   'o3_8hr': 29.2,
#   'pm10': 32,
#   'pm10_avg': 29,
#   'pm2.5': 12,
#   'pm2.5_avg': 9.7,
#   'pollutant': None,
#   'siteid': 9,
#   'sitename': '林口',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 58,
#   'windspeed': 3.1},
#  {'aqi': 40,
#   'co': 0.32,
#   'co_8hr': 0.3,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.06895,
#   'longitude': 121.481028,
#   'no': 0.7,
#   'no2': 10.1,
#   'nox': 10.8,
#   'o3': 43.9,
#   'o3_8hr': 35.6,
#   'pm10': 36,
#   'pm10_avg': 26,
#   'pm2.5': 16,
#   'pm2.5_avg': 12.2,
#   'pollutant': None,
#   'siteid': 8,
#   'sitename': '菜寮',
#   'so2': 0.7,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 75,
#   'windspeed': 3.5},
#  {'aqi': 41,
#   'co': 0.28,
#   'co_8hr': 0.3,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.037972,
#   'longitude': 121.4325,
#   'no': 0.6,
#   'no2': 6.9,
#   'nox': 7.5,
#   'o3': 44.9,
#   'o3_8hr': 34.4,
#   'pm10': 47,
#   'pm10_avg': 34,
#   'pm2.5': 17,
#   'pm2.5_avg': 12.7,
#   'pollutant': None,
#   'siteid': 7,
#   'sitename': '新莊',
#   'so2': 1.1,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 68,
#   'windspeed': 5.7},
#  {'aqi': 34,
#   'co': 0.36,
#   'co_8hr': 0.3,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.012972,
#   'longitude': 121.458667,
#   'no': 1,
#   'no2': 13.7,
#   'nox': 14.7,
#   'o3': 43.3,
#   'o3_8hr': 34.7,
#   'pm10': 41,
#   'pm10_avg': 29,
#   'pm2.5': 14,
#   'pm2.5_avg': 10.4,
#   'pollutant': None,
#   'siteid': 6,
#   'sitename': '板橋',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 55,
#   'windspeed': 3},
#  {'aqi': 37,
#   'co': 0.35,
#   'co_8hr': 0.3,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.982528,
#   'longitude': 121.451861,
#   'no': 0.6,
#   'no2': 11.6,
#   'nox': 12.3,
#   'o3': 40.4,
#   'o3_8hr': 32.4,
#   'pm10': 34,
#   'pm10_avg': 29,
#   'pm2.5': 10,
#   'pm2.5_avg': 11.5,
#   'pollutant': None,
#   'siteid': 5,
#   'sitename': '土城',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 145,
#   'windspeed': 1.9},
#  {'aqi': 49,
#   'co': 0.33,
#   'co_8hr': 0.3,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.977222,
#   'longitude': 121.537778,
#   'no': 0.7,
#   'no2': 10.1,
#   'nox': 10.9,
#   'o3': 37.7,
#   'o3_8hr': 29.2,
#   'pm10': 40,
#   'pm10_avg': 27,
#   'pm2.5': 17,
#   'pm2.5_avg': 15.1,
#   'pollutant': None,
#   'siteid': 4,
#   'sitename': '新店',
#   'so2': 0.6,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 118,
#   'windspeed': 1.9},
#  {'aqi': 82,
#   'co': 0.23,
#   'co_8hr': 0.2,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.179667,
#   'longitude': 121.689881,
#   'no': 0.5,
#   'no2': 2.9,
#   'nox': 3.5,
#   'o3': 53.9,
#   'o3_8hr': 48.2,
#   'pm10': 95,
#   'pm10_avg': 82,
#   'pm2.5': 17,
#   'pm2.5_avg': 16.3,
#   'pollutant': '懸浮微粒',
#   'siteid': 3,
#   'sitename': '萬里',
#   'so2': 0.1,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 45,
#   'windspeed': 5.9},
#  {'aqi': 39,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.06624,
#   'longitude': 121.64081,
#   'no': 1.2,
#   'no2': 9.8,
#   'nox': 11,
#   'o3': 40.9,
#   'o3_8hr': 33.3,
#   'pm10': 38,
#   'pm10_avg': 28,
#   'pm2.5': 15,
#   'pm2.5_avg': 12,
#   'pollutant': None,
#   'siteid': 2,
#   'sitename': '汐止',
#   'so2': 1.7,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 42,
#   'windspeed': 1.1},
#  {'aqi': 39,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '基隆市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.129167,
#   'longitude': 121.760056,
#   'no': 0.1,
#   'no2': 4,
#   'nox': 4.2,
#   'o3': 48.7,
#   'o3_8hr': 42.9,
#   'pm10': 41,
#   'pm10_avg': 31,
#   'pm2.5': 12,
#   'pm2.5_avg': 8.9,
#   'pollutant': None,
#   'siteid': 1,
#   'sitename': '基隆',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 89,
#   'windspeed': 2.4},
#  {'aqi': 41,
#   'co': 0.24,
#   'co_8hr': 0.1,
#   'county': '屏東縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 22.260899,
#   'longitude': 120.651472,
#   'no': 0.2,
#   'no2': 2.7,
#   'nox': 2.9,
#   'o3': 39.7,
#   'o3_8hr': 44.4,
#   'pm10': 21,
#   'pm10_avg': 28,
#   'pm2.5': 6,
#   'pm2.5_avg': 9.2,
#   'pollutant': None,
#   'siteid': 313,
#   'sitename': '屏東(枋山)',
#   'so2': 0,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 88,
#   'windspeed': 6.9},
#  {'aqi': 34,
#   'co': 0.34,
#   'co_8hr': 0.3,
#   'county': '花蓮縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.97709367,
#   'longitude': 121.61575076,
#   'no': 1.4,
#   'no2': 5.4,
#   'nox': 6.8,
#   'o3': 42.8,
#   'o3_8hr': 37.5,
#   'pm10': 25,
#   'pm10_avg': 25,
#   'pm2.5': 12,
#   'pm2.5_avg': 10.1,
#   'pollutant': None,
#   'siteid': 312,
#   'sitename': '花蓮（美崙）',
#   'so2': 0,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 38,
#   'windspeed': 4.7},
#  {'aqi': 38,
#   'co': 0.43,
#   'co_8hr': 0.4,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 24.94902778,
#   'longitude': 121.38352778,
#   'no': 8.5,
#   'no2': 23.7,
#   'nox': 32.2,
#   'o3': 26.8,
#   'o3_8hr': 21.1,
#   'pm10': 39,
#   'pm10_avg': 27,
#   'pm2.5': 14,
#   'pm2.5_avg': 10.5,
#   'pollutant': None,
#   'siteid': 311,
#   'sitename': '新北(樹林)',
#   'so2': 0.7,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 140,
#   'windspeed': 0},
#  {'aqi': 57,
#   'co': 0.36,
#   'co_8hr': 0.3,
#   'county': '屏東縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 22.35222,
#   'longitude': 120.37722,
#   'no': 0.9,
#   'no2': 9.7,
#   'nox': 10.6,
#   'o3': 48.3,
#   'o3_8hr': 56.3,
#   'pm10': 55,
#   'pm10_avg': 47,
#   'pm2.5': 19,
#   'pm2.5_avg': 18,
#   'pollutant': '細懸浮微粒',
#   'siteid': 204,
#   'sitename': '屏東（琉球）',
#   'so2': 1.4,
#   'so2_avg': 2,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 315,
#   'windspeed': 3.2},
#  {'aqi': 79,
#   'co': 0.41,
#   'co_8hr': 0.2,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.17904722,
#   'longitude': 120.24583056,
#   'no': 0.4,
#   'no2': 14,
#   'nox': 14.5,
#   'o3': 22.2,
#   'o3_8hr': 40.1,
#   'pm10': 105,
#   'pm10_avg': 79,
#   'pm2.5': 18,
#   'pm2.5_avg': 14,
#   'pollutant': '懸浮微粒',
#   'siteid': 203,
#   'sitename': '臺南（麻豆）',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 9,
#   'windspeed': 3.1},
#  {'aqi': 61,
#   'co': 0.4,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 22.87985556,
#   'longitude': 120.24535,
#   'no': 0,
#   'no2': 14,
#   'nox': 13.9,
#   'o3': 32.1,
#   'o3_8hr': 43.3,
#   'pm10': 113,
#   'pm10_avg': 61,
#   'pm2.5': 12,
#   'pm2.5_avg': 8.5,
#   'pollutant': '懸浮微粒',
#   'siteid': 202,
#   'sitename': '高雄（湖內）',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 303,
#   'windspeed': 1.4},
#  {'aqi': 31,
#   'co': 0.4,
#   'co_8hr': 0.3,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.96117,
#   'longitude': 120.56373,
#   'no': 2.1,
#   'no2': 13.7,
#   'nox': 15.8,
#   'o3': 22.7,
#   'o3_8hr': 33.5,
#   'pm10': 26,
#   'pm10_avg': 30,
#   'pm2.5': 9,
#   'pm2.5_avg': 8,
#   'pollutant': None,
#   'siteid': 201,
#   'sitename': '彰化（員林）',
#   'so2': 1.3,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 352,
#   'windspeed': 1.9},
#  {'aqi': 39,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.85493056,
#   'longitude': 120.26964167,
#   'no': 1,
#   'no2': 6,
#   'nox': 7.1,
#   'o3': 37.1,
#   'o3_8hr': 42.1,
#   'pm10': 24,
#   'pm10_avg': 30,
#   'pm2.5': 14,
#   'pm2.5_avg': 11,
#   'pollutant': None,
#   'siteid': 85,
#   'sitename': '大城',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 45,
#   'windspeed': 9},
#  {'aqi': 48,
#   'co': 0.2,
#   'co_8hr': 0.2,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 25.29681695,
#   'longitude': 121.53656894,
#   'no': 0.1,
#   'no2': 1.8,
#   'nox': 1.9,
#   'o3': 54.8,
#   'o3_8hr': 46.4,
#   'pm10': 54,
#   'pm10_avg': 48,
#   'pm2.5': 18,
#   'pm2.5_avg': 13,
#   'pollutant': None,
#   'siteid': 84,
#   'sitename': '富貴角',
#   'so2': 0.3,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 51,
#   'windspeed': 10.7},
#  {'aqi': 70,
#   'co': 0.3,
#   'co_8hr': 0.3,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.753506,
#   'longitude': 120.251825,
#   'no': 1,
#   'no2': 7.3,
#   'nox': 8.3,
#   'o3': 34.5,
#   'o3_8hr': 40.5,
#   'pm10': 62,
#   'pm10_avg': 70,
#   'pm2.5': 14,
#   'pm2.5_avg': 11.7,
#   'pollutant': '懸浮微粒',
#   'siteid': 83,
#   'sitename': '麥寮',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 3,
#   'windspeed': 7.4},
#  {'aqi': 39,
#   'co': 0.33,
#   'co_8hr': 0.2,
#   'county': '臺東縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.045083,
#   'longitude': 121.161933,
#   'no': 0.3,
#   'no2': 5.1,
#   'nox': 5.4,
#   'o3': 30.9,
#   'o3_8hr': 33.2,
#   'pm10': 16,
#   'pm10_avg': 39,
#   'pm2.5': 6,
#   'pm2.5_avg': 5.3,
#   'pollutant': None,
#   'siteid': 80,
#   'sitename': '關山',
#   'so2': 0.9,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 37,
#   'windspeed': 2.6},
#  {'aqi': 35,
#   'co': 0.29,
#   'co_8hr': 0.3,
#   'county': '澎湖縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.569031,
#   'longitude': 119.566158,
#   'no': 0.8,
#   'no2': 3.4,
#   'nox': 4.2,
#   'o3': 41,
#   'o3_8hr': 38.2,
#   'pm10': 16,
#   'pm10_avg': 13,
#   'pm2.5': 9,
#   'pm2.5_avg': 5.2,
#   'pollutant': None,
#   'siteid': 78,
#   'sitename': '馬公',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 39,
#   'windspeed': 7.3},
#  {'aqi': 46,
#   'co': 0.38,
#   'co_8hr': 0.3,
#   'county': '金門縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 24.432133,
#   'longitude': 118.312256,
#   'no': 0.8,
#   'no2': 6.8,
#   'nox': 7.7,
#   'o3': 37,
#   'o3_8hr': 50.4,
#   'pm10': 22,
#   'pm10_avg': 21,
#   'pm2.5': 11,
#   'pm2.5_avg': 8.4,
#   'pollutant': None,
#   'siteid': 77,
#   'sitename': '金門',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 86,
#   'windspeed': 2.1},
#  {'aqi': 39,
#   'co': 0.27,
#   'co_8hr': 0.3,
#   'county': '連江縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 26.153736,
#   'longitude': 119.952724,
#   'no': 0.9,
#   'no2': 4.3,
#   'nox': 5.3,
#   'o3': 53,
#   'o3_8hr': 42.9,
#   'pm10': 34,
#   'pm10_avg': 24,
#   'pm2.5': 10,
#   'pm2.5_avg': 9.6,
#   'pollutant': None,
#   'siteid': 75,
#   'sitename': '馬祖',
#   'so2': 0.6,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 330,
#   'windspeed': 1},
#  {'aqi': 47,
#   'co': 0.4,
#   'co_8hr': 0.2,
#   'county': '南投縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.968842,
#   'longitude': 120.967903,
#   'no': 1.2,
#   'no2': 11.2,
#   'nox': 12.4,
#   'o3': 33.7,
#   'o3_8hr': 36.2,
#   'pm10': 23,
#   'pm10_avg': 17,
#   'pm2.5': 15,
#   'pm2.5_avg': 14.5,
#   'pollutant': None,
#   'siteid': 72,
#   'sitename': '埔里',
#   'so2': 1.7,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 310,
#   'windspeed': 0.5},
#  {'aqi': 56,
#   'co': 0.58,
#   'co_8hr': 0.4,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 22.608711,
#   'longitude': 120.312017,
#   'no': 1.8,
#   'no2': 21.2,
#   'nox': 23.1,
#   'o3': 33.8,
#   'o3_8hr': 43.1,
#   'pm10': 80,
#   'pm10_avg': 54,
#   'pm2.5': 19,
#   'pm2.5_avg': 17.5,
#   'pollutant': '細懸浮微粒',
#   'siteid': 71,
#   'sitename': '復興',
#   'so2': 1.5,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 282,
#   'windspeed': 2},
#  {'aqi': 34,
#   'co': 0.48,
#   'co_8hr': 0.4,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 25.017,
#   'longitude': 121.516306,
#   'no': 3.6,
#   'no2': 15.4,
#   'nox': 19,
#   'o3': 36.7,
#   'o3_8hr': 29.7,
#   'pm10': 39,
#   'pm10_avg': 29,
#   'pm2.5': 14,
#   'pm2.5_avg': 10.4,
#   'pollutant': None,
#   'siteid': 70,
#   'sitename': '永和',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 73,
#   'windspeed': 2.7},
#  {'aqi': 37,
#   'co': 0.43,
#   'co_8hr': 0.3,
#   'county': '南投縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.756389,
#   'longitude': 120.677306,
#   'no': 0.6,
#   'no2': 17.1,
#   'nox': 17.8,
#   'o3': 19,
#   'o3_8hr': 39.8,
#   'pm10': 33,
#   'pm10_avg': 28,
#   'pm2.5': 18,
#   'pm2.5_avg': 11.4,
#   'pollutant': None,
#   'siteid': 69,
#   'sitename': '竹山',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 23,
#   'windspeed': 2},
#  {'aqi': 47,
#   'co': 0.8,
#   'co_8hr': 0.7,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 24.953278,
#   'longitude': 121.221667,
#   'no': 20.9,
#   'no2': 28,
#   'nox': 49,
#   'o3': 22.9,
#   'o3_8hr': 16.2,
#   'pm10': 41,
#   'pm10_avg': 27,
#   'pm2.5': 14,
#   'pm2.5_avg': 12,
# ...
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.63390278,
#   'longitude': 120.28676111,
#   'no': 2.6,
#   'no2': 11,
#   'nox': 13.6,
#   'o3': 48.2,
#   'o3_8hr': 31.9,
#   'pm10': 47,
#   'pm10_avg': 52,
#   'pm2.5': 16,
#   'pm2.5_avg': 16.6,
#   'pollutant': '細懸浮微粒',
#   'siteid': 56,
#   'sitename': '前金',
#   'so2': 1.1,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 356,
#   'windspeed': 4.1},
#  {'aqi': 55,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.674861,
#   'longitude': 120.292917,
#   'no': 1.2,
#   'no2': 6.3,
#   'nox': 7.5,
#   'o3': 52.6,
#   'o3_8hr': 33.6,
#   'pm10': 41,
#   'pm10_avg': 43,
#   'pm2.5': 19,
#   'pm2.5_avg': 17,
#   'pollutant': '細懸浮微粒',
#   'siteid': 54,
#   'sitename': '左營',
#   'so2': 1.3,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 359,
#   'windspeed': 4},
#  {'aqi': 48,
#   'co': 0.22,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.733667,
#   'longitude': 120.328289,
#   'no': 1.1,
#   'no2': 8.8,
#   'nox': 9.9,
#   'o3': 51.9,
#   'o3_8hr': 32.4,
#   'pm10': 41,
#   'pm10_avg': 46,
#   'pm2.5': 14,
#   'pm2.5_avg': 14.8,
#   'pollutant': None,
#   'siteid': 53,
#   'sitename': '楠梓',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 25,
#   'windspeed': 2.6},
#  {'aqi': 62,
#   'co': 0.29,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.4795,
#   'longitude': 120.41175,
#   'no': 0.8,
#   'no2': 8.8,
#   'nox': 9.7,
#   'o3': 50.6,
#   'o3_8hr': 34.3,
#   'pm10': 29,
#   'pm10_avg': 40,
#   'pm2.5': 11,
#   'pm2.5_avg': 20.1,
#   'pollutant': '細懸浮微粒',
#   'siteid': 52,
#   'sitename': '林園',
#   'so2': 2,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 1,
#   'windspeed': 2.1},
#  {'aqi': 57,
#   'co': 0.2,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.56413611,
#   'longitude': 120.425311,
#   'no': 1.2,
#   'no2': 8.7,
#   'nox': 9.9,
#   'o3': 48.9,
#   'o3_8hr': 30.9,
#   'pm10': 20,
#   'pm10_avg': 24,
#   'pm2.5': 13,
#   'pm2.5_avg': 17.8,
#   'pollutant': '細懸浮微粒',
#   'siteid': 51,
#   'sitename': '大寮',
#   'so2': 1,
#   'so2_avg': 2,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 359,
#   'windspeed': 1.7},
#  {'aqi': 59,
#   'co': 0.37,
#   'co_8hr': 0.4,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.628126,
#   'longitude': 120.357422,
#   'no': 2.8,
#   'no2': 12.1,
#   'nox': 15,
#   'o3': 45.4,
#   'o3_8hr': 28.8,
#   'pm10': 43,
#   'pm10_avg': 41,
#   'pm2.5': 14,
#   'pm2.5_avg': 18.9,
#   'pollutant': '細懸浮微粒',
#   'siteid': 50,
#   'sitename': '鳳山',
#   'so2': 0.7,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 269,
#   'windspeed': 1.5},
#  {'aqi': 59,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.689056,
#   'longitude': 120.332631,
#   'no': 2.2,
#   'no2': 8.9,
#   'nox': 11.1,
#   'o3': 49.3,
#   'o3_8hr': 29.4,
#   'pm10': 29,
#   'pm10_avg': 36,
#   'pm2.5': 15,
#   'pm2.5_avg': 18.6,
#   'pollutant': '細懸浮微粒',
#   'siteid': 49,
#   'sitename': '仁武',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 345,
#   'windspeed': 3.2},
#  {'aqi': 52,
#   'co': 0.22,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.757506,
#   'longitude': 120.305689,
#   'no': 1.6,
#   'no2': 8.7,
#   'nox': 10.3,
#   'o3': 50.1,
#   'o3_8hr': 32.2,
#   'pm10': 31,
#   'pm10_avg': 40,
#   'pm2.5': 11,
#   'pm2.5_avg': 16,
#   'pollutant': '細懸浮微粒',
#   'siteid': 48,
#   'sitename': '橋頭',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 10,
#   'windspeed': 2.9},
#  {'aqi': 33,
#   'co': 0.2,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.883583,
#   'longitude': 120.530542,
#   'no': 1.1,
#   'no2': 3.9,
#   'nox': 5,
#   'o3': 46,
#   'o3_8hr': 29.9,
#   'pm10': 19,
#   'pm10_avg': 23,
#   'pm2.5': 7,
#   'pm2.5_avg': 10.1,
#   'pollutant': None,
#   'siteid': 47,
#   'sitename': '美濃',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 293,
#   'windspeed': 1.5},
#  {'aqi': 35,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.98928311,
#   'longitude': 120.21947897,
#   'no': 0.6,
#   'no2': 7.1,
#   'nox': 7.8,
#   'o3': 48.6,
#   'o3_8hr': 32,
#   'pm10': 39,
#   'pm10_avg': 35,
#   'pm2.5': 11,
#   'pm2.5_avg': 8.8,
#   'pollutant': None,
#   'siteid': 46,
#   'sitename': '臺南',
#   'so2': 1.3,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 15,
#   'windspeed': 2.8},
#  {'aqi': 43,
#   'co': 0.26,
#   'co_8hr': 0.2,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.048197,
#   'longitude': 120.2175,
#   'no': 1.3,
#   'no2': 5.9,
#   'nox': 7.3,
#   'o3': 48.4,
#   'o3_8hr': 32.4,
#   'pm10': 44,
#   'pm10_avg': 43,
#   'pm2.5': 10,
#   'pm2.5_avg': 12.5,
#   'pollutant': None,
#   'siteid': 45,
#   'sitename': '安南',
#   'so2': 1.1,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 328,
#   'windspeed': 3.6},
#  {'aqi': 40,
#   'co': 0.19,
#   'co_8hr': 0.1,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.11337642,
#   'longitude': 120.29740529,
#   'no': 1.2,
#   'no2': 3.9,
#   'nox': 5.1,
#   'o3': 49.6,
#   'o3_8hr': 32.7,
#   'pm10': 39,
#   'pm10_avg': 40,
#   'pm2.5': 7,
#   'pm2.5_avg': 9.2,
#   'pollutant': None,
#   'siteid': 44,
#   'sitename': '善化',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 8,
#   'windspeed': 5.2},
#  {'aqi': 45,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.305633,
#   'longitude': 120.31725,
#   'no': 1.4,
#   'no2': 6.7,
#   'nox': 8.2,
#   'o3': 46.8,
#   'o3_8hr': 30.3,
#   'pm10': 49,
#   'pm10_avg': 45,
#   'pm2.5': 13,
#   'pm2.5_avg': 10.5,
#   'pollutant': None,
#   'siteid': 43,
#   'sitename': '新營',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 25,
#   'windspeed': 3.4},
#  {'aqi': 36,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '嘉義市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.46477865,
#   'longitude': 120.44125148,
#   'no': 1.1,
#   'no2': 4.4,
#   'nox': 5.5,
#   'o3': 51.1,
#   'o3_8hr': 30.9,
#   'pm10': 33,
#   'pm10_avg': 35,
#   'pm2.5': 8,
#   'pm2.5_avg': 11.1,
#   'pollutant': None,
#   'siteid': 42,
#   'sitename': '嘉義',
#   'so2': 1.1,
#   'so2_avg': 2,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 13,
#   'windspeed': 2.5},
#  {'aqi': 34,
#   'co': 0.32,
#   'co_8hr': 0.2,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.702175,
#   'longitude': 120.19933333,
#   'no': 1.6,
#   'no2': 7.3,
#   'nox': 9,
#   'o3': 42.7,
#   'o3_8hr': 31.8,
#   'pm10': 37,
#   'pm10_avg': 34,
#   'pm2.5': 6,
#   'pm2.5_avg': 5.2,
#   'pollutant': None,
#   'siteid': 41,
#   'sitename': '臺西',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 19,
#   'windspeed': 6.8},
#  {'aqi': 50,
#   'co': 0.23,
#   'co_8hr': 0.2,
#   'county': '嘉義縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.46538,
#   'longitude': 120.2478,
#   'no': 2.4,
#   'no2': 4.6,
#   'nox': 7,
#   'o3': 46.7,
#   'o3_8hr': 31.2,
#   'pm10': 38,
#   'pm10_avg': 50,
#   'pm2.5': 10,
#   'pm2.5_avg': 7.3,
#   'pollutant': None,
#   'siteid': 40,
#   'sitename': '朴子',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 345,
#   'windspeed': 2.8},
#  {'aqi': 34,
#   'co': 0.22,
#   'co_8hr': 0.1,
#   'county': '嘉義縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.554839,
#   'longitude': 120.345531,
#   'no': 0.9,
#   'no2': 6.1,
#   'nox': 7.1,
#   'o3': 49,
#   'o3_8hr': 32.6,
#   'pm10': 26,
#   'pm10_avg': 34,
#   'pm2.5': 14,
#   'pm2.5_avg': 8.9,
#   'pollutant': None,
#   'siteid': 39,
#   'sitename': '新港',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 7,
#   'windspeed': 3.5},
#  {'aqi': 63,
#   'co': 0.31,
#   'co_8hr': 0.2,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.757547,
#   'longitude': 120.348742,
#   'no': 1.2,
#   'no2': 5.1,
#   'nox': 6.4,
#   'o3': 46.4,
#   'o3_8hr': 28,
#   'pm10': 33,
#   'pm10_avg': 63,
#   'pm2.5': 8,
#   'pm2.5_avg': 9.8,
#   'pollutant': '懸浮微粒',
#   'siteid': 38,
#   'sitename': '崙背',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 323,
#   'windspeed': 2.5},
#  {'aqi': 41,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.711853,
#   'longitude': 120.544994,
#   'no': 0.9,
#   'no2': 4.6,
#   'nox': 5.6,
#   'o3': 52.3,
#   'o3_8hr': 31.3,
#   'pm10': 16,
#   'pm10_avg': 41,
#   'pm2.5': 5,
#   'pm2.5_avg': 8.1,
#   'pollutant': None,
#   'siteid': 37,
#   'sitename': '斗六',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 10,
#   'windspeed': 1.5},
#  {'aqi': 27,
#   'co': 0.28,
#   'co_8hr': 0.3,
#   'county': '南投縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.913,
#   'longitude': 120.685306,
#   'no': 1.8,
#   'no2': 7.5,
#   'nox': 9.4,
#   'o3': 48.3,
#   'o3_8hr': 26.4,
#   'pm10': 9,
#   'pm10_avg': 19,
#   'pm2.5': 4,
#   'pm2.5_avg': 8.3,
#   'pollutant': None,
#   'siteid': 36,
#   'sitename': '南投',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 221,
#   'windspeed': 1.6},
#  {'aqi': 29,
#   'co': 0.34,
#   'co_8hr': 0.2,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.925175,
#   'longitude': 120.409653,
#   'no': 1.4,
#   'no2': 6.1,
#   'nox': 7.5,
#   'o3': 49.4,
#   'o3_8hr': 31.5,
#   'pm10': 24,
#   'pm10_avg': 26,
#   'pm2.5': 6,
#   'pm2.5_avg': 6.2,
#   'pollutant': None,
#   'siteid': 35,
#   'sitename': '二林',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 352,
#   'windspeed': 4.9},
#  {'aqi': 26,
#   'co': 0.36,
#   'co_8hr': 0.2,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.131672,
#   'longitude': 120.469061,
#   'no': 2.4,
#   'no2': 8.6,
#   'nox': 11,
#   'o3': 39.8,
#   'o3_8hr': 28.8,
#   'pm10': 22,
#   'pm10_avg': 17,
#   'pm2.5': 3,
#   'pm2.5_avg': 5,
#   'pollutant': None,
#   'siteid': 34,
#   'sitename': '線西',
#   'so2': 1.9,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 14,
#   'windspeed': 7.4},
#  {'aqi': 22,
#   'co': 0.34,
#   'co_8hr': 0.3,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.066,
#   'longitude': 120.541519,
#   'no': None,
#   'no2': None,
#   'nox': None,
#   'o3': 30.1,
#   'o3_8hr': 24.6,
#   'pm10': None,
#   'pm10_avg': 13,
#   'pm2.5': None,
#   'pm2.5_avg': 6.8,
#   'pollutant': None,
#   'siteid': 33,
#   'sitename': '彰化',
#   'so2': 0.4,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 5,
#   'windspeed': 2.7},
#  {'aqi': 24,
#   'co': 0.3,
#   'co_8hr': 0.2,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.162197,
#   'longitude': 120.616917,
#   'no': 2.6,
#   'no2': 8.1,
#   'nox': 10.7,
#   'o3': 38.6,
#   'o3_8hr': 27,
#   'pm10': 15,
#   'pm10_avg': 22,
#   'pm2.5': 4,
#   'pm2.5_avg': 6.1,
#   'pollutant': None,
#   'siteid': 32,
#   'sitename': '西屯',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 352,
#   'windspeed': 4.4},
#  {'aqi': 23,
#   'co': 0.36,
#   'co_8hr': 0.2,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.151958,
#   'longitude': 120.641092,
#   'no': 3.5,
#   'no2': 10.1,
#   'nox': 13.7,
#   'o3': 37.2,
#   'o3_8hr': 25.9,
#   'pm10': 10,
#   'pm10_avg': 14,
#   'pm2.5': 4,
#   'pm2.5_avg': 5.9,
#   'pollutant': None,
#   'siteid': 31,
#   'sitename': '忠明',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 283,
#   'windspeed': 2.2},
#  {'aqi': 25,
#   'co': 0.36,
#   'co_8hr': 0.2,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.09961111,
#   'longitude': 120.67844444,
#   'no': 3.2,
#   'no2': 9.4,
#   'nox': 12.6,
#   'o3': 40.6,
#   'o3_8hr': 27.2,
#   'pm10': 9,
#   'pm10_avg': 15,
#   'pm2.5': 4,
#   'pm2.5_avg': 7.7,
#   'pollutant': None,
#   'siteid': 30,
#   'sitename': '大里',
#   'so2': 1.3,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 297,
#   'windspeed': 3.1},
#  {'aqi': 25,
#   'co': 0.32,
#   'co_8hr': 0.2,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.225628,
#   'longitude': 120.568794,
#   'no': 2.1,
#   'no2': 6.5,
#   'nox': 8.6,
#   'o3': 40.6,
#   'o3_8hr': 27.7,
#   'pm10': 9,
#   'pm10_avg': 15,
#   'pm2.5': 6,
#   'pm2.5_avg': 5.7,
#   'pollutant': None,
#   'siteid': 29,
#   'sitename': '沙鹿',
#   'so2': 0.9,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 338,
#   'windspeed': 5.2},
#  {'aqi': 28,
#   'co': 0.3,
#   'co_8hr': 0.2,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.25699731,
#   'longitude': 120.74252414,
#   'no': 1.2,
#   'no2': 5.1,
#   'nox': 6.3,
#   'o3': 40.2,
#   'o3_8hr': 30.6,
#   'pm10': 8,
#   'pm10_avg': 9,
#   'pm2.5': 4,
#   'pm2.5_avg': 7.4,
#   'pollutant': None,
#   'siteid': 28,
#   'sitename': '豐原',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 330,
#   'windspeed': 3.8},
#  {'aqi': 23,
#   'co': 0.31,
#   'co_8hr': 0.2,
#   'county': '苗栗縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.38248443,
#   'longitude': 120.75956754,
#   'no': 2.3,
#   'no2': 4.3,
#   'nox': 6.6,
#   'o3': 33.8,
#   'o3_8hr': 25.2,
#   'pm10': 9,
#   'pm10_avg': 8,
#   'pm2.5': 2,
#   'pm2.5_avg': 3.9,
#   'pollutant': None,
#   'siteid': 27,
#   'sitename': '三義',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 12,
#   'windspeed': 6.2},
#  {'aqi': 19,
#   'co': 0.32,
#   'co_8hr': 0.2,
#   'county': '苗栗縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.56499183,
#   'longitude': 120.82011468,
#   'no': 2.3,
#   'no2': 6,
#   'nox': 8.3,
#   'o3': 32.2,
#   'o3_8hr': 21.4,
#   'pm10': 9,
#   'pm10_avg': 12,
#   'pm2.5': 3,
#   'pm2.5_avg': 4.9,
#   'pollutant': None,
#   'siteid': 26,
#   'sitename': '苗栗',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 6,
#   'windspeed': 5},
#  {'aqi': 19,
#   'co': 0.36,
#   'co_8hr': 0.3,
#   'county': '苗栗縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.69690679,
#   'longitude': 120.89869286,
#   'no': 3.6,
#   'no2': 6.9,
#   'nox': 10.6,
#   'o3': 28.8,
#   'o3_8hr': 21.5,
#   'pm10': 6,
#   'pm10_avg': 10,
#   'pm2.5': 6,
#   'pm2.5_avg': 5.8,
#   'pollutant': None,
#   'siteid': 25,
#   'sitename': '頭份',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 10,
#   'windspeed': 4.6},
#  {'aqi': 19,
#   'co': 0.39,
#   'co_8hr': 0.3,
#   'county': '新竹市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.8056356,
#   'longitude': 120.97236752,
#   'no': 3.1,
#   'no2': 9.7,
#   'nox': 12.8,
#   'o3': 24.7,
#   'o3_8hr': 21.8,
#   'pm10': 4,
#   'pm10_avg': 8,
#   'pm2.5': 4,
#   'pm2.5_avg': 3.3,
#   'pollutant': None,
#   'siteid': 24,
#   'sitename': '新竹',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 28,
#   'windspeed': 4.4},
#  {'aqi': 19,
#   'co': 0.32,
#   'co_8hr': 0.2,
#   'county': '新竹縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.74091408,
#   'longitude': 121.08895493,
#   'no': 1.7,
#   'no2': 5,
#   'nox': 6.7,
#   'o3': 31.4,
#   'o3_8hr': 21.2,
#   'pm10': 7,
#   'pm10_avg': 9,
#   'pm2.5': 0,
#   'pm2.5_avg': 4.4,
#   'pollutant': None,
#   'siteid': 23,
#   'sitename': '竹東',
#   'so2': 0.3,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 19,
#   'windspeed': 3.1},
#  {'aqi': 21,
#   'co': 0.38,
#   'co_8hr': 0.3,
#   'county': '新竹縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.90009696,
#   'longitude': 121.03886894,
#   'no': 2,
#   'no2': 8.9,
#   'nox': 10.9,
#   'o3': 22.8,
#   'o3_8hr': 23,
#   'pm10': 8,
#   'pm10_avg': 9,
#   'pm2.5': 5,
#   'pm2.5_avg': 5.2,
#   'pollutant': None,
#   'siteid': 22,
#   'sitename': '湖口',
#   'so2': 2.5,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 37,
#   'windspeed': 6},
#  {'aqi': 20,
#   'co': 0.34,
#   'co_8hr': 0.3,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.86400048,
#   'longitude': 121.21645772,
#   'no': 2.3,
#   'no2': 5.9,
#   'nox': 8.2,
#   'o3': 30.6,
#   'o3_8hr': 20.9,
#   'pm10': 14,
#   'pm10_avg': 11,
#   'pm2.5': 4,
#   'pm2.5_avg': 6.3,
#   'pollutant': None,
#   'siteid': 21,
#   'sitename': '龍潭',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 57,
#   'windspeed': 6.4}]

# %%
from openpyxl import load_workbook, Workbook, worksheet

wb:Workbook = load_workbook('aqi.xlsx')
from pprint import pprint
sheet:worksheet = wb.worksheets[0]
sheets:list = []
column_names:list[str] =[cell.value for cell in list(sheet)[0]]
for row in list(sheet)[1:]:
    site:dict = {column_names[idx]:cell.value for idx,cell in enumerate(row)}    
    sheets.append(site)

pprint(sheets)
# Out:
# [{'aqi': 40,
#   'co': 0.24,
#   'co_8hr': 0.1,
#   'county': '屏東縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.260899,
#   'longitude': 120.651472,
#   'no': 0.2,
#   'no2': 2.4,
#   'nox': 2.6,
#   'o3': 39.4,
#   'o3_8hr': 43.6,
#   'pm10': 17,
#   'pm10_avg': 27,
#   'pm2.5': 6,
#   'pm2.5_avg': 8.7,
#   'pollutant': None,
#   'siteid': 313,
#   'sitename': '屏東(枋山)',
#   'so2': 0,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 90,
#   'windspeed': 5.7},
#  {'aqi': 36,
#   'co': 0.33,
#   'co_8hr': 0.3,
#   'county': '花蓮縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.97709367,
#   'longitude': 121.61575076,
#   'no': 0.8,
#   'no2': 3.8,
#   'nox': 4.6,
#   'o3': 47.7,
#   'o3_8hr': 39.3,
#   'pm10': 26,
#   'pm10_avg': 25,
#   'pm2.5': 12,
#   'pm2.5_avg': 10.8,
#   'pollutant': None,
#   'siteid': 312,
#   'sitename': '花蓮（美崙）',
#   'so2': 0,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 33,
#   'windspeed': 5},
#  {'aqi': 37,
#   'co': 0.41,
#   'co_8hr': 0.4,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.94902778,
#   'longitude': 121.38352778,
#   'no': 4.9,
#   'no2': 19.7,
#   'nox': 24.6,
#   'o3': 29.1,
#   'o3_8hr': 23.6,
#   'pm10': 40,
#   'pm10_avg': 30,
#   'pm2.5': 16,
#   'pm2.5_avg': 11.4,
#   'pollutant': None,
#   'siteid': 311,
#   'sitename': '新北(樹林)',
#   'so2': 0.3,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 141,
#   'windspeed': 0},
#  {'aqi': 57,
#   'co': 0.4,
#   'co_8hr': 0.3,
#   'county': '屏東縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.35222,
#   'longitude': 120.37722,
#   'no': 0.8,
#   'no2': 12.5,
#   'nox': 13.4,
#   'o3': 39,
#   'o3_8hr': 55.2,
#   'pm10': 86,
#   'pm10_avg': 54,
#   'pm2.5': 17,
#   'pm2.5_avg': 17.8,
#   'pollutant': '細懸浮微粒',
#   'siteid': 204,
#   'sitename': '屏東（琉球）',
#   'so2': 1.4,
#   'so2_avg': 2,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 320,
#   'windspeed': 3.2},
#  {'aqi': 80,
#   'co': 0.39,
#   'co_8hr': 0.3,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.17904722,
#   'longitude': 120.24583056,
#   'no': 0.4,
#   'no2': 16.8,
#   'nox': 17.3,
#   'o3': 16.3,
#   'o3_8hr': 37.8,
#   'pm10': 65,
#   'pm10_avg': 80,
#   'pm2.5': 16,
#   'pm2.5_avg': 14.5,
#   'pollutant': '懸浮微粒',
#   'siteid': 203,
#   'sitename': '臺南（麻豆）',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 12,
#   'windspeed': 3.4},
#  {'aqi': 73,
#   'co': 0.44,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.87985556,
#   'longitude': 120.24535,
#   'no': 0.2,
#   'no2': 16.8,
#   'nox': 17,
#   'o3': 20.2,
#   'o3_8hr': 41.4,
#   'pm10': 101,
#   'pm10_avg': 73,
#   'pm2.5': 14,
#   'pm2.5_avg': 9.9,
#   'pollutant': '懸浮微粒',
#   'siteid': 202,
#   'sitename': '高雄（湖內）',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 318,
#   'windspeed': 1.4},
#  {'aqi': 30,
#   'co': 0.34,
#   'co_8hr': 0.3,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.96117,
#   'longitude': 120.56373,
#   'no': 1.6,
#   'no2': 11,
#   'nox': 12.6,
#   'o3': 26.8,
#   'o3_8hr': 33,
#   'pm10': 22,
#   'pm10_avg': 27,
#   'pm2.5': 9,
#   'pm2.5_avg': 7.8,
#   'pollutant': None,
#   'siteid': 201,
#   'sitename': '彰化（員林）',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 355,
#   'windspeed': 1.5},
#  {'aqi': 40,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.85493056,
#   'longitude': 120.26964167,
#   'no': 0.4,
#   'no2': 6.8,
#   'nox': 7.2,
#   'o3': 37.5,
#   'o3_8hr': 42.1,
#   'pm10': 36,
#   'pm10_avg': 30,
#   'pm2.5': 16,
#   'pm2.5_avg': 12.2,
#   'pollutant': None,
#   'siteid': 85,
#   'sitename': '大城',
#   'so2': 1.5,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 47,
#   'windspeed': 8.6},
#  {'aqi': 49,
#   'co': 0.2,
#   'co_8hr': 0.2,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.29681695,
#   'longitude': 121.53656894,
#   'no': 0.1,
#   'no2': 1.6,
#   'nox': 1.7,
#   'o3': 54.8,
#   'o3_8hr': 49.2,
#   'pm10': 55,
#   'pm10_avg': 49,
#   'pm2.5': 18,
#   'pm2.5_avg': 14,
#   'pollutant': None,
#   'siteid': 84,
#   'sitename': '富貴角',
#   'so2': 0.3,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 51,
#   'windspeed': 9.1},
#  {'aqi': 65,
#   'co': 0.29,
#   'co_8hr': 0.3,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.753506,
#   'longitude': 120.251825,
#   'no': 1.1,
#   'no2': 7.6,
#   'nox': 8.8,
#   'o3': 34,
#   'o3_8hr': 40.3,
#   'pm10': 46,
#   'pm10_avg': 65,
#   'pm2.5': 19,
#   'pm2.5_avg': 13.3,
#   'pollutant': '懸浮微粒',
#   'siteid': 83,
#   'sitename': '麥寮',
#   'so2': 1.5,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 3,
#   'windspeed': 5.9},
#  {'aqi': 34,
#   'co': 0.31,
#   'co_8hr': 0.2,
#   'county': '臺東縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.045083,
#   'longitude': 121.161933,
#   'no': 0.3,
#   'no2': 4.2,
#   'nox': 4.5,
#   'o3': 31.7,
#   'o3_8hr': 33,
#   'pm10': 16,
#   'pm10_avg': 34,
#   'pm2.5': 5,
#   'pm2.5_avg': 5.2,
#   'pollutant': None,
#   'siteid': 80,
#   'sitename': '關山',
#   'so2': 0.9,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 32,
#   'windspeed': 2.3},
#  {'aqi': 37,
#   'co': 0.26,
#   'co_8hr': 0.3,
#   'county': '澎湖縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.569031,
#   'longitude': 119.566158,
#   'no': 0.8,
#   'no2': 2.7,
#   'nox': 3.5,
#   'o3': 46.3,
#   'o3_8hr': 40.2,
#   'pm10': 21,
#   'pm10_avg': 14,
#   'pm2.5': 8,
#   'pm2.5_avg': 5.7,
#   'pollutant': None,
#   'siteid': 78,
#   'sitename': '馬公',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 32,
#   'windspeed': 7.3},
#  {'aqi': 46,
#   'co': 0.37,
#   'co_8hr': 0.3,
#   'county': '金門縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.432133,
#   'longitude': 118.312256,
#   'no': 0.6,
#   'no2': 7.8,
#   'nox': 8.5,
#   'o3': 36.4,
#   'o3_8hr': 50.2,
#   'pm10': 23,
#   'pm10_avg': 21,
#   'pm2.5': 14,
#   'pm2.5_avg': 9.6,
#   'pollutant': None,
#   'siteid': 77,
#   'sitename': '金門',
#   'so2': 1.3,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 76,
#   'windspeed': 2.7},
#  {'aqi': 43,
#   'co': 0.26,
#   'co_8hr': 0.2,
#   'county': '連江縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 26.153736,
#   'longitude': 119.952724,
#   'no': 1,
#   'no2': 3.7,
#   'nox': 4.7,
#   'o3': 53.3,
#   'o3_8hr': 46.4,
#   'pm10': 34,
#   'pm10_avg': 26,
#   'pm2.5': 14,
#   'pm2.5_avg': 10.6,
#   'pollutant': None,
#   'siteid': 75,
#   'sitename': '馬祖',
#   'so2': 0.6,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 355,
#   'windspeed': 1.2},
#  {'aqi': 46,
#   'co': 0.42,
#   'co_8hr': 0.2,
#   'county': '南投縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.968842,
#   'longitude': 120.967903,
#   'no': 1.3,
#   'no2': 9.7,
#   'nox': 11,
#   'o3': 30.8,
#   'o3_8hr': 36.2,
#   'pm10': 21,
#   'pm10_avg': 18,
#   'pm2.5': 12,
#   'pm2.5_avg': 14.3,
#   'pollutant': None,
#   'siteid': 72,
#   'sitename': '埔里',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 321,
#   'windspeed': 0.3},
#  {'aqi': 68,
#   'co': 0.52,
#   'co_8hr': 0.4,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.608711,
#   'longitude': 120.312017,
#   'no': 1.5,
#   'no2': 19.2,
#   'nox': 20.7,
#   'o3': 28.5,
#   'o3_8hr': 42.4,
#   'pm10': 122,
#   'pm10_avg': 68,
#   'pm2.5': 21,
#   'pm2.5_avg': 18.4,
#   'pollutant': '懸浮微粒',
#   'siteid': 71,
#   'sitename': '復興',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 165,
#   'windspeed': 1.5},
#  {'aqi': 35,
#   'co': 0.44,
#   'co_8hr': 0.4,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.017,
#   'longitude': 121.516306,
#   'no': 2.9,
#   'no2': 13.6,
#   'nox': 16.5,
#   'o3': 37.8,
#   'o3_8hr': 32,
#   'pm10': 40,
#   'pm10_avg': 32,
#   'pm2.5': 12,
#   'pm2.5_avg': 10.7,
#   'pollutant': None,
#   'siteid': 70,
#   'sitename': '永和',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 82,
#   'windspeed': 2.2},
#  {'aqi': 36,
#   'co': 0.41,
#   'co_8hr': 0.3,
#   'county': '南投縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.756389,
#   'longitude': 120.677306,
#   'no': 0.5,
#   'no2': 17.4,
#   'nox': 17.9,
#   'o3': 15.3,
#   'o3_8hr': 37.3,
#   'pm10': 32,
#   'pm10_avg': 28,
#   'pm2.5': 11,
#   'pm2.5_avg': 11.1,
#   'pollutant': None,
#   'siteid': 69,
#   'sitename': '竹山',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 28,
#   'windspeed': 2},
#  {'aqi': 42,
#   'co': 0.78,
#   'co_8hr': 0.7,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.953278,
#   'longitude': 121.221667,
#   'no': 15.5,
#   'no2': 24.4,
#   'nox': 39.9,
#   'o3': 23.9,
#   'o3_8hr': 17.7,
#   'pm10': 35,
#   'pm10_avg': 29,
#   'pm2.5': 16,
#   'pm2.5_avg': 12.8,
#   'pollutant': None,
#   'siteid': 68,
#   'sitename': '中壢',
#   'so2': 1,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 5,
#   'windspeed': 1.3},
#  {'aqi': 52,
#   'co': 0.84,
#   'co_8hr': 1,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.072611,
#   'longitude': 121.493806,
#   'no': 38.1,
#   'no2': 32.6,
#   'nox': 70.7,
#   'o3': 18.5,
#   'o3_8hr': 12.9,
#   'pm10': 48,
#   'pm10_avg': 37,
#   'pm2.5': 15,
#   'pm2.5_avg': 13.8,
#   'pollutant': '二氧化氮',
#   'siteid': 67,
#   'sitename': '三重',
#   'so2': 0.7,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': '-',
#   'windspeed': '-'},
#  {'aqi': 31,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '宜蘭縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.632203,
#   'longitude': 121.792928,
#   'no': 1.2,
#   'no2': 6.7,
#   'nox': 7.9,
#   'o3': 39.2,
#   'o3_8hr': 33.6,
#   'pm10': 34,
#   'pm10_avg': 31,
#   'pm2.5': 12,
#   'pm2.5_avg': 9.4,
#   'pollutant': None,
#   'siteid': 66,
#   'sitename': '冬山',
#   'so2': 0.7,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 239,
#   'windspeed': 1.2},
#  {'aqi': 31,
#   'co': 0.28,
#   'co_8hr': 0.3,
#   'county': '宜蘭縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.747917,
#   'longitude': 121.746394,
#   'no': 0.6,
#   'no2': 4.8,
#   'nox': 5.4,
#   'o3': 33.2,
#   'o3_8hr': 33.3,
#   'pm10': 23,
#   'pm10_avg': 20,
#   'pm2.5': 11,
#   'pm2.5_avg': 9.7,
#   'pollutant': None,
#   'siteid': 65,
#   'sitename': '宜蘭',
#   'so2': 0.8,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 293,
#   'windspeed': 1.1},
#  {'aqi': 39,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '臺北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.182722,
#   'longitude': 121.529583,
#   'no': 1,
#   'no2': 1.1,
#   'nox': 2.2,
#   'o3': 49.7,
#   'o3_8hr': 43,
#   'pm10': 28,
#   'pm10_avg': 17,
#   'pm2.5': 7,
#   'pm2.5_avg': 4.7,
#   'pollutant': None,
#   'siteid': 64,
#   'sitename': '陽明',
#   'so2': 0.9,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': None,
#   'windspeed': None},
#  {'aqi': 34,
#   'co': 0.25,
#   'co_8hr': 0.3,
#   'county': '花蓮縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.971306,
#   'longitude': 121.599769,
#   'no': 0.4,
#   'no2': 3.9,
#   'nox': 4.3,
#   'o3': 45.4,
#   'o3_8hr': 37.3,
#   'pm10': 34,
#   'pm10_avg': 31,
#   'pm2.5': 10,
#   'pm2.5_avg': 8.2,
#   'pollutant': None,
#   'siteid': 63,
#   'sitename': '花蓮',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 72,
#   'windspeed': 4.4},
#  {'aqi': 34,
#   'co': 0.39,
#   'co_8hr': 0.3,
#   'county': '臺東縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.755358,
#   'longitude': 121.15045,
#   'no': 1.4,
#   'no2': 6.3,
#   'nox': 7.8,
#   'o3': 29,
#   'o3_8hr': 37,
#   'pm10': 12,
#   'pm10_avg': 21,
#   'pm2.5': 5,
#   'pm2.5_avg': 7.2,
#   'pollutant': None,
#   'siteid': 62,
#   'sitename': '臺東',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 326,
#   'windspeed': 1.6},
#  {'aqi': 28,
#   'co': 0.29,
#   'co_8hr': 0.2,
#   'county': '屏東縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 21.958069,
#   'longitude': 120.788928,
#   'no': 0.6,
#   'no2': 2.7,
#   'nox': 3.4,
#   'o3': None,
#   'o3_8hr': None,
#   'pm10': 20,
#   'pm10_avg': 17,
#   'pm2.5': 7,
#   'pm2.5_avg': 8.5,
#   'pollutant': None,
#   'siteid': 61,
#   'sitename': '恆春',
#   'so2': 0.7,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 27,
#   'windspeed': 10.2},
#  {'aqi': 53,
#   'co': 0.35,
#   'co_8hr': 0.2,
#   'county': '屏東縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.523108,
#   'longitude': 120.561175,
#   'no': 1.5,
#   'no2': 11,
#   'nox': 12.5,
#   'o3': 34.8,
#   'o3_8hr': 50.6,
#   'pm10': 63,
#   'pm10_avg': 34,
#   'pm2.5': 22,
#   'pm2.5_avg': 16.3,
#   'pollutant': '細懸浮微粒',
#   'siteid': 60,
#   'sitename': '潮州',
#   'so2': 1.5,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 285,
#   'windspeed': 2.1},
#  {'aqi': 48,
#   'co': 0.42,
#   'co_8hr': 0.2,
#   'county': '屏東縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.673081,
#   'longitude': 120.488033,
#   'no': 0.5,
#   'no2': 13.1,
#   'nox': 13.6,
#   'o3': 36.7,
#   'o3_8hr': 46.5,
#   'pm10': 116,
#   'pm10_avg': 48,
#   'pm2.5': 21,
#   'pm2.5_avg': 13.7,
#   'pollutant': None,
#   'siteid': 59,
#   'sitename': '屏東',
#   'so2': 1.7,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 256,
#   'windspeed': 1.8},
#  {'aqi': 63,
#   'co': 0.53,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.565833,
#   'longitude': 120.337736,
#   'no': 0.7,
#   'no2': 22.4,
#   'nox': 23.1,
#   'o3': 29.4,
#   'o3_8hr': 43.8,
#   'pm10': 113,
#   'pm10_avg': 63,
#   'pm2.5': 20,
#   'pm2.5_avg': 14.9,
#   'pollutant': '懸浮微粒',
#   'siteid': 58,
#   'sitename': '小港',
#   'so2': 1.3,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 331,
#   'windspeed': 1.3},
#  {'aqi': 74,
#   'co': 0.53,
#   'co_8hr': 0.4,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.6044507,
#   'longitude': 120.30833356,
#   'no': 2.5,
#   'no2': 19.5,
#   'nox': 22,
#   'o3': 28.3,
#   'o3_8hr': 43.3,
#   'pm10': 139,
#   'pm10_avg': 74,
#   'pm2.5': 23,
#   'pm2.5_avg': 18,
#   'pollutant': '懸浮微粒',
#   'siteid': 57,
#   'sitename': '前鎮',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 3,
#   'windspeed': 3.2},
#  {'aqi': 79,
#   'co': 0.46,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.63390278,
#   'longitude': 120.28676111,
#   'no': 0.8,
#   'no2': 18.3,
#   'nox': 19.2,
#   'o3': 27.4,
#   'o3_8hr': 44.4,
#   'pm10': 130,
#   'pm10_avg': 79,
#   'pm2.5': 15,
#   'pm2.5_avg': 14.3,
#   'pollutant': '懸浮微粒',
#   'siteid': 56,
#   'sitename': '前金',
#   'so2': 1.4,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 354,
#   'windspeed': 4.2},
#  {'aqi': 82,
#   'co': 0.46,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.674861,
#   'longitude': 120.292917,
#   'no': 0.7,
#   'no2': 16.7,
#   'nox': 17.5,
#   'o3': 28.2,
#   'o3_8hr': 46.3,
#   'pm10': 163,
#   'pm10_avg': 82,
#   'pm2.5': 23,
#   'pm2.5_avg': 16.7,
#   'pollutant': '懸浮微粒',
#   'siteid': 54,
#   'sitename': '左營',
#   'so2': 1.5,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 7,
#   'windspeed': 3},
#  {'aqi': 90,
#   'co': 0.45,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.733667,
#   'longitude': 120.328289,
#   'no': 0.4,
#   'no2': 16.6,
#   'nox': 17.1,
#   'o3': 26.7,
#   'o3_8hr': 45.4,
#   'pm10': 182,
#   'pm10_avg': 90,
#   'pm2.5': 20,
#   'pm2.5_avg': 14.7,
#   'pollutant': '懸浮微粒',
#   'siteid': 53,
#   'sitename': '楠梓',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 340,
#   'windspeed': 2.3},
#  {'aqi': 59,
#   'co': 0.51,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.4795,
#   'longitude': 120.41175,
#   'no': 0,
#   'no2': 23.2,
#   'nox': 23.2,
#   'o3': 28.4,
#   'o3_8hr': 47.3,
#   'pm10': 84,
#   'pm10_avg': 59,
#   'pm2.5': 17,
#   'pm2.5_avg': 16.8,
#   'pollutant': '懸浮微粒',
#   'siteid': 52,
#   'sitename': '林園',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 315,
#   'windspeed': 1},
#  {'aqi': 52,
#   'co': 0.46,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.56413611,
#   'longitude': 120.425311,
#   'no': 0.9,
#   'no2': 23.2,
#   'nox': 24.2,
#   'o3': 24.7,
#   'o3_8hr': 41.6,
#   'pm10': 57,
#   'pm10_avg': 33,
#   'pm2.5': 18,
#   'pm2.5_avg': 16,
#   'pollutant': '細懸浮微粒',
#   'siteid': 51,
#   'sitename': '大寮',
#   'so2': 2.1,
#   'so2_avg': 2,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 318,
#   'windspeed': 1.8},
#  {'aqi': 71,
#   'co': 0.71,
#   'co_8hr': 0.4,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.628126,
#   'longitude': 120.357422,
#   'no': 3,
#   'no2': 21.4,
#   'nox': 24.5,
#   'o3': 25.2,
#   'o3_8hr': 41.1,
#   'pm10': 164,
#   'pm10_avg': 71,
#   'pm2.5': 26,
#   'pm2.5_avg': 19.3,
#   'pollutant': '懸浮微粒',
#   'siteid': 50,
#   'sitename': '鳳山',
#   'so2': 1.3,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 252,
#   'windspeed': 1.3},
#  {'aqi': 64,
#   'co': 0.48,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.689056,
#   'longitude': 120.332631,
#   'no': 1.1,
#   'no2': 17.9,
#   'nox': 19,
#   'o3': 25.4,
#   'o3_8hr': 43.7,
#   'pm10': 136,
#   'pm10_avg': 64,
#   'pm2.5': 25,
#   'pm2.5_avg': 17.6,
#   'pollutant': '懸浮微粒',
#   'siteid': 49,
#   'sitename': '仁武',
#   'so2': 1.5,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 342,
#   'windspeed': 2.8},
#  {'aqi': 83,
#   'co': 0.48,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.757506,
#   'longitude': 120.305689,
#   'no': 1.5,
#   'no2': 20.2,
#   'nox': 21.7,
#   'o3': 22.9,
#   'o3_8hr': 44.1,
#   'pm10': 153,
#   'pm10_avg': 83,
#   'pm2.5': 24,
#   'pm2.5_avg': 15.7,
#   'pollutant': '懸浮微粒',
#   'siteid': 48,
#   'sitename': '橋頭',
#   'so2': 1.7,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 10,
#   'windspeed': 3.2},
#  {'aqi': 54,
#   'co': 0.39,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.883583,
#   'longitude': 120.530542,
#   'no': 0.7,
#   'no2': 9.1,
#   'nox': 9.8,
#   'o3': 36.2,
#   'o3_8hr': 44.8,
#   'pm10': 123,
#   'pm10_avg': 54,
#   'pm2.5': 21,
#   'pm2.5_avg': 12.1,
#   'pollutant': '懸浮微粒',
#   'siteid': 47,
#   'sitename': '美濃',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 267,
#   'windspeed': 1.2},
#  {'aqi': 75,
#   'co': 0.45,
#   'co_8hr': 0.3,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 22.98928311,
#   'longitude': 120.21947897,
#   'no': 0.6,
#   'no2': 17.2,
#   'nox': 17.8,
#   'o3': 19.6,
#   'o3_8hr': 42.1,
#   'pm10': 73,
#   'pm10_avg': 75,
#   'pm2.5': 21,
#   'pm2.5_avg': 14.5,
#   'pollutant': '懸浮微粒',
#   'siteid': 46,
#   'sitename': '臺南',
#   'so2': 2,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 2,
#   'windspeed': 4.2},
#  {'aqi': 75,
#   'co': 0.43,
#   'co_8hr': 0.3,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.048197,
#   'longitude': 120.2175,
#   'no': 0.4,
#   'no2': 13.7,
#   'nox': 14.2,
#   'o3': 20.9,
#   'o3_8hr': 42.6,
#   'pm10': 63,
#   'pm10_avg': 75,
#   'pm2.5': 13,
#   'pm2.5_avg': 14.7,
#   'pollutant': '懸浮微粒',
#   'siteid': 45,
#   'sitename': '安南',
#   'so2': 1.5,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 320,
#   'windspeed': 3},
#  {'aqi': 92,
#   'co': 0.4,
#   'co_8hr': 0.2,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.11337642,
#   'longitude': 120.29740529,
#   'no': 0.7,
#   'no2': 13.6,
#   'nox': 14.4,
#   'o3': 19.8,
#   'o3_8hr': 42.1,
#   'pm10': 60,
#   'pm10_avg': 92,
#   'pm2.5': 16,
#   'pm2.5_avg': 13.2,
#   'pollutant': '懸浮微粒',
#   'siteid': 44,
#   'sitename': '善化',
#   'so2': 1.7,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 355,
#   'windspeed': 3.9},
#  {'aqi': 105,
#   'co': 0.45,
#   'co_8hr': 0.3,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.305633,
#   'longitude': 120.31725,
#   'no': 0.2,
#   'no2': 16.5,
#   'nox': 16.8,
#   'o3': 17.3,
#   'o3_8hr': 37.7,
#   'pm10': 63,
#   'pm10_avg': 113,
#   'pm2.5': 16,
#   'pm2.5_avg': 16.6,
#   'pollutant': '懸浮微粒',
#   'siteid': 43,
#   'sitename': '新營',
#   'so2': 1.9,
#   'so2_avg': 1,
#   'status': '對敏感族群不健康',
#   'unit': None,
#   'winddirec': 14,
#   'windspeed': 3.4},
#  {'aqi': 63,
#   'co': 0.47,
#   'co_8hr': 0.3,
#   'county': '嘉義市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.46477865,
#   'longitude': 120.44125148,
#   'no': 1.6,
#   'no2': 17.2,
#   'nox': 18.8,
#   'o3': 15.4,
#   'o3_8hr': 37.4,
#   'pm10': 26,
#   'pm10_avg': 63,
#   'pm2.5': 16,
#   'pm2.5_avg': 14.2,
#   'pollutant': '懸浮微粒',
#   'siteid': 42,
#   'sitename': '嘉義',
#   'so2': 10.5,
#   'so2_avg': 2,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 6,
#   'windspeed': 2.7},
#  {'aqi': 39,
#   'co': 0.28,
#   'co_8hr': 0.3,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.702175,
#   'longitude': 120.19933333,
#   'no': 0.5,
#   'no2': 6.2,
#   'nox': 6.8,
#   'o3': 35.9,
#   'o3_8hr': 41,
#   'pm10': 49,
#   'pm10_avg': 39,
#   'pm2.5': 10,
#   'pm2.5_avg': 8.9,
#   'pollutant': None,
#   'siteid': 41,
#   'sitename': '臺西',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 25,
#   'windspeed': 7.4},
#  {'aqi': 72,
#   'co': 0.31,
#   'co_8hr': 0.3,
#   'county': '嘉義縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.46538,
#   'longitude': 120.2478,
#   'no': 1.9,
#   'no2': 11.4,
#   'nox': 13.3,
#   'o3': 25.1,
#   'o3_8hr': 38.8,
#   'pm10': 56,
#   'pm10_avg': 72,
#   'pm2.5': 9,
#   'pm2.5_avg': 9.6,
#   'pollutant': '懸浮微粒',
#   'siteid': 40,
#   'sitename': '朴子',
#   'so2': 2.3,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 352,
#   'windspeed': 2.4},
#  {'aqi': 104,
#   'co': 0.32,
#   'co_8hr': 0.3,
#   'county': '嘉義縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.554839,
#   'longitude': 120.345531,
#   'no': 0.4,
#   'no2': 12.9,
#   'nox': 13.3,
#   'o3': 25.4,
#   'o3_8hr': 38.3,
#   'pm10': 40,
#   'pm10_avg': 109,
#   'pm2.5': 12,
#   'pm2.5_avg': 15.3,
#   'pollutant': '懸浮微粒',
#   'siteid': 39,
#   'sitename': '新港',
#   'so2': 1.9,
#   'so2_avg': 1,
#   'status': '對敏感族群不健康',
#   'unit': None,
#   'winddirec': 5,
#   'windspeed': 3.4},
#  {'aqi': 124,
#   'co': 0.34,
#   'co_8hr': 0.3,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.757547,
#   'longitude': 120.348742,
#   'no': 0.7,
#   'no2': 11.3,
#   'nox': 12.1,
#   'o3': 26.9,
#   'o3_8hr': 33.9,
#   'pm10': 135,
#   'pm10_avg': 173,
#   'pm2.5': 14,
#   'pm2.5_avg': 17,
#   'pollutant': '懸浮微粒',
#   'siteid': 38,
#   'sitename': '崙背',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '對敏感族群不健康',
#   'unit': None,
#   'winddirec': 2,
#   'windspeed': 2.4},
#  {'aqi': 49,
#   'co': 0.36,
#   'co_8hr': 0.3,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.711853,
#   'longitude': 120.544994,
#   'no': 1,
#   'no2': 12.2,
#   'nox': 13.2,
#   'o3': 22.6,
#   'o3_8hr': 38.8,
#   'pm10': 21,
#   'pm10_avg': 49,
#   'pm2.5': 10,
#   'pm2.5_avg': 10.8,
#   'pollutant': None,
#   'siteid': 37,
#   'sitename': '斗六',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 344,
#   'windspeed': 1.8},
#  {'aqi': 31,
#   'co': 0.39,
#   'co_8hr': 0.3,
#   'county': '南投縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.913,
#   'longitude': 120.685306,
#   'no': 1.2,
#   'no2': 15.5,
#   'nox': 16.8,
#   'o3': 19.7,
#   'o3_8hr': 33.4,
#   'pm10': 21,
#   'pm10_avg': 26,
#   'pm2.5': 6,
#   'pm2.5_avg': 9.1,
#   'pollutant': None,
#   'siteid': 36,
#   'sitename': '南投',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 340,
#   'windspeed': 1.5},
#  {'aqi': 39,
#   'co': 0.29,
#   'co_8hr': 0.3,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 23.925175,
#   'longitude': 120.409653,
#   'no': 0.3,
#   'no2': 9.1,
#   'nox': 9.5,
#   'o3': 34.8,
#   'o3_8hr': 37.4,
#   'pm10': 39,
#   'pm10_avg': 39,
#   'pm2.5': 10,
#   'pm2.5_avg': 7.8,
#   'pollutant': None,
#   'siteid': 35,
#   'sitename': '二林',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 26,
#   'windspeed': 5.6},
#  {'aqi': 34,
#   'co': 0.28,
#   'co_8hr': 0.3,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.131672,
#   'longitude': 120.469061,
#   'no': 0.5,
#   'no2': 12.3,
#   'nox': 12.8,
#   'o3': 32.8,
#   'o3_8hr': 33.6,
#   'pm10': 31,
#   'pm10_avg': 29,
#   'pm2.5': 15,
#   'pm2.5_avg': 10.5,
#   'pollutant': None,
#   'siteid': 34,
#   'sitename': '線西',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 35,
#   'windspeed': 8},
#  {'aqi': 26,
#   'co': 0.33,
#   'co_8hr': 0.3,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.066,
#   'longitude': 120.541519,
#   'no': 1.1,
#   'no2': 13.2,
#   'nox': 14.3,
#   'o3': 27,
#   'o3_8hr': 28.4,
#   'pm10': 23,
#   'pm10_avg': 22,
#   'pm2.5': 8,
#   'pm2.5_avg': 7.8,
#   'pollutant': None,
#   'siteid': 33,
#   'sitename': '彰化',
#   'so2': 0.6,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 23,
#   'windspeed': 2.4},
#  {'aqi': 29,
#   'co': 0.27,
#   'co_8hr': 0.3,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.162197,
#   'longitude': 120.616917,
#   'no': 1.2,
#   'no2': 7.3,
#   'nox': 8.6,
#   'o3': 33.3,
#   'o3_8hr': 31.9,
#   'pm10': 21,
#   'pm10_avg': 26,
#   'pm2.5': 8,
#   'pm2.5_avg': 7.1,
#   'pollutant': None,
#   'siteid': 32,
#   'sitename': '西屯',
#   'so2': 1,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 0,
#   'windspeed': 4.7},
#  {'aqi': 27,
#   'co': 0.36,
#   'co_8hr': 0.3,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.151958,
#   'longitude': 120.641092,
#   'no': 1.2,
#   'no2': 10.9,
#   'nox': 12.1,
#   'o3': 26.6,
#   'o3_8hr': 29.1,
#   'pm10': 16,
#   'pm10_avg': 19,
#   'pm2.5': 7,
#   'pm2.5_avg': 6.7,
#   'pollutant': None,
#   'siteid': 31,
#   'sitename': '忠明',
#   'so2': 1.5,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 329,
#   'windspeed': 1.8},
#  {'aqi': 28,
#   'co': 0.39,
#   'co_8hr': 0.4,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.09961111,
#   'longitude': 120.67844444,
#   'no': 1.6,
#   'no2': 10.8,
#   'nox': 12.5,
#   'o3': 22.7,
#   'o3_8hr': 30.4,
#   'pm10': 20,
#   'pm10_avg': 19,
#   'pm2.5': 8,
#   'pm2.5_avg': 8.2,
#   'pollutant': None,
#   'siteid': 30,
#   'sitename': '大里',
#   'so2': 1.3,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 8,
#   'windspeed': 2.1},
#  {'aqi': 26,
#   'co': 0.27,
#   'co_8hr': 0.3,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.225628,
#   'longitude': 120.568794,
#   'no': 0.7,
#   'no2': 6.3,
#   'nox': 7,
#   'o3': 13,
#   'o3_8hr': 24.1,
#   'pm10': 26,
#   'pm10_avg': 22,
#   'pm2.5': 11,
#   'pm2.5_avg': 8.1,
#   'pollutant': None,
#   'siteid': 29,
#   'sitename': '沙鹿',
#   'so2': 0.9,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 9,
#   'windspeed': 5.4},
#  {'aqi': 30,
#   'co': 0.29,
#   'co_8hr': 0.3,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.25699731,
#   'longitude': 120.74252414,
#   'no': 0.3,
#   'no2': 5.8,
#   'nox': 6.1,
#   'o3': 27.4,
#   'o3_8hr': 32,
#   'pm10': 11,
#   'pm10_avg': 15,
#   'pm2.5': 10,
#   'pm2.5_avg': 8.7,
#   'pollutant': None,
#   'siteid': 28,
#   'sitename': '豐原',
#   'so2': 0.8,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 33,
#   'windspeed': 3.3},
#  {'aqi': 30,
#   'co': 0.24,
#   'co_8hr': 0.3,
#   'county': '苗栗縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.38248443,
#   'longitude': 120.75956754,
#   'no': 0.9,
#   'no2': 3.2,
#   'nox': 4.2,
#   'o3': 40,
#   'o3_8hr': 32.9,
#   'pm10': 25,
#   'pm10_avg': 13,
#   'pm2.5': 9,
#   'pm2.5_avg': 6.5,
#   'pollutant': None,
#   'siteid': 27,
#   'sitename': '三義',
#   'so2': 0.9,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 16,
#   'windspeed': 7},
#  {'aqi': 30,
#   'co': 0.27,
#   'co_8hr': 0.3,
#   'county': '苗栗縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.56499183,
#   'longitude': 120.82011468,
#   'no': 1,
#   'no2': 7.7,
#   'nox': 8.7,
#   'o3': 39.6,
#   'o3_8hr': 32.4,
#   'pm10': 27,
#   'pm10_avg': 20,
#   'pm2.5': 14,
#   'pm2.5_avg': 8.5,
#   'pollutant': None,
#   'siteid': 26,
#   'sitename': '苗栗',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 8,
#   'windspeed': 3.8},
#  {'aqi': 31,
#   'co': 0.32,
#   'co_8hr': 0.3,
#   'county': '苗栗縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.69690679,
#   'longitude': 120.89869286,
#   'no': 1.1,
#   'no2': 10.5,
#   'nox': 11.6,
#   'o3': 40.8,
#   'o3_8hr': 31.1,
#   'pm10': 34,
#   'pm10_avg': 21,
#   'pm2.5': 11,
#   'pm2.5_avg': 9.5,
#   'pollutant': None,
#   'siteid': 25,
#   'sitename': '頭份',
#   'so2': 1.5,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 45,
#   'windspeed': 2.3},
#  {'aqi': 28,
#   'co': 0.33,
#   'co_8hr': 0.3,
#   'county': '新竹市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.8056356,
#   'longitude': 120.97236752,
#   'no': 0.4,
#   'no2': 10,
#   'nox': 10.4,
#   'o3': 39.2,
#   'o3_8hr': 30.4,
#   'pm10': 34,
#   'pm10_avg': 24,
#   'pm2.5': 18,
#   'pm2.5_avg': 7.4,
#   'pollutant': None,
#   'siteid': 24,
#   'sitename': '新竹',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 39,
#   'windspeed': 2.7},
#  {'aqi': 32,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '新竹縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.74091408,
#   'longitude': 121.08895493,
#   'no': 0.2,
#   'no2': 5.5,
#   'nox': 5.7,
#   'o3': 43.8,
#   'o3_8hr': 35.1,
#   'pm10': 31,
#   'pm10_avg': 19,
#   'pm2.5': 11,
#   'pm2.5_avg': 6.5,
#   'pollutant': None,
#   'siteid': 23,
#   'sitename': '竹東',
#   'so2': 0.5,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 45,
#   'windspeed': 3.3},
#  {'aqi': 32,
#   'co': 0.26,
#   'co_8hr': 0.3,
#   'county': '新竹縣',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.90009696,
#   'longitude': 121.03886894,
#   'no': 0.3,
#   'no2': 4.5,
#   'nox': 4.9,
#   'o3': 45.1,
#   'o3_8hr': 35,
#   'pm10': 30,
#   'pm10_avg': 24,
#   'pm2.5': 11,
#   'pm2.5_avg': 8.2,
#   'pollutant': None,
#   'siteid': 22,
#   'sitename': '湖口',
#   'so2': 2.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 49,
#   'windspeed': 5.3},
#  {'aqi': 31,
#   'co': 0.27,
#   'co_8hr': 0.3,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.86400048,
#   'longitude': 121.21645772,
#   'no': 0.8,
#   'no2': 7.4,
#   'nox': 8.2,
#   'o3': 41.9,
#   'o3_8hr': 33.4,
#   'pm10': 37,
#   'pm10_avg': 26,
#   'pm2.5': 11,
#   'pm2.5_avg': 9.2,
#   'pollutant': None,
#   'siteid': 21,
#   'sitename': '龍潭',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 62,
#   'windspeed': 6.4},
#  {'aqi': 35,
#   'co': 0.41,
#   'co_8hr': 0.4,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.952786,
#   'longitude': 121.203986,
#   'no': 1.5,
#   'no2': 13.3,
#   'nox': 14.8,
#   'o3': 39.4,
#   'o3_8hr': 29.9,
#   'pm10': 29,
#   'pm10_avg': 25,
#   'pm2.5': 15,
#   'pm2.5_avg': 10.7,
#   'pollutant': None,
#   'siteid': 20,
#   'sitename': '平鎮',
#   'so2': 1.2,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 79,
#   'windspeed': 3.5},
#  {'aqi': 43,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.03556747,
#   'longitude': 121.08283092,
#   'no': 0.1,
#   'no2': 7.3,
#   'nox': 7.4,
#   'o3': 44.5,
#   'o3_8hr': 36.6,
#   'pm10': 39,
#   'pm10_avg': 41,
#   'pm2.5': 17,
#   'pm2.5_avg': 13.1,
#   'pollutant': None,
#   'siteid': 19,
#   'sitename': '觀音',
#   'so2': 1.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 86,
#   'windspeed': 6.5},
#  {'aqi': 46,
#   'co': 0.27,
#   'co_8hr': 0.3,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.06100357,
#   'longitude': 121.20251473,
#   'no': 0.9,
#   'no2': 12.2,
#   'nox': 13.2,
#   'o3': 41.4,
#   'o3_8hr': 34.4,
#   'pm10': 42,
#   'pm10_avg': 34,
#   'pm2.5': 16,
#   'pm2.5_avg': 14.3,
#   'pollutant': None,
#   'siteid': 18,
#   'sitename': '大園',
#   'so2': 1.3,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 64,
#   'windspeed': 4.4},
#  {'aqi': 27,
#   'co': 0.35,
#   'co_8hr': 0.4,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.9947107,
#   'longitude': 121.30500531,
#   'no': 1.2,
#   'no2': 10,
#   'nox': 11.3,
#   'o3': 41.1,
#   'o3_8hr': 29,
#   'pm10': 32,
#   'pm10_avg': 27,
#   'pm2.5': 10,
#   'pm2.5_avg': 8.2,
#   'pollutant': None,
#   'siteid': 17,
#   'sitename': '桃園',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 51,
#   'windspeed': 3.7},
#  {'aqi': 48,
#   'co': 0.58,
#   'co_8hr': 0.6,
#   'county': '臺北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.06331455,
#   'longitude': 121.51342074,
#   'no': 15.1,
#   'no2': 26.5,
#   'nox': 41.6,
#   'o3': 26.9,
#   'o3_8hr': 21.6,
#   'pm10': 41,
#   'pm10_avg': 32,
#   'pm2.5': 17,
#   'pm2.5_avg': 14.8,
#   'pollutant': None,
#   'siteid': 16,
#   'sitename': '大同',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': '-',
#   'windspeed': '-'},
#  {'aqi': 46,
#   'co': 0.28,
#   'co_8hr': 0.3,
#   'county': '臺北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.05,
#   'longitude': 121.578611,
#   'no': 1.9,
#   'no2': 13.2,
#   'nox': 15.2,
#   'o3': 37.6,
#   'o3_8hr': 30.8,
#   'pm10': 44,
#   'pm10_avg': 36,
#   'pm2.5': 16,
#   'pm2.5_avg': 14.1,
#   'pollutant': None,
#   'siteid': 15,
#   'sitename': '松山',
#   'so2': 1.3,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 18,
#   'windspeed': 2.1},
#  {'aqi': 36,
#   'co': 0.35,
#   'co_8hr': 0.3,
#   'county': '臺北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.020608,
#   'longitude': 121.529556,
#   'no': 0.6,
#   'no2': 13.2,
#   'nox': 13.8,
#   'o3': 37.1,
#   'o3_8hr': 31.4,
#   'pm10': 40,
#   'pm10_avg': 31,
#   'pm2.5': 13,
#   'pm2.5_avg': 11.2,
#   'pollutant': None,
#   'siteid': 14,
#   'sitename': '古亭',
#   'so2': 1.4,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 67,
#   'windspeed': 1.8},
#  {'aqi': 39,
#   'co': 0.34,
#   'co_8hr': 0.3,
#   'county': '臺北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.046503,
#   'longitude': 121.507972,
#   'no': 2.2,
#   'no2': 16.8,
#   'nox': 19.1,
#   'o3': 32.1,
#   'o3_8hr': 22.5,
#   'pm10': 37,
#   'pm10_avg': 32,
#   'pm2.5': 16,
#   'pm2.5_avg': 11.9,
#   'pollutant': None,
#   'siteid': 13,
#   'sitename': '萬華',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 94,
#   'windspeed': 2.9},
#  {'aqi': 45,
#   'co': 0.42,
#   'co_8hr': 0.4,
#   'county': '臺北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.062361,
#   'longitude': 121.526528,
#   'no': 2.8,
#   'no2': 17.3,
#   'nox': 20.1,
#   'o3': 34.1,
#   'o3_8hr': 27,
#   'pm10': 42,
#   'pm10_avg': 32,
#   'pm2.5': 16,
#   'pm2.5_avg': 14,
#   'pollutant': None,
#   'siteid': 12,
#   'sitename': '中山',
#   'so2': 0.9,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 62,
#   'windspeed': 2},
#  {'aqi': 36,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '臺北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.10334003,
#   'longitude': 121.51666356,
#   'no': 0.6,
#   'no2': 5.7,
#   'nox': 6.3,
#   'o3': 47.6,
#   'o3_8hr': 39.4,
#   'pm10': 30,
#   'pm10_avg': 27,
#   'pm2.5': 19,
#   'pm2.5_avg': 10.1,
#   'pollutant': None,
#   'siteid': 11,
#   'sitename': '士林',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 49,
#   'windspeed': 2.3},
#  {'aqi': 36,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.1645,
#   'longitude': 121.449239,
#   'no': 0.9,
#   'no2': 3.3,
#   'nox': 4.3,
#   'o3': 48,
#   'o3_8hr': 39.8,
#   'pm10': 40,
#   'pm10_avg': 28,
#   'pm2.5': 12,
#   'pm2.5_avg': 10.6,
#   'pollutant': None,
#   'siteid': 10,
#   'sitename': '淡水',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': None,
#   'windspeed': None},
#  {'aqi': 31,
#   'co': 0.26,
#   'co_8hr': 0.2,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.07798949,
#   'longitude': 121.36548982,
#   'no': 1.3,
#   'no2': 7.8,
#   'nox': 9.2,
#   'o3': 40,
#   'o3_8hr': 29.2,
#   'pm10': 32,
#   'pm10_avg': 29,
#   'pm2.5': 12,
#   'pm2.5_avg': 9.7,
#   'pollutant': None,
#   'siteid': 9,
#   'sitename': '林口',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 58,
#   'windspeed': 3.1},
#  {'aqi': 40,
#   'co': 0.32,
#   'co_8hr': 0.3,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.06895,
#   'longitude': 121.481028,
#   'no': 0.7,
#   'no2': 10.1,
#   'nox': 10.8,
#   'o3': 43.9,
#   'o3_8hr': 35.6,
#   'pm10': 36,
#   'pm10_avg': 26,
#   'pm2.5': 16,
#   'pm2.5_avg': 12.2,
#   'pollutant': None,
#   'siteid': 8,
#   'sitename': '菜寮',
#   'so2': 0.7,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 75,
#   'windspeed': 3.5},
#  {'aqi': 41,
#   'co': 0.28,
#   'co_8hr': 0.3,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.037972,
#   'longitude': 121.4325,
#   'no': 0.6,
#   'no2': 6.9,
#   'nox': 7.5,
#   'o3': 44.9,
#   'o3_8hr': 34.4,
#   'pm10': 47,
#   'pm10_avg': 34,
#   'pm2.5': 17,
#   'pm2.5_avg': 12.7,
#   'pollutant': None,
#   'siteid': 7,
#   'sitename': '新莊',
#   'so2': 1.1,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 68,
#   'windspeed': 5.7},
#  {'aqi': 34,
#   'co': 0.36,
#   'co_8hr': 0.3,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.012972,
#   'longitude': 121.458667,
#   'no': 1,
#   'no2': 13.7,
#   'nox': 14.7,
#   'o3': 43.3,
#   'o3_8hr': 34.7,
#   'pm10': 41,
#   'pm10_avg': 29,
#   'pm2.5': 14,
#   'pm2.5_avg': 10.4,
#   'pollutant': None,
#   'siteid': 6,
#   'sitename': '板橋',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 55,
#   'windspeed': 3},
#  {'aqi': 37,
#   'co': 0.35,
#   'co_8hr': 0.3,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.982528,
#   'longitude': 121.451861,
#   'no': 0.6,
#   'no2': 11.6,
#   'nox': 12.3,
#   'o3': 40.4,
#   'o3_8hr': 32.4,
#   'pm10': 34,
#   'pm10_avg': 29,
#   'pm2.5': 10,
#   'pm2.5_avg': 11.5,
#   'pollutant': None,
#   'siteid': 5,
#   'sitename': '土城',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 145,
#   'windspeed': 1.9},
#  {'aqi': 49,
#   'co': 0.33,
#   'co_8hr': 0.3,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 24.977222,
#   'longitude': 121.537778,
#   'no': 0.7,
#   'no2': 10.1,
#   'nox': 10.9,
#   'o3': 37.7,
#   'o3_8hr': 29.2,
#   'pm10': 40,
#   'pm10_avg': 27,
#   'pm2.5': 17,
#   'pm2.5_avg': 15.1,
#   'pollutant': None,
#   'siteid': 4,
#   'sitename': '新店',
#   'so2': 0.6,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 118,
#   'windspeed': 1.9},
#  {'aqi': 82,
#   'co': 0.23,
#   'co_8hr': 0.2,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.179667,
#   'longitude': 121.689881,
#   'no': 0.5,
#   'no2': 2.9,
#   'nox': 3.5,
#   'o3': 53.9,
#   'o3_8hr': 48.2,
#   'pm10': 95,
#   'pm10_avg': 82,
#   'pm2.5': 17,
#   'pm2.5_avg': 16.3,
#   'pollutant': '懸浮微粒',
#   'siteid': 3,
#   'sitename': '萬里',
#   'so2': 0.1,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 45,
#   'windspeed': 5.9},
#  {'aqi': 39,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.06624,
#   'longitude': 121.64081,
#   'no': 1.2,
#   'no2': 9.8,
#   'nox': 11,
#   'o3': 40.9,
#   'o3_8hr': 33.3,
#   'pm10': 38,
#   'pm10_avg': 28,
#   'pm2.5': 15,
#   'pm2.5_avg': 12,
#   'pollutant': None,
#   'siteid': 2,
#   'sitename': '汐止',
#   'so2': 1.7,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 42,
#   'windspeed': 1.1},
#  {'aqi': 39,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '基隆市',
#   'datacreationdate': '2024-11-26 20:00',
#   'latitude': 25.129167,
#   'longitude': 121.760056,
#   'no': 0.1,
#   'no2': 4,
#   'nox': 4.2,
#   'o3': 48.7,
#   'o3_8hr': 42.9,
#   'pm10': 41,
#   'pm10_avg': 31,
#   'pm2.5': 12,
#   'pm2.5_avg': 8.9,
#   'pollutant': None,
#   'siteid': 1,
#   'sitename': '基隆',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 89,
#   'windspeed': 2.4},
#  {'aqi': 41,
#   'co': 0.24,
#   'co_8hr': 0.1,
#   'county': '屏東縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 22.260899,
#   'longitude': 120.651472,
#   'no': 0.2,
#   'no2': 2.7,
#   'nox': 2.9,
#   'o3': 39.7,
#   'o3_8hr': 44.4,
#   'pm10': 21,
#   'pm10_avg': 28,
#   'pm2.5': 6,
#   'pm2.5_avg': 9.2,
#   'pollutant': None,
#   'siteid': 313,
#   'sitename': '屏東(枋山)',
#   'so2': 0,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 88,
#   'windspeed': 6.9},
#  {'aqi': 34,
#   'co': 0.34,
#   'co_8hr': 0.3,
#   'county': '花蓮縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.97709367,
#   'longitude': 121.61575076,
#   'no': 1.4,
#   'no2': 5.4,
#   'nox': 6.8,
#   'o3': 42.8,
#   'o3_8hr': 37.5,
#   'pm10': 25,
#   'pm10_avg': 25,
#   'pm2.5': 12,
#   'pm2.5_avg': 10.1,
#   'pollutant': None,
#   'siteid': 312,
#   'sitename': '花蓮（美崙）',
#   'so2': 0,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 38,
#   'windspeed': 4.7},
#  {'aqi': 38,
#   'co': 0.43,
#   'co_8hr': 0.4,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 24.94902778,
#   'longitude': 121.38352778,
#   'no': 8.5,
#   'no2': 23.7,
#   'nox': 32.2,
#   'o3': 26.8,
#   'o3_8hr': 21.1,
#   'pm10': 39,
#   'pm10_avg': 27,
#   'pm2.5': 14,
#   'pm2.5_avg': 10.5,
#   'pollutant': None,
#   'siteid': 311,
#   'sitename': '新北(樹林)',
#   'so2': 0.7,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 140,
#   'windspeed': 0},
#  {'aqi': 57,
#   'co': 0.36,
#   'co_8hr': 0.3,
#   'county': '屏東縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 22.35222,
#   'longitude': 120.37722,
#   'no': 0.9,
#   'no2': 9.7,
#   'nox': 10.6,
#   'o3': 48.3,
#   'o3_8hr': 56.3,
#   'pm10': 55,
#   'pm10_avg': 47,
#   'pm2.5': 19,
#   'pm2.5_avg': 18,
#   'pollutant': '細懸浮微粒',
#   'siteid': 204,
#   'sitename': '屏東（琉球）',
#   'so2': 1.4,
#   'so2_avg': 2,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 315,
#   'windspeed': 3.2},
#  {'aqi': 79,
#   'co': 0.41,
#   'co_8hr': 0.2,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.17904722,
#   'longitude': 120.24583056,
#   'no': 0.4,
#   'no2': 14,
#   'nox': 14.5,
#   'o3': 22.2,
#   'o3_8hr': 40.1,
#   'pm10': 105,
#   'pm10_avg': 79,
#   'pm2.5': 18,
#   'pm2.5_avg': 14,
#   'pollutant': '懸浮微粒',
#   'siteid': 203,
#   'sitename': '臺南（麻豆）',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 9,
#   'windspeed': 3.1},
#  {'aqi': 61,
#   'co': 0.4,
#   'co_8hr': 0.3,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 22.87985556,
#   'longitude': 120.24535,
#   'no': 0,
#   'no2': 14,
#   'nox': 13.9,
#   'o3': 32.1,
#   'o3_8hr': 43.3,
#   'pm10': 113,
#   'pm10_avg': 61,
#   'pm2.5': 12,
#   'pm2.5_avg': 8.5,
#   'pollutant': '懸浮微粒',
#   'siteid': 202,
#   'sitename': '高雄（湖內）',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 303,
#   'windspeed': 1.4},
#  {'aqi': 31,
#   'co': 0.4,
#   'co_8hr': 0.3,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.96117,
#   'longitude': 120.56373,
#   'no': 2.1,
#   'no2': 13.7,
#   'nox': 15.8,
#   'o3': 22.7,
#   'o3_8hr': 33.5,
#   'pm10': 26,
#   'pm10_avg': 30,
#   'pm2.5': 9,
#   'pm2.5_avg': 8,
#   'pollutant': None,
#   'siteid': 201,
#   'sitename': '彰化（員林）',
#   'so2': 1.3,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 352,
#   'windspeed': 1.9},
#  {'aqi': 39,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.85493056,
#   'longitude': 120.26964167,
#   'no': 1,
#   'no2': 6,
#   'nox': 7.1,
#   'o3': 37.1,
#   'o3_8hr': 42.1,
#   'pm10': 24,
#   'pm10_avg': 30,
#   'pm2.5': 14,
#   'pm2.5_avg': 11,
#   'pollutant': None,
#   'siteid': 85,
#   'sitename': '大城',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 45,
#   'windspeed': 9},
#  {'aqi': 48,
#   'co': 0.2,
#   'co_8hr': 0.2,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 25.29681695,
#   'longitude': 121.53656894,
#   'no': 0.1,
#   'no2': 1.8,
#   'nox': 1.9,
#   'o3': 54.8,
#   'o3_8hr': 46.4,
#   'pm10': 54,
#   'pm10_avg': 48,
#   'pm2.5': 18,
#   'pm2.5_avg': 13,
#   'pollutant': None,
#   'siteid': 84,
#   'sitename': '富貴角',
#   'so2': 0.3,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 51,
#   'windspeed': 10.7},
#  {'aqi': 70,
#   'co': 0.3,
#   'co_8hr': 0.3,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.753506,
#   'longitude': 120.251825,
#   'no': 1,
#   'no2': 7.3,
#   'nox': 8.3,
#   'o3': 34.5,
#   'o3_8hr': 40.5,
#   'pm10': 62,
#   'pm10_avg': 70,
#   'pm2.5': 14,
#   'pm2.5_avg': 11.7,
#   'pollutant': '懸浮微粒',
#   'siteid': 83,
#   'sitename': '麥寮',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 3,
#   'windspeed': 7.4},
#  {'aqi': 39,
#   'co': 0.33,
#   'co_8hr': 0.2,
#   'county': '臺東縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.045083,
#   'longitude': 121.161933,
#   'no': 0.3,
#   'no2': 5.1,
#   'nox': 5.4,
#   'o3': 30.9,
#   'o3_8hr': 33.2,
#   'pm10': 16,
#   'pm10_avg': 39,
#   'pm2.5': 6,
#   'pm2.5_avg': 5.3,
#   'pollutant': None,
#   'siteid': 80,
#   'sitename': '關山',
#   'so2': 0.9,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 37,
#   'windspeed': 2.6},
#  {'aqi': 35,
#   'co': 0.29,
#   'co_8hr': 0.3,
#   'county': '澎湖縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.569031,
#   'longitude': 119.566158,
#   'no': 0.8,
#   'no2': 3.4,
#   'nox': 4.2,
#   'o3': 41,
#   'o3_8hr': 38.2,
#   'pm10': 16,
#   'pm10_avg': 13,
#   'pm2.5': 9,
#   'pm2.5_avg': 5.2,
#   'pollutant': None,
#   'siteid': 78,
#   'sitename': '馬公',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 39,
#   'windspeed': 7.3},
#  {'aqi': 46,
#   'co': 0.38,
#   'co_8hr': 0.3,
#   'county': '金門縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 24.432133,
#   'longitude': 118.312256,
#   'no': 0.8,
#   'no2': 6.8,
#   'nox': 7.7,
#   'o3': 37,
#   'o3_8hr': 50.4,
#   'pm10': 22,
#   'pm10_avg': 21,
#   'pm2.5': 11,
#   'pm2.5_avg': 8.4,
#   'pollutant': None,
#   'siteid': 77,
#   'sitename': '金門',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 86,
#   'windspeed': 2.1},
#  {'aqi': 39,
#   'co': 0.27,
#   'co_8hr': 0.3,
#   'county': '連江縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 26.153736,
#   'longitude': 119.952724,
#   'no': 0.9,
#   'no2': 4.3,
#   'nox': 5.3,
#   'o3': 53,
#   'o3_8hr': 42.9,
#   'pm10': 34,
#   'pm10_avg': 24,
#   'pm2.5': 10,
#   'pm2.5_avg': 9.6,
#   'pollutant': None,
#   'siteid': 75,
#   'sitename': '馬祖',
#   'so2': 0.6,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 330,
#   'windspeed': 1},
#  {'aqi': 47,
#   'co': 0.4,
#   'co_8hr': 0.2,
#   'county': '南投縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.968842,
#   'longitude': 120.967903,
#   'no': 1.2,
#   'no2': 11.2,
#   'nox': 12.4,
#   'o3': 33.7,
#   'o3_8hr': 36.2,
#   'pm10': 23,
#   'pm10_avg': 17,
#   'pm2.5': 15,
#   'pm2.5_avg': 14.5,
#   'pollutant': None,
#   'siteid': 72,
#   'sitename': '埔里',
#   'so2': 1.7,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 310,
#   'windspeed': 0.5},
#  {'aqi': 56,
#   'co': 0.58,
#   'co_8hr': 0.4,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 22.608711,
#   'longitude': 120.312017,
#   'no': 1.8,
#   'no2': 21.2,
#   'nox': 23.1,
#   'o3': 33.8,
#   'o3_8hr': 43.1,
#   'pm10': 80,
#   'pm10_avg': 54,
#   'pm2.5': 19,
#   'pm2.5_avg': 17.5,
#   'pollutant': '細懸浮微粒',
#   'siteid': 71,
#   'sitename': '復興',
#   'so2': 1.5,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 282,
#   'windspeed': 2},
#  {'aqi': 34,
#   'co': 0.48,
#   'co_8hr': 0.4,
#   'county': '新北市',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 25.017,
#   'longitude': 121.516306,
#   'no': 3.6,
#   'no2': 15.4,
#   'nox': 19,
#   'o3': 36.7,
#   'o3_8hr': 29.7,
#   'pm10': 39,
#   'pm10_avg': 29,
#   'pm2.5': 14,
#   'pm2.5_avg': 10.4,
#   'pollutant': None,
#   'siteid': 70,
#   'sitename': '永和',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 73,
#   'windspeed': 2.7},
#  {'aqi': 37,
#   'co': 0.43,
#   'co_8hr': 0.3,
#   'county': '南投縣',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 23.756389,
#   'longitude': 120.677306,
#   'no': 0.6,
#   'no2': 17.1,
#   'nox': 17.8,
#   'o3': 19,
#   'o3_8hr': 39.8,
#   'pm10': 33,
#   'pm10_avg': 28,
#   'pm2.5': 18,
#   'pm2.5_avg': 11.4,
#   'pollutant': None,
#   'siteid': 69,
#   'sitename': '竹山',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 23,
#   'windspeed': 2},
#  {'aqi': 47,
#   'co': 0.8,
#   'co_8hr': 0.7,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 19:00',
#   'latitude': 24.953278,
#   'longitude': 121.221667,
#   'no': 20.9,
#   'no2': 28,
#   'nox': 49,
#   'o3': 22.9,
#   'o3_8hr': 16.2,
#   'pm10': 41,
#   'pm10_avg': 27,
#   'pm2.5': 14,
#   'pm2.5_avg': 12,
#   'pollutant': None,
#   'siteid': 68,
#   'sitename': '中壢',
#   'so2': 0.7,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 307,
#   'windspeed': 1.2},
#  {'aqi': 55,
#   'co': 1.16,
#   'co_8hr': 1,
#   'county': '新北市',
# ...
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.63390278,
#   'longitude': 120.28676111,
#   'no': 2.6,
#   'no2': 11,
#   'nox': 13.6,
#   'o3': 48.2,
#   'o3_8hr': 31.9,
#   'pm10': 47,
#   'pm10_avg': 52,
#   'pm2.5': 16,
#   'pm2.5_avg': 16.6,
#   'pollutant': '細懸浮微粒',
#   'siteid': 56,
#   'sitename': '前金',
#   'so2': 1.1,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 356,
#   'windspeed': 4.1},
#  {'aqi': 55,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.674861,
#   'longitude': 120.292917,
#   'no': 1.2,
#   'no2': 6.3,
#   'nox': 7.5,
#   'o3': 52.6,
#   'o3_8hr': 33.6,
#   'pm10': 41,
#   'pm10_avg': 43,
#   'pm2.5': 19,
#   'pm2.5_avg': 17,
#   'pollutant': '細懸浮微粒',
#   'siteid': 54,
#   'sitename': '左營',
#   'so2': 1.3,
#   'so2_avg': 0,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 359,
#   'windspeed': 4},
#  {'aqi': 48,
#   'co': 0.22,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.733667,
#   'longitude': 120.328289,
#   'no': 1.1,
#   'no2': 8.8,
#   'nox': 9.9,
#   'o3': 51.9,
#   'o3_8hr': 32.4,
#   'pm10': 41,
#   'pm10_avg': 46,
#   'pm2.5': 14,
#   'pm2.5_avg': 14.8,
#   'pollutant': None,
#   'siteid': 53,
#   'sitename': '楠梓',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 25,
#   'windspeed': 2.6},
#  {'aqi': 62,
#   'co': 0.29,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.4795,
#   'longitude': 120.41175,
#   'no': 0.8,
#   'no2': 8.8,
#   'nox': 9.7,
#   'o3': 50.6,
#   'o3_8hr': 34.3,
#   'pm10': 29,
#   'pm10_avg': 40,
#   'pm2.5': 11,
#   'pm2.5_avg': 20.1,
#   'pollutant': '細懸浮微粒',
#   'siteid': 52,
#   'sitename': '林園',
#   'so2': 2,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 1,
#   'windspeed': 2.1},
#  {'aqi': 57,
#   'co': 0.2,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.56413611,
#   'longitude': 120.425311,
#   'no': 1.2,
#   'no2': 8.7,
#   'nox': 9.9,
#   'o3': 48.9,
#   'o3_8hr': 30.9,
#   'pm10': 20,
#   'pm10_avg': 24,
#   'pm2.5': 13,
#   'pm2.5_avg': 17.8,
#   'pollutant': '細懸浮微粒',
#   'siteid': 51,
#   'sitename': '大寮',
#   'so2': 1,
#   'so2_avg': 2,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 359,
#   'windspeed': 1.7},
#  {'aqi': 59,
#   'co': 0.37,
#   'co_8hr': 0.4,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.628126,
#   'longitude': 120.357422,
#   'no': 2.8,
#   'no2': 12.1,
#   'nox': 15,
#   'o3': 45.4,
#   'o3_8hr': 28.8,
#   'pm10': 43,
#   'pm10_avg': 41,
#   'pm2.5': 14,
#   'pm2.5_avg': 18.9,
#   'pollutant': '細懸浮微粒',
#   'siteid': 50,
#   'sitename': '鳳山',
#   'so2': 0.7,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 269,
#   'windspeed': 1.5},
#  {'aqi': 59,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.689056,
#   'longitude': 120.332631,
#   'no': 2.2,
#   'no2': 8.9,
#   'nox': 11.1,
#   'o3': 49.3,
#   'o3_8hr': 29.4,
#   'pm10': 29,
#   'pm10_avg': 36,
#   'pm2.5': 15,
#   'pm2.5_avg': 18.6,
#   'pollutant': '細懸浮微粒',
#   'siteid': 49,
#   'sitename': '仁武',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 345,
#   'windspeed': 3.2},
#  {'aqi': 52,
#   'co': 0.22,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.757506,
#   'longitude': 120.305689,
#   'no': 1.6,
#   'no2': 8.7,
#   'nox': 10.3,
#   'o3': 50.1,
#   'o3_8hr': 32.2,
#   'pm10': 31,
#   'pm10_avg': 40,
#   'pm2.5': 11,
#   'pm2.5_avg': 16,
#   'pollutant': '細懸浮微粒',
#   'siteid': 48,
#   'sitename': '橋頭',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 10,
#   'windspeed': 2.9},
#  {'aqi': 33,
#   'co': 0.2,
#   'co_8hr': 0.2,
#   'county': '高雄市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.883583,
#   'longitude': 120.530542,
#   'no': 1.1,
#   'no2': 3.9,
#   'nox': 5,
#   'o3': 46,
#   'o3_8hr': 29.9,
#   'pm10': 19,
#   'pm10_avg': 23,
#   'pm2.5': 7,
#   'pm2.5_avg': 10.1,
#   'pollutant': None,
#   'siteid': 47,
#   'sitename': '美濃',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 293,
#   'windspeed': 1.5},
#  {'aqi': 35,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 22.98928311,
#   'longitude': 120.21947897,
#   'no': 0.6,
#   'no2': 7.1,
#   'nox': 7.8,
#   'o3': 48.6,
#   'o3_8hr': 32,
#   'pm10': 39,
#   'pm10_avg': 35,
#   'pm2.5': 11,
#   'pm2.5_avg': 8.8,
#   'pollutant': None,
#   'siteid': 46,
#   'sitename': '臺南',
#   'so2': 1.3,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 15,
#   'windspeed': 2.8},
#  {'aqi': 43,
#   'co': 0.26,
#   'co_8hr': 0.2,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.048197,
#   'longitude': 120.2175,
#   'no': 1.3,
#   'no2': 5.9,
#   'nox': 7.3,
#   'o3': 48.4,
#   'o3_8hr': 32.4,
#   'pm10': 44,
#   'pm10_avg': 43,
#   'pm2.5': 10,
#   'pm2.5_avg': 12.5,
#   'pollutant': None,
#   'siteid': 45,
#   'sitename': '安南',
#   'so2': 1.1,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 328,
#   'windspeed': 3.6},
#  {'aqi': 40,
#   'co': 0.19,
#   'co_8hr': 0.1,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.11337642,
#   'longitude': 120.29740529,
#   'no': 1.2,
#   'no2': 3.9,
#   'nox': 5.1,
#   'o3': 49.6,
#   'o3_8hr': 32.7,
#   'pm10': 39,
#   'pm10_avg': 40,
#   'pm2.5': 7,
#   'pm2.5_avg': 9.2,
#   'pollutant': None,
#   'siteid': 44,
#   'sitename': '善化',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 8,
#   'windspeed': 5.2},
#  {'aqi': 45,
#   'co': 0.25,
#   'co_8hr': 0.2,
#   'county': '臺南市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.305633,
#   'longitude': 120.31725,
#   'no': 1.4,
#   'no2': 6.7,
#   'nox': 8.2,
#   'o3': 46.8,
#   'o3_8hr': 30.3,
#   'pm10': 49,
#   'pm10_avg': 45,
#   'pm2.5': 13,
#   'pm2.5_avg': 10.5,
#   'pollutant': None,
#   'siteid': 43,
#   'sitename': '新營',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 25,
#   'windspeed': 3.4},
#  {'aqi': 36,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '嘉義市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.46477865,
#   'longitude': 120.44125148,
#   'no': 1.1,
#   'no2': 4.4,
#   'nox': 5.5,
#   'o3': 51.1,
#   'o3_8hr': 30.9,
#   'pm10': 33,
#   'pm10_avg': 35,
#   'pm2.5': 8,
#   'pm2.5_avg': 11.1,
#   'pollutant': None,
#   'siteid': 42,
#   'sitename': '嘉義',
#   'so2': 1.1,
#   'so2_avg': 2,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 13,
#   'windspeed': 2.5},
#  {'aqi': 34,
#   'co': 0.32,
#   'co_8hr': 0.2,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.702175,
#   'longitude': 120.19933333,
#   'no': 1.6,
#   'no2': 7.3,
#   'nox': 9,
#   'o3': 42.7,
#   'o3_8hr': 31.8,
#   'pm10': 37,
#   'pm10_avg': 34,
#   'pm2.5': 6,
#   'pm2.5_avg': 5.2,
#   'pollutant': None,
#   'siteid': 41,
#   'sitename': '臺西',
#   'so2': 1.6,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 19,
#   'windspeed': 6.8},
#  {'aqi': 50,
#   'co': 0.23,
#   'co_8hr': 0.2,
#   'county': '嘉義縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.46538,
#   'longitude': 120.2478,
#   'no': 2.4,
#   'no2': 4.6,
#   'nox': 7,
#   'o3': 46.7,
#   'o3_8hr': 31.2,
#   'pm10': 38,
#   'pm10_avg': 50,
#   'pm2.5': 10,
#   'pm2.5_avg': 7.3,
#   'pollutant': None,
#   'siteid': 40,
#   'sitename': '朴子',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 345,
#   'windspeed': 2.8},
#  {'aqi': 34,
#   'co': 0.22,
#   'co_8hr': 0.1,
#   'county': '嘉義縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.554839,
#   'longitude': 120.345531,
#   'no': 0.9,
#   'no2': 6.1,
#   'nox': 7.1,
#   'o3': 49,
#   'o3_8hr': 32.6,
#   'pm10': 26,
#   'pm10_avg': 34,
#   'pm2.5': 14,
#   'pm2.5_avg': 8.9,
#   'pollutant': None,
#   'siteid': 39,
#   'sitename': '新港',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 7,
#   'windspeed': 3.5},
#  {'aqi': 63,
#   'co': 0.31,
#   'co_8hr': 0.2,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.757547,
#   'longitude': 120.348742,
#   'no': 1.2,
#   'no2': 5.1,
#   'nox': 6.4,
#   'o3': 46.4,
#   'o3_8hr': 28,
#   'pm10': 33,
#   'pm10_avg': 63,
#   'pm2.5': 8,
#   'pm2.5_avg': 9.8,
#   'pollutant': '懸浮微粒',
#   'siteid': 38,
#   'sitename': '崙背',
#   'so2': 1.1,
#   'so2_avg': 1,
#   'status': '普通',
#   'unit': None,
#   'winddirec': 323,
#   'windspeed': 2.5},
#  {'aqi': 41,
#   'co': 0.24,
#   'co_8hr': 0.2,
#   'county': '雲林縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.711853,
#   'longitude': 120.544994,
#   'no': 0.9,
#   'no2': 4.6,
#   'nox': 5.6,
#   'o3': 52.3,
#   'o3_8hr': 31.3,
#   'pm10': 16,
#   'pm10_avg': 41,
#   'pm2.5': 5,
#   'pm2.5_avg': 8.1,
#   'pollutant': None,
#   'siteid': 37,
#   'sitename': '斗六',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 10,
#   'windspeed': 1.5},
#  {'aqi': 27,
#   'co': 0.28,
#   'co_8hr': 0.3,
#   'county': '南投縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.913,
#   'longitude': 120.685306,
#   'no': 1.8,
#   'no2': 7.5,
#   'nox': 9.4,
#   'o3': 48.3,
#   'o3_8hr': 26.4,
#   'pm10': 9,
#   'pm10_avg': 19,
#   'pm2.5': 4,
#   'pm2.5_avg': 8.3,
#   'pollutant': None,
#   'siteid': 36,
#   'sitename': '南投',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 221,
#   'windspeed': 1.6},
#  {'aqi': 29,
#   'co': 0.34,
#   'co_8hr': 0.2,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 23.925175,
#   'longitude': 120.409653,
#   'no': 1.4,
#   'no2': 6.1,
#   'nox': 7.5,
#   'o3': 49.4,
#   'o3_8hr': 31.5,
#   'pm10': 24,
#   'pm10_avg': 26,
#   'pm2.5': 6,
#   'pm2.5_avg': 6.2,
#   'pollutant': None,
#   'siteid': 35,
#   'sitename': '二林',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 352,
#   'windspeed': 4.9},
#  {'aqi': 26,
#   'co': 0.36,
#   'co_8hr': 0.2,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.131672,
#   'longitude': 120.469061,
#   'no': 2.4,
#   'no2': 8.6,
#   'nox': 11,
#   'o3': 39.8,
#   'o3_8hr': 28.8,
#   'pm10': 22,
#   'pm10_avg': 17,
#   'pm2.5': 3,
#   'pm2.5_avg': 5,
#   'pollutant': None,
#   'siteid': 34,
#   'sitename': '線西',
#   'so2': 1.9,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 14,
#   'windspeed': 7.4},
#  {'aqi': 22,
#   'co': 0.34,
#   'co_8hr': 0.3,
#   'county': '彰化縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.066,
#   'longitude': 120.541519,
#   'no': None,
#   'no2': None,
#   'nox': None,
#   'o3': 30.1,
#   'o3_8hr': 24.6,
#   'pm10': None,
#   'pm10_avg': 13,
#   'pm2.5': None,
#   'pm2.5_avg': 6.8,
#   'pollutant': None,
#   'siteid': 33,
#   'sitename': '彰化',
#   'so2': 0.4,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 5,
#   'windspeed': 2.7},
#  {'aqi': 24,
#   'co': 0.3,
#   'co_8hr': 0.2,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.162197,
#   'longitude': 120.616917,
#   'no': 2.6,
#   'no2': 8.1,
#   'nox': 10.7,
#   'o3': 38.6,
#   'o3_8hr': 27,
#   'pm10': 15,
#   'pm10_avg': 22,
#   'pm2.5': 4,
#   'pm2.5_avg': 6.1,
#   'pollutant': None,
#   'siteid': 32,
#   'sitename': '西屯',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 352,
#   'windspeed': 4.4},
#  {'aqi': 23,
#   'co': 0.36,
#   'co_8hr': 0.2,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.151958,
#   'longitude': 120.641092,
#   'no': 3.5,
#   'no2': 10.1,
#   'nox': 13.7,
#   'o3': 37.2,
#   'o3_8hr': 25.9,
#   'pm10': 10,
#   'pm10_avg': 14,
#   'pm2.5': 4,
#   'pm2.5_avg': 5.9,
#   'pollutant': None,
#   'siteid': 31,
#   'sitename': '忠明',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 283,
#   'windspeed': 2.2},
#  {'aqi': 25,
#   'co': 0.36,
#   'co_8hr': 0.2,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.09961111,
#   'longitude': 120.67844444,
#   'no': 3.2,
#   'no2': 9.4,
#   'nox': 12.6,
#   'o3': 40.6,
#   'o3_8hr': 27.2,
#   'pm10': 9,
#   'pm10_avg': 15,
#   'pm2.5': 4,
#   'pm2.5_avg': 7.7,
#   'pollutant': None,
#   'siteid': 30,
#   'sitename': '大里',
#   'so2': 1.3,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 297,
#   'windspeed': 3.1},
#  {'aqi': 25,
#   'co': 0.32,
#   'co_8hr': 0.2,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.225628,
#   'longitude': 120.568794,
#   'no': 2.1,
#   'no2': 6.5,
#   'nox': 8.6,
#   'o3': 40.6,
#   'o3_8hr': 27.7,
#   'pm10': 9,
#   'pm10_avg': 15,
#   'pm2.5': 6,
#   'pm2.5_avg': 5.7,
#   'pollutant': None,
#   'siteid': 29,
#   'sitename': '沙鹿',
#   'so2': 0.9,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 338,
#   'windspeed': 5.2},
#  {'aqi': 28,
#   'co': 0.3,
#   'co_8hr': 0.2,
#   'county': '臺中市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.25699731,
#   'longitude': 120.74252414,
#   'no': 1.2,
#   'no2': 5.1,
#   'nox': 6.3,
#   'o3': 40.2,
#   'o3_8hr': 30.6,
#   'pm10': 8,
#   'pm10_avg': 9,
#   'pm2.5': 4,
#   'pm2.5_avg': 7.4,
#   'pollutant': None,
#   'siteid': 28,
#   'sitename': '豐原',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 330,
#   'windspeed': 3.8},
#  {'aqi': 23,
#   'co': 0.31,
#   'co_8hr': 0.2,
#   'county': '苗栗縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.38248443,
#   'longitude': 120.75956754,
#   'no': 2.3,
#   'no2': 4.3,
#   'nox': 6.6,
#   'o3': 33.8,
#   'o3_8hr': 25.2,
#   'pm10': 9,
#   'pm10_avg': 8,
#   'pm2.5': 2,
#   'pm2.5_avg': 3.9,
#   'pollutant': None,
#   'siteid': 27,
#   'sitename': '三義',
#   'so2': 0.8,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 12,
#   'windspeed': 6.2},
#  {'aqi': 19,
#   'co': 0.32,
#   'co_8hr': 0.2,
#   'county': '苗栗縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.56499183,
#   'longitude': 120.82011468,
#   'no': 2.3,
#   'no2': 6,
#   'nox': 8.3,
#   'o3': 32.2,
#   'o3_8hr': 21.4,
#   'pm10': 9,
#   'pm10_avg': 12,
#   'pm2.5': 3,
#   'pm2.5_avg': 4.9,
#   'pollutant': None,
#   'siteid': 26,
#   'sitename': '苗栗',
#   'so2': 1.2,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 6,
#   'windspeed': 5},
#  {'aqi': 19,
#   'co': 0.36,
#   'co_8hr': 0.3,
#   'county': '苗栗縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.69690679,
#   'longitude': 120.89869286,
#   'no': 3.6,
#   'no2': 6.9,
#   'nox': 10.6,
#   'o3': 28.8,
#   'o3_8hr': 21.5,
#   'pm10': 6,
#   'pm10_avg': 10,
#   'pm2.5': 6,
#   'pm2.5_avg': 5.8,
#   'pollutant': None,
#   'siteid': 25,
#   'sitename': '頭份',
#   'so2': 1.8,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 10,
#   'windspeed': 4.6},
#  {'aqi': 19,
#   'co': 0.39,
#   'co_8hr': 0.3,
#   'county': '新竹市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.8056356,
#   'longitude': 120.97236752,
#   'no': 3.1,
#   'no2': 9.7,
#   'nox': 12.8,
#   'o3': 24.7,
#   'o3_8hr': 21.8,
#   'pm10': 4,
#   'pm10_avg': 8,
#   'pm2.5': 4,
#   'pm2.5_avg': 3.3,
#   'pollutant': None,
#   'siteid': 24,
#   'sitename': '新竹',
#   'so2': 1.4,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 28,
#   'windspeed': 4.4},
#  {'aqi': 19,
#   'co': 0.32,
#   'co_8hr': 0.2,
#   'county': '新竹縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.74091408,
#   'longitude': 121.08895493,
#   'no': 1.7,
#   'no2': 5,
#   'nox': 6.7,
#   'o3': 31.4,
#   'o3_8hr': 21.2,
#   'pm10': 7,
#   'pm10_avg': 9,
#   'pm2.5': 0,
#   'pm2.5_avg': 4.4,
#   'pollutant': None,
#   'siteid': 23,
#   'sitename': '竹東',
#   'so2': 0.3,
#   'so2_avg': 0,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 19,
#   'windspeed': 3.1},
#  {'aqi': 21,
#   'co': 0.38,
#   'co_8hr': 0.3,
#   'county': '新竹縣',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.90009696,
#   'longitude': 121.03886894,
#   'no': 2,
#   'no2': 8.9,
#   'nox': 10.9,
#   'o3': 22.8,
#   'o3_8hr': 23,
#   'pm10': 8,
#   'pm10_avg': 9,
#   'pm2.5': 5,
#   'pm2.5_avg': 5.2,
#   'pollutant': None,
#   'siteid': 22,
#   'sitename': '湖口',
#   'so2': 2.5,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 37,
#   'windspeed': 6},
#  {'aqi': 20,
#   'co': 0.34,
#   'co_8hr': 0.3,
#   'county': '桃園市',
#   'datacreationdate': '2024-11-26 14:00',
#   'latitude': 24.86400048,
#   'longitude': 121.21645772,
#   'no': 2.3,
#   'no2': 5.9,
#   'nox': 8.2,
#   'o3': 30.6,
#   'o3_8hr': 20.9,
#   'pm10': 14,
#   'pm10_avg': 11,
#   'pm2.5': 4,
#   'pm2.5_avg': 6.3,
#   'pollutant': None,
#   'siteid': 21,
#   'sitename': '龍潭',
#   'so2': 1,
#   'so2_avg': 1,
#   'status': '良好',
#   'unit': None,
#   'winddirec': 57,
#   'windspeed': 6.4}]

# %%
for site in sheets:
    if site['sitename'] == '永和':
        print(site)
# Out:
# {'sitename': '永和', 'county': '新北市', 'aqi': 35, 'pollutant': None, 'status': '良好', 'so2': 1.1, 'co': 0.44, 'o3': 37.8, 'o3_8hr': 32, 'pm10': 40, 'pm2.5': 12, 'no2': 13.6, 'nox': 16.5, 'no': 2.9, 'windspeed': 2.2, 'winddirec': 82, 'datacreationdate': '2024-11-26 20:00', 'unit': None, 'co_8hr': 0.4, 'pm2.5_avg': 10.7, 'pm10_avg': 32, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
# {'sitename': '永和', 'county': '新北市', 'aqi': 34, 'pollutant': None, 'status': '良好', 'so2': 1, 'co': 0.48, 'o3': 36.7, 'o3_8hr': 29.7, 'pm10': 39, 'pm2.5': 14, 'no2': 15.4, 'nox': 19, 'no': 3.6, 'windspeed': 2.7, 'winddirec': 73, 'datacreationdate': '2024-11-26 19:00', 'unit': None, 'co_8hr': 0.4, 'pm2.5_avg': 10.4, 'pm10_avg': 29, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
# {'sitename': '永和', 'county': '新北市', 'aqi': 34, 'pollutant': None, 'status': '良好', 'so2': 1, 'co': 0.48, 'o3': 36.7, 'o3_8hr': 29.7, 'pm10': 39, 'pm2.5': 14, 'no2': 15.4, 'nox': 19, 'no': 3.6, 'windspeed': 2.7, 'winddirec': 73, 'datacreationdate': '2024-11-26 19:00', 'unit': None, 'co_8hr': 0.4, 'pm2.5_avg': 10.4, 'pm10_avg': 29, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
# {'sitename': '永和', 'county': '新北市', 'aqi': 31, 'pollutant': None, 'status': '良好', 'so2': 1.1, 'co': 0.49, 'o3': 36.2, 'o3_8hr': 27.1, 'pm10': 44, 'pm2.5': 15, 'no2': 14.8, 'nox': 18.1, 'no': 3.2, 'windspeed': 1.7, 'winddirec': 77, 'datacreationdate': '2024-11-26 18:00', 'unit': None, 'co_8hr': 0.4, 'pm2.5_avg': 9.5, 'pm10_avg': 27, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
# {'sitename': '永和', 'county': '新北市', 'aqi': 31, 'pollutant': None, 'status': '良好', 'so2': 1.1, 'co': 0.49, 'o3': 36.2, 'o3_8hr': 27.1, 'pm10': 44, 'pm2.5': 15, 'no2': 14.8, 'nox': 18.1, 'no': 3.2, 'windspeed': 1.7, 'winddirec': 77, 'datacreationdate': '2024-11-26 18:00', 'unit': None, 'co_8hr': 0.4, 'pm2.5_avg': 9.5, 'pm10_avg': 27, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
# {'sitename': '永和', 'county': '新北市', 'aqi': 28, 'pollutant': None, 'status': '良好', 'so2': 1, 'co': 0.4, 'o3': 32.7, 'o3_8hr': 24.4, 'pm10': 40, 'pm2.5': 11, 'no2': 15, 'nox': 20.5, 'no': 5.4, 'windspeed': 2.4, 'winddirec': 75, 'datacreationdate': '2024-11-26 17:00', 'unit': None, 'co_8hr': 0.4, 'pm2.5_avg': 8.5, 'pm10_avg': 23, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
# {'sitename': '永和', 'county': '新北市', 'aqi': 28, 'pollutant': None, 'status': '良好', 'so2': 1, 'co': 0.4, 'o3': 32.7, 'o3_8hr': 24.4, 'pm10': 40, 'pm2.5': 11, 'no2': 15, 'nox': 20.5, 'no': 5.4, 'windspeed': 2.4, 'winddirec': 75, 'datacreationdate': '2024-11-26 17:00', 'unit': None, 'co_8hr': 0.4, 'pm2.5_avg': 8.5, 'pm10_avg': 23, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
# {'sitename': '永和', 'county': '新北市', 'aqi': 24, 'pollutant': None, 'status': '良好', 'so2': 0.9, 'co': 0.37, 'o3': 33.5, 'o3_8hr': 21.5, 'pm10': 30, 'pm2.5': 11, 'no2': 10.3, 'nox': 13.6, 'no': 3.2, 'windspeed': 2.7, 'winddirec': 90, 'datacreationdate': '2024-11-26 16:00', 'unit': None, 'co_8hr': 0.5, 'pm2.5_avg': 7.5, 'pm10_avg': 19, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
# {'sitename': '永和', 'county': '新北市', 'aqi': 24, 'pollutant': None, 'status': '良好', 'so2': 0.9, 'co': 0.37, 'o3': 33.5, 'o3_8hr': 21.5, 'pm10': 30, 'pm2.5': 11, 'no2': 10.3, 'nox': 13.6, 'no': 3.2, 'windspeed': 2.7, 'winddirec': 90, 'datacreationdate': '2024-11-26 16:00', 'unit': None, 'co_8hr': 0.5, 'pm2.5_avg': 7.5, 'pm10_avg': 19, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
# {'sitename': '永和', 'county': '新北市', 'aqi': 22, 'pollutant': None, 'status': '良好', 'so2': 0.9, 'co': 0.41, 'o3': 30.2, 'o3_8hr': 18.6, 'pm10': 27, 'pm2.5': 8, 'no2': 10.3, 'nox': 14.5, 'no': 4.2, 'windspeed': 3.6, 'winddirec': 67, 'datacreationdate': '2024-11-26 15:00', 'unit': None, 'co_8hr': 0.7, 'pm2.5_avg': 6.7, 'pm10_avg': 15, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
# {'sitename': '永和', 'county': '新北市', 'aqi': 22, 'pollutant': None, 'status': '良好', 'so2': 0.9, 'co': 0.41, 'o3': 30.2, 'o3_8hr': 18.6, 'pm10': 27, 'pm2.5': 8, 'no2': 10.3, 'nox': 14.5, 'no': 4.2, 'windspeed': 3.6, 'winddirec': 67, 'datacreationdate': '2024-11-26 15:00', 'unit': None, 'co_8hr': 0.7, 'pm2.5_avg': 6.7, 'pm10_avg': 15, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
# {'sitename': '永和', 'county': '新北市', 'aqi': 20, 'pollutant': None, 'status': '良好', 'so2': 0.9, 'co': 0.48, 'o3': 25.3, 'o3_8hr': 16.5, 'pm10': 21, 'pm2.5': 9, 'no2': 10.4, 'nox': 15.2, 'no': 4.7, 'windspeed': 3.3, 'winddirec': 81, 'datacreationdate': '2024-11-26 14:00', 'unit': None, 'co_8hr': 0.7, 'pm2.5_avg': 6.2, 'pm10_avg': 13, 'so2_avg': 1, 'longitude': 121.516306, 'latitude': 25.017, 'siteid': 70}
